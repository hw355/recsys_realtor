# %% [markdown]
# # Content-based Engines for the for-sale Homes using Python

# %%
import numpy as np
import pandas as pd
import requests
import json
import urllib
import datetime as dt

import os, sys, inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir)

from ipynb.fs.full.Credentials import *

# %%
DS_dir = currentdir + '/Data_Source'

try:
    os.mkdir(DS_dir, mode = 0o666)

except FileExistsError:
    
    pass

# %% [markdown]
# ## Data Collection

# %%
where = urllib.parse.quote_plus("""
{
    "State": "NJ",
    "County": "Ocean County"
}
""")
url = 'https://parseapi.back4app.com/classes/US_Zip_Code?count=1&limit=35&order=US_Zip_Code&excludeKeys=Unacceptable_cities,country,Remarks,Timezone&where=%s' % where
headers = {
    'X-Parse-Application-Id': back4app_ID,
    'X-Parse-Master-Key': back4app_key
}

data_cities = json.loads(requests.get(url, headers = headers).content.decode('utf-8'))
print(json.dumps(data_cities, indent = 2))
# Out:
# {
#   "results": [
#     {
#       "objectId": "meQ6vKJetk",
#       "US_Zip_Code": 8005,
#       "Type": "STANDARD",
#       "Primary_city": "Barnegat",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 609,
#       "Latitude": 39.75,
#       "Longitude": -74.22,
#       "estimated_population": 19593,
#       "createdAt": "2020-02-11T17:24:50.669Z",
#       "updatedAt": "2020-02-11T17:24:50.669Z"
#     },
#     {
#       "objectId": "dtP0eU85lh",
#       "US_Zip_Code": 8006,
#       "Type": "PO BOX",
#       "Primary_city": "Barnegat Light",
#       "Acceptable_cities": "Barnegat Lgt",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 609,
#       "Latitude": 39.75,
#       "Longitude": -74.11,
#       "estimated_population": 687,
#       "createdAt": "2020-02-11T17:24:50.669Z",
#       "updatedAt": "2020-02-11T17:24:50.669Z"
#     },
#     {
#       "objectId": "lc4pUW4mon",
#       "US_Zip_Code": 8008,
#       "Type": "STANDARD",
#       "Primary_city": "Beach Haven",
#       "Acceptable_cities": "Harvey Cedars, Long Bch Twp, Long Beach, Long Beach Township, Ship Bottom, Surf City",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 609,
#       "Latitude": 39.55,
#       "Longitude": -74.24,
#       "estimated_population": 6743,
#       "createdAt": "2020-02-11T17:24:50.669Z",
#       "updatedAt": "2020-02-11T17:24:50.669Z"
#     },
#     {
#       "objectId": "LJ6dAgrWmg",
#       "US_Zip_Code": 8050,
#       "Type": "STANDARD",
#       "Primary_city": "Manahawkin",
#       "Acceptable_cities": "Stafford Township, Stafford Twp",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 609,
#       "Latitude": 39.69,
#       "Longitude": -74.25,
#       "estimated_population": 20931,
#       "createdAt": "2020-02-11T17:24:50.706Z",
#       "updatedAt": "2020-02-11T17:24:50.706Z"
#     },
#     {
#       "objectId": "YMZimxAlJ9",
#       "US_Zip_Code": 8087,
#       "Type": "STANDARD",
#       "Primary_city": "Tuckerton",
#       "Acceptable_cities": "Little Egg Harbor, Little Egg Harbor Twp, Ltl Egg Hbr, Mystic Islands, Mystic Islnds",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 609,
#       "Latitude": 39.59,
#       "Longitude": -74.32,
#       "estimated_population": 20609,
#       "createdAt": "2020-02-11T17:24:50.708Z",
#       "updatedAt": "2020-02-11T17:24:50.708Z"
#     },
#     {
#       "objectId": "srBzYvMuo4",
#       "US_Zip_Code": 8092,
#       "Type": "STANDARD",
#       "Primary_city": "West Creek",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 609,
#       "Latitude": 39.65,
#       "Longitude": -74.28,
#       "estimated_population": 3158,
#       "createdAt": "2020-02-11T17:24:50.708Z",
#       "updatedAt": "2020-02-11T17:24:50.708Z"
#     },
#     {
#       "objectId": "MHHcTj6OPc",
#       "US_Zip_Code": 8527,
#       "Type": "STANDARD",
#       "Primary_city": "Jackson",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 40.1,
#       "Longitude": -74.35,
#       "estimated_population": 47406,
#       "createdAt": "2020-02-11T17:24:50.753Z",
#       "updatedAt": "2020-02-11T17:24:50.753Z"
#     },
#     {
#       "objectId": "Vv5aU0LOUX",
#       "US_Zip_Code": 8533,
#       "Type": "STANDARD",
#       "Primary_city": "New Egypt",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 609,
#       "Latitude": 40.06,
#       "Longitude": -74.53,
#       "estimated_population": 6225,
#       "createdAt": "2020-02-11T17:24:50.754Z",
#       "updatedAt": "2020-02-11T17:24:50.754Z"
#     },
#     {
#       "objectId": "lHgsyHmsNF",
#       "US_Zip_Code": 8701,
#       "Type": "STANDARD",
#       "Primary_city": "Lakewood",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732610000000,
#       "Latitude": 40.09,
#       "Longitude": -74.21,
#       "estimated_population": 52778,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "4T4vhwyS3A",
#       "US_Zip_Code": 8721,
#       "Type": "STANDARD",
#       "Primary_city": "Bayville",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 39.91,
#       "Longitude": -74.21,
#       "estimated_population": 17550,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "EARqt5TGi6",
#       "US_Zip_Code": 8722,
#       "Type": "STANDARD",
#       "Primary_city": "Beachwood",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 39.92,
#       "Longitude": -74.2,
#       "estimated_population": 9570,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "nor0AD2OKt",
#       "US_Zip_Code": 8723,
#       "Type": "STANDARD",
#       "Primary_city": "Brick",
#       "Acceptable_cities": "Osbornville",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 40.06,
#       "Longitude": -74.11,
#       "estimated_population": 27903,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "iS57kYIQUs",
#       "US_Zip_Code": 8724,
#       "Type": "STANDARD",
#       "Primary_city": "Brick",
#       "Acceptable_cities": "Wall Township",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 40.06,
#       "Longitude": -74.11,
#       "estimated_population": 37268,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "E8GsD2HHVN",
#       "US_Zip_Code": 8731,
#       "Type": "STANDARD",
#       "Primary_city": "Forked River",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 609732856,
#       "Latitude": 39.84,
#       "Longitude": -74.19,
#       "estimated_population": 17395,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "v3eNyb5DTp",
#       "US_Zip_Code": 8732,
#       "Type": "PO BOX",
#       "Primary_city": "Island Heights",
#       "Acceptable_cities": "Island Hgts",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 39.94,
#       "Longitude": -74.14,
#       "estimated_population": 1563,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "jCyxZOkjkw",
#       "US_Zip_Code": 8733,
#       "Type": "STANDARD",
#       "Primary_city": "Lakehurst",
#       "Acceptable_cities": "Lakehurst Nae, Lakehurst Naec",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 40.01,
#       "Longitude": -74.32,
#       "estimated_population": 2437,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "ttFMAIpYDr",
#       "US_Zip_Code": 8734,
#       "Type": "STANDARD",
#       "Primary_city": "Lanoka Harbor",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 609,
#       "Latitude": 39.86,
#       "Longitude": -74.16,
#       "estimated_population": 6888,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "ctHq2rrXTA",
#       "US_Zip_Code": 8735,
#       "Type": "STANDARD",
#       "Primary_city": "Lavallette",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 39.96,
#       "Longitude": -74.06,
#       "estimated_population": 2840,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "svWKYNzwFE",
#       "US_Zip_Code": 8738,
#       "Type": "STANDARD",
#       "Primary_city": "Mantoloking",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 40.04,
#       "Longitude": -74.04,
#       "estimated_population": 831,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "qYFoCFL6u6",
#       "US_Zip_Code": 8739,
#       "Type": "PO BOX",
#       "Primary_city": "Normandy Beach",
#       "Acceptable_cities": "Normandy Bch",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 40,
#       "Longitude": -74.06,
#       "estimated_population": 478,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "8pA5MtSBVJ",
#       "US_Zip_Code": 8740,
#       "Type": "PO BOX",
#       "Primary_city": "Ocean Gate",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 39.92,
#       "Longitude": -74.13,
#       "estimated_population": 1669,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "5g0VmmxWIa",
#       "US_Zip_Code": 8741,
#       "Type": "STANDARD",
#       "Primary_city": "Pine Beach",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 39.93,
#       "Longitude": -74.17,
#       "estimated_population": 2458,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "dp0RtgEz1C",
#       "US_Zip_Code": 8742,
#       "Type": "STANDARD",
#       "Primary_city": "Point Pleasant Beach",
#       "Acceptable_cities": "Bay Head, Point Pleasant Boro, Pt Pleas Bch, Pt Pleasant, Pt Pleasant B, Pt Pleasant Beach",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 40.09,
#       "Longitude": -74.04,
#       "estimated_population": 22127,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "euVxvd2u6T",
#       "US_Zip_Code": 8751,
#       "Type": "STANDARD",
#       "Primary_city": "Seaside Heights",
#       "Acceptable_cities": "Seaside Hgts",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 201732,
#       "Latitude": 39.94,
#       "Longitude": -74.07,
#       "estimated_population": 3094,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "W4acBzqd64",
#       "US_Zip_Code": 8752,
#       "Type": "STANDARD",
#       "Primary_city": "Seaside Park",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 201732,
#       "Latitude": 39.79,
#       "Longitude": -74.09,
#       "estimated_population": 1913,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "itFWH1ht9y",
#       "US_Zip_Code": 8753,
#       "Type": "STANDARD",
#       "Primary_city": "Toms River",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 39.95,
#       "Longitude": -74.18,
#       "estimated_population": 55159,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "mU0Ht5IQ77",
#       "US_Zip_Code": 8754,
#       "Type": "PO BOX",
#       "Primary_city": "Toms River",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 39.95,
#       "Longitude": -74.18,
#       "estimated_population": 640,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "Kr3wVgt15R",
#       "US_Zip_Code": 8755,
#       "Type": "STANDARD",
#       "Primary_city": "Toms River",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732848908,
#       "Latitude": 39.95,
#       "Longitude": -74.18,
#       "estimated_population": 21432,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "Uh0HfLQ5ur",
#       "US_Zip_Code": 8756,
#       "Type": "PO BOX",
#       "Primary_city": "Toms River",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 39.95,
#       "Longitude": -74.18,
#       "estimated_population": 0,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "4vnZoZsC3j",
#       "US_Zip_Code": 8757,
#       "Type": "STANDARD",
#       "Primary_city": "Toms River",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732848908,
#       "Latitude": 39.95,
#       "Longitude": -74.18,
#       "estimated_population": 26967,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "FXx7NVKo0d",
#       "US_Zip_Code": 8758,
#       "Type": "STANDARD",
#       "Primary_city": "Waretown",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 609,
#       "Latitude": 39.78,
#       "Longitude": -74.19,
#       "estimated_population": 6336,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "bbYwcCiHSb",
#       "US_Zip_Code": 8759,
#       "Type": "STANDARD",
#       "Primary_city": "Manchester Township",
#       "Acceptable_cities": "Lakehurst, Manchester, Manchester Tw, Whiting",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 39.93,
#       "Longitude": -74.39,
#       "estimated_population": 27892,
#       "createdAt": "2020-02-11T17:24:50.793Z",
#       "updatedAt": "2020-02-11T17:24:50.793Z"
#     }
#   ],
#   "count": 32
# }

# %%
df_cities = pd.json_normalize(data_cities['results'])
city_names = list(df_cities['Primary_city'].unique())
city_names
# Out:
# ['Barnegat',
#  'Barnegat Light',
#  'Beach Haven',
#  'Manahawkin',
#  'Tuckerton',
#  'West Creek',
#  'Jackson',
#  'New Egypt',
#  'Lakewood',
#  'Bayville',
#  'Beachwood',
#  'Brick',
#  'Forked River',
#  'Island Heights',
#  'Lakehurst',
#  'Lanoka Harbor',
#  'Lavallette',
#  'Mantoloking',
#  'Normandy Beach',
#  'Ocean Gate',
#  'Pine Beach',
#  'Point Pleasant Beach',
#  'Seaside Heights',
#  'Seaside Park',
#  'Toms River',
#  'Waretown',
#  'Manchester Township']

# %%
api_key = Realtor_API_KEY_2

features = ['single_story', 'two_or_more_stories', 'garage_1_or_more', 'garage_2_or_more', 'basement']

# %%
def getHome(api_key, cities, state, features):
    table = []
    url = "https://realtor.p.rapidapi.com/properties/v2/list-for-sale"
    
    for city in cities:
        for feature in features:
            querystring = {"city":city,
                           "limit":"200",
                           "offset":"0",
                           "beds_min":"1",
                           "baths_min":"1",
                           "sqft_min":"1",
                           "state_code":state,
                           "features":feature
                          }

            headers = {
                'x-rapidapi-key': api_key,
                'x-rapidapi-host': "realtor.p.rapidapi.com"
                }
            try:
        
                response = requests.request("GET", url, headers = headers, params = querystring)

                print(city, feature, len(response.json()['properties']))

                if len(response.json()['properties']) > 0:
                    for item in response.json()['properties']:
                        item['city'] = item['address']['city']
                        item['line'] = item['address']['line']
                        item['zipcode'] = item['address']['postal_code']
                        item['state'] = item['address']['state_code']
                        item['longitude'] = item['address']['lon']
                        item['latitude'] = item['address']['lat']
                        item['size(sqft)'] = item['building_size']['size']
                        item['features'] = feature
                        data = pd.DataFrame.from_dict(item, orient = 'index').T
                        row = data[['property_id', 'price', 'beds', 'baths', 'size(sqft)',
                                    'line', 'city', 'state', 'zipcode', 
                                    'longitude', 'latitude', 'features', 'last_update']]

                        table.append(row)
            except len(response.json()['properties']) == 0:
                continue

    table = pd.concat(table, axis = 0, ignore_index = True, sort = False)
    
    table['price'] = table['price'].astype(int)
    table['price'].describe().apply(lambda x: format(x, 'f'))
    table['size(sqft)'] = table['size(sqft)'].astype(int)
    table['size(sqft)'].describe().apply(lambda x: format(x, 'f'))
    table['longitude'] = table['longitude'].astype(float)
    table['latitude'] = table['latitude'].astype(float)
    table['beds'] = table['beds'].astype(int)
    table['baths'] = table['baths'].astype(int)
    table['last_update'] = pd.to_datetime(table['last_update'], format='%Y-%m-%dT%H:%M:%SZ', errors='coerce')
    table['zipcode'] = table['zipcode'].astype('category')
    table['features'] = table['features'].astype('category')
        
    return table

# %%
df_home = getHome(api_key, city_names, 'NJ', features)
df_home
# Out:
#       property_id   price  beds  baths  size(sqft)                line  \
# 0     M6251759680  495000     4      3        3383      187 Emerson Ln
# 1     M6140700387  189000     2      2        1174     3 Tall Hedge Ct
# 2     M5705044185  339000     2      2        2059      40 Lakeland Dr
# 3     M6200124677  310000     2      2        1860      33 Westport Dr
# 4     M6319666484  235000     3      1        1112          117 7th St
# ...           ...     ...   ...    ...         ...                 ...
# 5486  M5350598726  299900     3      2        1682  840 Englemere Blvd
# 5487  M5294372276  369000     2      3        2324       4 Campania Ct
# 5488  M6100873763  290000     3      2        1404        1909 1st Ave
# 5489  M5975617856  199900     1      1         864  2001 Manchester St
# 5490  M9971883576  409900     4      3        2730   933 Amsterdam Ave
#
#             city state zipcode  longitude   latitude         last_update  \
# 0       Barnegat    NJ   08005 -74.223409  39.764946 2021-03-18 00:05:52
# 1       Barnegat    NJ   08005 -74.271988  39.769174 2021-03-18 15:57:18
# 2       Barnegat    NJ   08005 -74.264284  39.771079 2021-03-16 18:00:00
# 3       Barnegat    NJ   08005 -74.274185  39.762913 2021-03-18 10:25:29
# 4       Barnegat    NJ   08005 -74.203929  39.770314 2021-03-13 07:42:37
# ...          ...   ...     ...        ...        ...                 ...
# 5486  Toms River    NJ   08757 -74.268109  40.006305 2021-03-05 12:43:08
# 5487  Manchester    NJ   08759 -74.259830  40.045829 2021-01-23 12:05:42
# 5488  Toms River    NJ   08757 -74.243452  39.997435 2021-01-19 11:18:09
# 5489  Toms River    NJ   08757 -74.274287  40.006442 2021-01-29 11:18:35
# 5490  Toms River    NJ   08757 -74.266151  40.006371 2021-02-02 12:41:34
#
#           features
# 0     single_story
# 1     single_story
# 2     single_story
# 3     single_story
# 4     single_story
# ...            ...
# 5486      basement
# 5487      basement
# 5488      basement
# 5489      basement
# 5490      basement
#
# [5491 rows x 13 columns]

# %%
# df_home.to_csv('./Data_Source/home.csv', index = False)

# %%
df_home.info()
df_home.describe().apply(lambda s: s.apply('{0:.2f}'.format))

# %% [markdown]
# ## Clean Data

# %%
pre_home = pd.read_csv('./Data_Source/home.csv').drop_duplicates().reset_index(drop = True)
pre_home['last_update'] = pd.to_datetime(pre_home['last_update'])
pre_home['days_ago'] = (np.datetime64(dt.date.today()) - 
                        pre_home[['last_update']].values.astype('datetime64[D]')).astype(int)
pre_home
# Out:
#       property_id   price  beds  baths  size(sqft)                   line  \
# 0     M6251759680  495000     4      3        3383         187 Emerson Ln
# 1     M6140700387  189000     2      2        1174        3 Tall Hedge Ct
# 2     M5705044185  339000     2      2        2059         40 Lakeland Dr
# 3     M6200124677  310000     2      2        1860         33 Westport Dr
# 4     M6319666484  235000     3      1        1112             117 7th St
# ...           ...     ...   ...    ...         ...                    ...
# 5333  M5462419635  459000     5      4        2612  320 Commonwealth Blvd
# 5334  M6157159858  289900     3      2        1568       2573 Woodland Rd
# 5335  M6657962521  484900     4      3        2114      1781 New York Ave
# 5336  M5565388063  450000     4      3        2283      1661 Delaware Ave
# 5337  M5294372276  369000     2      3        2324          4 Campania Ct
#
#                      city state  zipcode  longitude   latitude      features  \
# 0                Barnegat    NJ     8005 -74.223409  39.764946  single_story
# 1                Barnegat    NJ     8005 -74.271988  39.769174  single_story
# 2                Barnegat    NJ     8005 -74.264284  39.771079  single_story
# 3                Barnegat    NJ     8005 -74.274185  39.762913  single_story
# 4                Barnegat    NJ     8005 -74.203929  39.770314  single_story
# ...                   ...   ...      ...        ...        ...           ...
# 5333           Manchester    NJ     8759 -74.277036  39.998821      basement
# 5334           Manchester    NJ     8759 -74.255452  40.034131      basement
# 5335  Manchester Township    NJ     8759 -74.379836  39.928933      basement
# 5336           Manchester    NJ     8759 -74.381291  39.923657      basement
# 5337           Manchester    NJ     8759 -74.259830  40.045829      basement
#
#              last_update  days_ago
# 0    2021-03-18 00:05:52         8
# 1    2021-03-18 15:57:18         8
# 2    2021-03-16 18:00:00        10
# 3    2021-03-18 10:25:29         8
# 4    2021-03-13 07:42:37        13
# ...                  ...       ...
# 5333 2021-03-16 07:40:18        10
# 5334 2021-03-12 11:05:30        14
# 5335 2021-03-05 16:51:31        21
# 5336 2021-02-16 08:22:31        38
# 5337 2021-01-23 12:05:42        62
#
# [5338 rows x 14 columns]

# %%
cols = pre_home.columns[5:7].tolist() + ['features']
Home_1 = pre_home.groupby(cols).agg({'days_ago':min, 'price':min}).reset_index()
Home_1
# Out:
#                    line          city             features  days_ago   price
# 0           0-A Bee Way  Forked River     garage_1_or_more        37  459900
# 1           0-A Bee Way  Forked River     garage_2_or_more        37  459900
# 2           0-A Bee Way  Forked River  two_or_more_stories        37  459900
# 3     1 24th Ave Apt B2  Seaside Park         single_story        41  454500
# 4     1 24th Ave Unit C  Seaside Park         single_story        49  575000
# ...                 ...           ...                  ...       ...     ...
# 5262  Court B Unit 1201         Brick     garage_1_or_more        53  209999
# 5263  Court B Unit 1201         Brick         single_story        53  209999
# 5264           Motor Rd    Pine Beach             basement       217  550000
# 5265           Motor Rd    Pine Beach     garage_1_or_more       217  550000
# 5266           Motor Rd    Pine Beach  two_or_more_stories       217  550000
#
# [5267 rows x 5 columns]

# %%
Home_1[Home_1.duplicated(cols)]
# Out:
# Empty DataFrame
# Columns: [line, city, features, days_ago, price]
# Index: []

# %%
Home_2 = Home_1.groupby(['line', 'city'])['features'].agg(lambda column: ", ".join(column)).reset_index(name = "features")
Home_2
# Out:
#                               line          city  \
# 0                      0-A Bee Way  Forked River
# 1                1 24th Ave Apt B2  Seaside Park
# 2                1 24th Ave Unit C  Seaside Park
# 3                         1 4th St    Manahawkin
# 4                      1 Azalea Ct      Barnegat
# ...                            ...           ...
# 2229        A Chatham Ct Unit 1001      Lakewood
# 2230  B Molly Pitcher Blvd Unit 11       Whiting
# 2231                       Bee Way  Forked River
# 2232             Court B Unit 1201         Brick
# 2233                      Motor Rd    Pine Beach
#
#                                                features
# 0     garage_1_or_more, garage_2_or_more, two_or_mor...
# 1                                          single_story
# 2                                          single_story
# 3                 garage_1_or_more, two_or_more_stories
# 4     basement, garage_1_or_more, garage_2_or_more, ...
# ...                                                 ...
# 2229                     garage_1_or_more, single_story
# 2230                                       single_story
# 2231              garage_1_or_more, two_or_more_stories
# 2232           basement, garage_1_or_more, single_story
# 2233    basement, garage_1_or_more, two_or_more_stories
#
# [2234 rows x 3 columns]

# %%
cols = Home_1.columns[:2].tolist() + Home_1.columns[-2:].tolist()
Home = Home_1[cols].merge(Home_2).sort_values('price').drop_duplicates(subset = Home_2.columns[:2].tolist(),
                                                                       keep = 'first').reset_index(drop = True)
Home
# Out:
#                               line                  city  days_ago    price  \
# 0                    525 Main C St             Tuckerton        25    18500
# 1           469 S Green St Trlr 27             Tuckerton        78    29900
# 2                19D Monticello Dr               Whiting        12    35000
# 3         10G Bennington Ln Unit G               Whiting        25    38500
# 4     B Molly Pitcher Blvd Unit 11               Whiting         9    39000
# ...                            ...                   ...       ...      ...
# 2229                 14 Cummins St           Mantoloking        25  4500000
# 2230              1324 Ocean Front  Point Pleasant Beach        19  5700000
# 2231              91 Pershing Blvd            Lavallette       139  6500000
# 2232                1211 Ocean Ave           Mantoloking        84  9250000
# 2233                1417 Ocean Ave           Mantoloking        65  9950000
#
#                                                features
# 0                                          single_story
# 1                                          single_story
# 2                                          single_story
# 3                                          single_story
# 4                                          single_story
# ...                                                 ...
# 2229  garage_1_or_more, garage_2_or_more, two_or_mor...
# 2230  basement, garage_1_or_more, garage_2_or_more, ...
# 2231  garage_1_or_more, garage_2_or_more, two_or_mor...
# 2232  basement, garage_1_or_more, garage_2_or_more, ...
# 2233  basement, garage_1_or_more, garage_2_or_more, ...
#
# [2234 rows x 5 columns]

# %%
home_ult = pre_home.iloc[:,:-3].merge(Home, how = 'right').drop_duplicates(subset = Home.columns[:2].tolist(),
                                                                           keep = 'first').reset_index(drop = True)
home_ult
# Out:
#       property_id    price  beds  baths  size(sqft)  \
# 0     M6602530331    18500     2      2        1000
# 1     M9930412229    29900     2      2         784
# 2     M9471690149    35000     1      1         782
# 3     M5847512768    38500     1      1         537
# 4     M9269193256    39000     2      1         850
# ...           ...      ...   ...    ...         ...
# 2229  M9886104467  4500000     6      5        4430
# 2230  M9479483724  5700000     7      8        4480
# 2231  M5334622826  6500000     8      8        7219
# 2232  M5495064600  9250000     7      8        7700
# 2233  M6731800872  9950000     8      9        7200
#
#                               line                  city state  zipcode  \
# 0                    525 Main C St             Tuckerton    NJ     8087
# 1           469 S Green St Trlr 27             Tuckerton    NJ     8087
# 2                19D Monticello Dr               Whiting    NJ     8759
# 3         10G Bennington Ln Unit G               Whiting    NJ     8759
# 4     B Molly Pitcher Blvd Unit 11               Whiting    NJ     8759
# ...                            ...                   ...   ...      ...
# 2229                 14 Cummins St           Mantoloking    NJ     8738
# 2230              1324 Ocean Front  Point Pleasant Beach    NJ     8742
# 2231              91 Pershing Blvd            Lavallette    NJ     8735
# 2232                1211 Ocean Ave           Mantoloking    NJ     8738
# 2233                1417 Ocean Ave           Mantoloking    NJ     8738
#
#       longitude   latitude  days_ago  \
# 0    -74.322433  39.615565        25
# 1    -74.338429  39.590329        78
# 2    -74.369100  39.956901        12
# 3    -74.369306  39.959331        25
# 4    -74.375238  39.960069         9
# ...         ...        ...       ...
# 2229 -74.057772  40.006954        25
# 2230 -74.039428  40.083495        19
# 2231 -74.083205  39.965606       139
# 2232 -74.049089  40.038775        84
# 2233 -74.050874  40.032632        65
#
#                                                features
# 0                                          single_story
# 1                                          single_story
# 2                                          single_story
# 3                                          single_story
# 4                                          single_story
# ...                                                 ...
# 2229  garage_1_or_more, garage_2_or_more, two_or_mor...
# 2230  basement, garage_1_or_more, garage_2_or_more, ...
# 2231  garage_1_or_more, garage_2_or_more, two_or_mor...
# 2232  basement, garage_1_or_more, garage_2_or_more, ...
# 2233  basement, garage_1_or_more, garage_2_or_more, ...
#
# [2234 rows x 13 columns]

# %%
pre_home[['line']][~pre_home['line'].isin(list(home_ult['line']))]
# Out:
#      line
# 1147  NaN
# 1156  NaN
# 1167  NaN
# 1174  NaN
# 1182  NaN
# 1826  NaN
# 2516  NaN
# 3897  NaN
# 3917  NaN
# 3927  NaN
# 4262  NaN
# 4615  NaN
# 4697  NaN
# 4702  NaN
# 4703  NaN
# 4704  NaN
# 4881  NaN
# 4884  NaN
# 4885  NaN
# 4886  NaN

# %%
home_ult[home_ult.duplicated(['line'])]
# Out:
# Empty DataFrame
# Columns: [property_id, price, beds, baths, size(sqft), line, city, state, zipcode, longitude, latitude, days_ago, features]
# Index: []

# %%
# home_ult.to_csv('./Data_Source/home_ult.csv', index = False)
