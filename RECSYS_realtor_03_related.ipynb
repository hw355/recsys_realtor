# %% [markdown]
# # Important features to Home

# %%
import json
import requests
import urllib
import pandas as pd
from fuzzywuzzy import process, fuzz

import os, sys, inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir)

from ipynb.fs.full.Credentials import *

# %%
DS_dir = currentdir + '/Data_Source'

try:
    os.mkdir(DS_dir, mode = 0o666)

except FileExistsError:
    
    pass

# %% [markdown]
# ## School

# %%
url_school = 'https://services1.arcgis.com/' + HIFLD_key + '/arcgis/rest/services/Public_Schools/FeatureServer/0/query?where=STATE%20%3D%20%27NJ%27%20AND%20COUNTY%20%3D%20%27OCEAN%27&outFields=OBJECTID,NAME,ADDRESS,CITY,STATE,ZIP,COUNTY,LEVEL_,LATITUDE,LONGITUDE&outSR=4326&f=json'
data_school = json.loads(requests.get(url_school).content.decode('utf-8'))
print(json.dumps(data_school, indent = 2))
# Out:
# {
#   "objectIdFieldName": "OBJECTID",
#   "uniqueIdField": {
#     "name": "OBJECTID",
#     "isSystemMaintained": true
#   },
#   "globalIdFieldName": "",
#   "geometryType": "esriGeometryPoint",
#   "spatialReference": {
#     "wkid": 4326,
#     "latestWkid": 4326
#   },
#   "fields": [
#     {
#       "name": "OBJECTID",
#       "type": "esriFieldTypeOID",
#       "alias": "OBJECTID",
#       "sqlType": "sqlTypeOther",
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "NAME",
#       "type": "esriFieldTypeString",
#       "alias": "NAME",
#       "sqlType": "sqlTypeOther",
#       "length": 150,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "ADDRESS",
#       "type": "esriFieldTypeString",
#       "alias": "ADDRESS",
#       "sqlType": "sqlTypeOther",
#       "length": 150,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "CITY",
#       "type": "esriFieldTypeString",
#       "alias": "CITY",
#       "sqlType": "sqlTypeOther",
#       "length": 50,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "STATE",
#       "type": "esriFieldTypeString",
#       "alias": "STATE",
#       "sqlType": "sqlTypeOther",
#       "length": 50,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "ZIP",
#       "type": "esriFieldTypeString",
#       "alias": "ZIP",
#       "sqlType": "sqlTypeOther",
#       "length": 15,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "COUNTY",
#       "type": "esriFieldTypeString",
#       "alias": "COUNTY",
#       "sqlType": "sqlTypeOther",
#       "length": 50,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "LEVEL_",
#       "type": "esriFieldTypeString",
#       "alias": "LEVEL",
#       "sqlType": "sqlTypeOther",
#       "length": 15,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "LATITUDE",
#       "type": "esriFieldTypeDouble",
#       "alias": "LATITUDE",
#       "sqlType": "sqlTypeOther",
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "LONGITUDE",
#       "type": "esriFieldTypeDouble",
#       "alias": "LONGITUDE",
#       "sqlType": "sqlTypeOther",
#       "domain": null,
#       "defaultValue": null
#     }
#   ],
#   "features": [
#     {
#       "attributes": {
#         "OBJECTID": 264,
#         "NAME": "FREDERIC A. PRIFF ELEMENTARY SCHOOL",
#         "ADDRESS": "139 WELLS MILL ROAD",
#         "CITY": "WARETOWN",
#         "STATE": "NJ",
#         "ZIP": "08758",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "MIDDLE",
#         "LATITUDE": 39.7906138330001,
#         "LONGITUDE": -74.2019661269999
#       },
#       "geometry": {
#         "x": -74.20196612699993,
#         "y": 39.79061383300006
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 2741,
#         "NAME": "CENTRAL REGIONAL MIDDLE SCHOOL",
#         "ADDRESS": "509 FOREST HILLS PARKWAY",
#         "CITY": "BAYVILLE",
#         "STATE": "NJ",
#         "ZIP": "08721",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "MIDDLE",
#         "LATITUDE": 39.88936993,
#         "LONGITUDE": -74.210435757
#       },
#       "geometry": {
#         "x": -74.21043575699997,
#         "y": 39.889369930000036
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 2822,
#         "NAME": "PINELANDS REGIONAL JUNIOR HIGH SCHOOL",
#         "ADDRESS": "590 NUGENTOWN ROAD",
#         "CITY": "LITTLE EGG HARBOR",
#         "STATE": "NJ",
#         "ZIP": "08087",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "MIDDLE",
#         "LATITUDE": 39.614155318,
#         "LONGITUDE": -74.3604522429999
#       },
#       "geometry": {
#         "x": -74.36045224299994,
#         "y": 39.614155318000044
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 3630,
#         "NAME": "MIDSTREAMS ELEMENTARY SCHOOL",
#         "ADDRESS": "500 MIDSTREAMS RD",
#         "CITY": "BRICK TOWN",
#         "STATE": "NJ",
#         "ZIP": "08724",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.06813371,
#         "LONGITUDE": -74.1000713559999
#       },
#       "geometry": {
#         "x": -74.10007135599994,
#         "y": 40.068133710000026
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5809,
#         "NAME": "OCEAN ACADEMY CHARTER SCHOOL",
#         "ADDRESS": "678 5TH ST",
#         "CITY": "LAKEWOOD",
#         "STATE": "NJ",
#         "ZIP": "08701",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.0937542670001,
#         "LONGITUDE": -74.2235893069999
#       },
#       "geometry": {
#         "x": -74.22358930699994,
#         "y": 40.09375426700006
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 6170,
#         "NAME": "OCEAN TRANS ED CENTER",
#         "ADDRESS": "1141 OLD FREEHOLD RD",
#         "CITY": "TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08743",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "NOT REPORTED",
#         "LATITUDE": 39.976112626,
#         "LONGITUDE": -74.1973838439999
#       },
#       "geometry": {
#         "x": -74.19738384399994,
#         "y": 39.976112626000024
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 8444,
#         "NAME": "LANES MILL ELEMENTARY SCHOOL",
#         "ADDRESS": "1891 LANES MILL RD",
#         "CITY": "BRICK",
#         "STATE": "NJ",
#         "ZIP": "08724",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.1015178110001,
#         "LONGITUDE": -74.134005313
#       },
#       "geometry": {
#         "x": -74.13400531299999,
#         "y": 40.10151781100006
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 10818,
#         "NAME": "OCEAN COUNTY VOCATIONAL TECHNICAL SCHOOL TOMS RIVER CENTER",
#         "ADDRESS": "1299 OLD FREEHOLD ROAD",
#         "CITY": "TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08753",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 39.9826465510001,
#         "LONGITUDE": -74.195588481
#       },
#       "geometry": {
#         "x": -74.19558848099996,
#         "y": 39.982646551000066
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 11566,
#         "NAME": "STAFFORD INTERMEDIATE SCHOOL",
#         "ADDRESS": "1000 MCKINLEY AVENUE",
#         "CITY": "MANAHAWKIN",
#         "STATE": "NJ",
#         "ZIP": "08050",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "MIDDLE",
#         "LATITUDE": 39.70272414,
#         "LONGITUDE": -74.283426105
#       },
#       "geometry": {
#         "x": -74.28342610499999,
#         "y": 39.70272414000004
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 14351,
#         "NAME": "OCEAN COUNTY VOCATIONAL TECHNICAL SCHOOL JACKSON CENTER",
#         "ADDRESS": "850 TOMS RIVER ROAD",
#         "CITY": "JACKSON",
#         "STATE": "NJ",
#         "ZIP": "08527",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 40.0586444420001,
#         "LONGITUDE": -74.354882604
#       },
#       "geometry": {
#         "x": -74.35488260399995,
#         "y": 40.05864444200005
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 17683,
#         "NAME": "OCEAN COUNTY VOCATIONAL TECHNICAL SCHOOL LAKEHURST CENTER",
#         "ADDRESS": "HANGAR ONE",
#         "CITY": "LAKEHURST",
#         "STATE": "NJ",
#         "ZIP": "08733",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "NOT REPORTED",
#         "LATITUDE": 40.0298280000001,
#         "LONGITUDE": -74.314706214
#       },
#       "geometry": {
#         "x": -74.31470621399995,
#         "y": 40.02982800000006
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 18105,
#         "NAME": "SOUTHERN REGIONAL HIGH SCHOOL",
#         "ADDRESS": "90 CEDAR BRIDGE ROAD",
#         "CITY": "MANAHAWKIN",
#         "STATE": "NJ",
#         "ZIP": "08050",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 39.7120474480001,
#         "LONGITUDE": -74.254013577
#       },
#       "geometry": {
#         "x": -74.25401357699997,
#         "y": 39.71204744800007
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 19939,
#         "NAME": "FORKED RIVER ELEMENTARY SCHOOL",
#         "ADDRESS": "110 LACEY ROAD",
#         "CITY": "FORKED RIVER",
#         "STATE": "NJ",
#         "ZIP": "08731",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.8422799260001,
#         "LONGITUDE": -74.1921724219999
#       },
#       "geometry": {
#         "x": -74.19217242199994,
#         "y": 39.84227992600006
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 20653,
#         "NAME": "CLARA B. WORTH ELEMENTARY SCHOOL",
#         "ADDRESS": "57 CENTRAL PARKWAY",
#         "CITY": "BAYVILLE",
#         "STATE": "NJ",
#         "ZIP": "08721",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.8899747680001,
#         "LONGITUDE": -74.164218179
#       },
#       "geometry": {
#         "x": -74.16421817899999,
#         "y": 39.88997476800006
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 20764,
#         "NAME": "OCEAN REGIONAL SCHOOL",
#         "ADDRESS": "1141 OLD FREEHOLD RD",
#         "CITY": "TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08753",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "OTHER",
#         "LATITUDE": 39.976217417,
#         "LONGITUDE": -74.197325539
#       },
#       "geometry": {
#         "x": -74.19732553899996,
#         "y": 39.97621741700004
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 21405,
#         "NAME": "OCEAN COUNTY VOCATIONAL TECHNICAL SCHOOL BRICK CENTER",
#         "ADDRESS": "350 CHAMBERS BRIDGE ROAD",
#         "CITY": "BRICK",
#         "STATE": "NJ",
#         "ZIP": "08723",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 40.0754592420001,
#         "LONGITUDE": -74.15239738
#       },
#       "geometry": {
#         "x": -74.15239737999997,
#         "y": 40.075459242000086
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 22227,
#         "NAME": "PERFORMING ARTS ACADEMY OF THE OCEAN COUNTY VOCATIONAL TECH",
#         "ADDRESS": "JOINT BASE MCGUIRE-DIX-LAKEHURST",
#         "CITY": "LAKEHURST",
#         "STATE": "NJ",
#         "ZIP": "08733",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 40.0287420490001,
#         "LONGITUDE": -74.316113359
#       },
#       "geometry": {
#         "x": -74.31611335899998,
#         "y": 40.02874204900007
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 23878,
#         "NAME": "POINT PLEASANT BEACH HIGH SCHOOL",
#         "ADDRESS": "700 TRENTON AVENUE",
#         "CITY": "POINT PLEASANT BEACH",
#         "STATE": "NJ",
#         "ZIP": "08742",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 40.089083691,
#         "LONGITUDE": -74.052665758
#       },
#       "geometry": {
#         "x": -74.05266575799999,
#         "y": 40.08908369100003
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 24003,
#         "NAME": "VETERANS MEMORIAL MIDDLE SCHOOL",
#         "ADDRESS": "105 HENDRICKSON AVENUE",
#         "CITY": "BRICK TOWN",
#         "STATE": "NJ",
#         "ZIP": "08724",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "MIDDLE",
#         "LATITUDE": 40.083267806,
#         "LONGITUDE": -74.1183487229999
#       },
#       "geometry": {
#         "x": -74.11834872299994,
#         "y": 40.08326780600003
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 25158,
#         "NAME": "SOUTH TOMS RIVER ELEMENTARY SCHOOL",
#         "ADDRESS": "419 DOVER ROAD",
#         "CITY": "SOUTH TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08757",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.940520318,
#         "LONGITUDE": -74.211638202
#       },
#       "geometry": {
#         "x": -74.21163820199996,
#         "y": 39.94052031800003
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 25363,
#         "NAME": "ETHEL A. JACOBSEN ELEMENTARY SCHOOL",
#         "ADDRESS": "200 S. BARNEGAT AVENUE",
#         "CITY": "SURF CITY",
#         "STATE": "NJ",
#         "ZIP": "08008",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.654967986,
#         "LONGITUDE": -74.1766086169999
#       },
#       "geometry": {
#         "x": -74.17660861699994,
#         "y": 39.65496798600003
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 26436,
#         "NAME": "JOSEPH T. DONAHUE ELEMENTARY SCHOOL",
#         "ADDRESS": "200 BENGAL BLVD",
#         "CITY": "BARNEGAT",
#         "STATE": "NJ",
#         "ZIP": "08005",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.771749877,
#         "LONGITUDE": -74.233151614
#       },
#       "geometry": {
#         "x": -74.23315161399995,
#         "y": 39.77174987700004
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 29552,
#         "NAME": "JOSEPH A. CITTA ELEMENTARY SCHOOL",
#         "ADDRESS": "2050 LAKEWOOD ROAD",
#         "CITY": "TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08755",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.0275669640001,
#         "LONGITUDE": -74.2254515069999
#       },
#       "geometry": {
#         "x": -74.22545150699995,
#         "y": 40.02756696400007
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 29640,
#         "NAME": "LAKEWOOD MIDDLE SCHOOL",
#         "ADDRESS": "755 SOMERSET AVENUE",
#         "CITY": "LAKEWOOD",
#         "STATE": "NJ",
#         "ZIP": "08701",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "MIDDLE",
#         "LATITUDE": 40.0967973910001,
#         "LONGITUDE": -74.193414167
#       },
#       "geometry": {
#         "x": -74.19341416699996,
#         "y": 40.096797391000045
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 30165,
#         "NAME": "LACEY TOWNSHIP MIDDLE SCHOOL",
#         "ADDRESS": "660 DENTON AVENUE",
#         "CITY": "FORKED RIVER",
#         "STATE": "NJ",
#         "ZIP": "08731",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "MIDDLE",
#         "LATITUDE": 39.8579937230001,
#         "LONGITUDE": -74.198853124
#       },
#       "geometry": {
#         "x": -74.19885312399998,
#         "y": 39.85799372300005
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 30166,
#         "NAME": "JACKSON LIBERTY HIGH SCHOOL",
#         "ADDRESS": "125 NORTH HOPE CHAPEL ROAD",
#         "CITY": "JACKSON",
#         "STATE": "NJ",
#         "ZIP": "08527",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 40.0911426550001,
#         "LONGITUDE": -74.262324196
#       },
#       "geometry": {
#         "x": -74.26232419599995,
#         "y": 40.09114265500005
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 30373,
#         "NAME": "MANCHESTER TOWNSHIP ELEMENTARY SCHOOL",
#         "ADDRESS": "101 N COLONIAL DRIVE",
#         "CITY": "MANCHESTER",
#         "STATE": "NJ",
#         "ZIP": "08733",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.016988719,
#         "LONGITUDE": -74.299059257
#       },
#       "geometry": {
#         "x": -74.29905925699995,
#         "y": 40.01698871900003
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 30374,
#         "NAME": "RUSSELL O. BRACKMAN MIDDLE SCHOOL",
#         "ADDRESS": "600 BARNEGAT BLVD NORTH",
#         "CITY": "BARNEGAT",
#         "STATE": "NJ",
#         "ZIP": "08005",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "MIDDLE",
#         "LATITUDE": 39.758769081,
#         "LONGITUDE": -74.236290017
#       },
#       "geometry": {
#         "x": -74.23629001699999,
#         "y": 39.75876908100003
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 31038,
#         "NAME": "CECIL S COLLINS ELEMENTARY",
#         "ADDRESS": "570 BARNEGAT BLVD NORTH",
#         "CITY": "BARNEGAT",
#         "STATE": "NJ",
#         "ZIP": "08005",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.759411508,
#         "LONGITUDE": -74.238955833
#       },
#       "geometry": {
#         "x": -74.23895583299998,
#         "y": 39.75941150800003
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 31504,
#         "NAME": "OXYCOCUS ELEMENTARY SCHOOL",
#         "ADDRESS": "250 NORTH MAIN STREET",
#         "CITY": "MANAHAWKIN",
#         "STATE": "NJ",
#         "ZIP": "08050",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "PREKINDERGARTEN",
#         "LATITUDE": 39.7022705700001,
#         "LONGITUDE": -74.2564606019999
#       },
#       "geometry": {
#         "x": -74.25646060199995,
#         "y": 39.70227057000005
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 32178,
#         "NAME": "EAGLESWOOD ELEMENTARY SCHOOL",
#         "ADDRESS": "511 ROUTE 9",
#         "CITY": "WEST CREEK",
#         "STATE": "NJ",
#         "ZIP": "08092",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.6571335290001,
#         "LONGITUDE": -74.290876898
#       },
#       "geometry": {
#         "x": -74.29087689799996,
#         "y": 39.65713352900006
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 32179,
#         "NAME": "WARREN H. WOLF ELEMENTARY SCHOOL",
#         "ADDRESS": "224 260 CHAMBERS BRIDGE RD",
#         "CITY": "BRICK",
#         "STATE": "NJ",
#         "ZIP": "08723",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.0684782180001,
#         "LONGITUDE": -74.148812101
#       },
#       "geometry": {
#         "x": -74.14881210099998,
#         "y": 40.06847821800005
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 32394,
#         "NAME": "CEDAR CREEK ELEMENTARY SCHOOL",
#         "ADDRESS": "220 WESTERN BLVD",
#         "CITY": "LANOKA HARBOR",
#         "STATE": "NJ",
#         "ZIP": "08734",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.8691933810001,
#         "LONGITUDE": -74.1977175329999
#       },
#       "geometry": {
#         "x": -74.19771753299995,
#         "y": 39.86919338100006
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 32936,
#         "NAME": "HERBERTSVILLE ELEMENTARY SCHOOL",
#         "ADDRESS": "2282 LANES MILL RD",
#         "CITY": "BRICK",
#         "STATE": "NJ",
#         "ZIP": "08724",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.111859646,
#         "LONGITUDE": -74.112204785
#       },
#       "geometry": {
#         "x": -74.11220478499996,
#         "y": 40.11185964600003
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 33410,
#         "NAME": "PINELANDS REGIONAL HIGH SCHOOL",
#         "ADDRESS": "565 NUGENTOWN ROAD",
#         "CITY": "LITTLE EGG HARBOR",
#         "STATE": "NJ",
#         "ZIP": "08087",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 39.6105154260001,
#         "LONGITUDE": -74.359807518
#       },
#       "geometry": {
#         "x": -74.35980751799997,
#         "y": 39.61051542600007
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 34809,
#         "NAME": "ELMS ELEMENTARY SCHOOL",
#         "ADDRESS": "780 PATTERSON ROAD",
#         "CITY": "JACKSON",
#         "STATE": "NJ",
#         "ZIP": "08527",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.1531920140001,
#         "LONGITUDE": -74.400343262
#       },
#       "geometry": {
#         "x": -74.40034326199998,
#         "y": 40.15319201400007
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 38792,
#         "NAME": "OCEAN RGC",
#         "ADDRESS": "1 GAME FARM ROAD",
#         "CITY": "FORKED RIVER",
#         "STATE": "NJ",
#         "ZIP": "08731",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "SECONDARY",
#         "LATITUDE": 39.840668991,
#         "LONGITUDE": -74.184613075
#       },
#       "geometry": {
#         "x": -74.18461307499996,
#         "y": 39.84066899100003
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 38868,
#         "NAME": "SOUTHERN REGIONAL MIDDLE SCHOOL",
#         "ADDRESS": "75 CEDAR BRIDGE ROAD",
#         "CITY": "MANAHAWKIN",
#         "STATE": "NJ",
#         "ZIP": "08050",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "MIDDLE",
#         "LATITUDE": 39.7082775470001,
#         "LONGITUDE": -74.2566437959999
#       },
#       "geometry": {
#         "x": -74.25664379599993,
#         "y": 39.70827754700008
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 39219,
#         "NAME": "BEACH HAVEN SCHOOL",
#         "ADDRESS": "8TH STREET & BEACH AVENUE",
#         "CITY": "BEACH HAVEN",
#         "STATE": "NJ",
#         "ZIP": "08008",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.5681284730001,
#         "LONGITUDE": -74.237435073
#       },
#       "geometry": {
#         "x": -74.23743507299997,
#         "y": 39.56812847300006
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 43398,
#         "NAME": "MANCHESTER TOWNSHIP MIDDLE SCHOOL",
#         "ADDRESS": "2759 RIDGEWAY RD",
#         "CITY": "MANCHESTER",
#         "STATE": "NJ",
#         "ZIP": "08759",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "MIDDLE",
#         "LATITUDE": 40.018817728,
#         "LONGITUDE": -74.2636563
#       },
#       "geometry": {
#         "x": -74.26365629999998,
#         "y": 40.01881772800003
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 44567,
#         "NAME": "DR. GERALD H. WOEHR ELEMENTARY SCHOOL",
#         "ADDRESS": "44 N MAIN ST",
#         "CITY": "NEW EGYPT",
#         "STATE": "NJ",
#         "ZIP": "08533",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.0711230650001,
#         "LONGITUDE": -74.5270312709999
#       },
#       "geometry": {
#         "x": -74.52703127099994,
#         "y": 40.071123065000045
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 45004,
#         "NAME": "SYLVIA ROSENAUER ELEMENTARY SCHOOL",
#         "ADDRESS": "60 CITADEL DRIVE",
#         "CITY": "JACKSON",
#         "STATE": "NJ",
#         "ZIP": "08527",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.12191498,
#         "LONGITUDE": -74.249904391
#       },
#       "geometry": {
#         "x": -74.24990439099997,
#         "y": 40.121914980000035
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 46065,
#         "NAME": "PINE BEACH ELEMENTARY SCHOOL",
#         "ADDRESS": "101 PENNSYLVANIA AVENUE",
#         "CITY": "PINE BEACH",
#         "STATE": "NJ",
#         "ZIP": "08741",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.93547356,
#         "LONGITUDE": -74.179608796
#       },
#       "geometry": {
#         "x": -74.17960879599997,
#         "y": 39.93547356000005
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 46166,
#         "NAME": "WHITING ELEMENTARY SCHOOL",
#         "ADDRESS": "412 MANCHESTER BLVD",
#         "CITY": "WHITING",
#         "STATE": "NJ",
#         "ZIP": "08759",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.9591333990001,
#         "LONGITUDE": -74.377910157
#       },
#       "geometry": {
#         "x": -74.37791015699997,
#         "y": 39.95913339900005
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 46348,
#         "NAME": "LILLIAN M. DUNFEE ELEMENTARY",
#         "ADDRESS": "128 BARNEGAT BLVD",
#         "CITY": "BARNEGAT",
#         "STATE": "NJ",
#         "ZIP": "08005",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.753602148,
#         "LONGITUDE": -74.221412076
#       },
#       "geometry": {
#         "x": -74.22141207599998,
#         "y": 39.75360214800004
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 47420,
#         "NAME": "OCEAN ROAD ELEMENTARY SCHOOL",
#         "ADDRESS": "BENEDICT STREET",
#         "CITY": "POINT PLEASANT",
#         "STATE": "NJ",
#         "ZIP": "08742",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.0824793580001,
#         "LONGITUDE": -74.06205589
#       },
#       "geometry": {
#         "x": -74.06205588999995,
#         "y": 40.08247935800005
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 47543,
#         "NAME": "HOOPER AVENUE ELEMENTARY SCHOOL",
#         "ADDRESS": "1517 HOOPER AVENUE",
#         "CITY": "TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08753",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.9948036420001,
#         "LONGITUDE": -74.1702220609999
#       },
#       "geometry": {
#         "x": -74.17022206099995,
#         "y": 39.99480364200008
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 47936,
#         "NAME": "ROBERT L. HORBELT ELEMENTARY SCHOOL",
#         "ADDRESS": "104 BURR STREET",
#         "CITY": "BARNEGAT",
#         "STATE": "NJ",
#         "ZIP": "08005",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.7570858180001,
#         "LONGITUDE": -74.233005595
#       },
#       "geometry": {
#         "x": -74.23300559499995,
#         "y": 39.757085818000064
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 48695,
#         "NAME": "OCEAN COUNTY VOCATIONAL TECHNICAL SCHOOL CULINARY CENTER",
#         "ADDRESS": "261 COUNTRY CLUB BLVD.",
#         "CITY": "LITTLE EGG HARBOR",
#         "STATE": "NJ",
#         "ZIP": "08087",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "NOT REPORTED",
#         "LATITUDE": 39.5772036650001,
#         "LONGITUDE": -74.3550638839999
#       },
#       "geometry": {
#         "x": -74.35506388399995,
#         "y": 39.57720366500007
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 49560,
#         "NAME": "HUGH J BOYD JR. ELEMENTARY SCHOOL",
#         "ADDRESS": "1200 BAY BOULEVARD",
#         "CITY": "SEASIDE HTS",
#         "STATE": "NJ",
#         "ZIP": "08751",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.9462730720001,
#         "LONGITUDE": -74.0780211009999
#       },
#       "geometry": {
#         "x": -74.07802110099993,
#         "y": 39.946273072000054
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 50031,
#         "NAME": "H & M POTTER SCHOOL",
#         "ADDRESS": "60 VEEDER LANE",
#         "CITY": "BAYVILLE",
#         "STATE": "NJ",
#         "ZIP": "08721",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.9143539510001,
#         "LONGITUDE": -74.145426675
#       },
#       "geometry": {
#         "x": -74.14542667499995,
#         "y": 39.914353951000066
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 50335,
#         "NAME": "BAYVILLE ELEMENTARY SCHOOL",
#         "ADDRESS": "356 ATLANTIC CITY BLVD",
#         "CITY": "BAYVILLE",
#         "STATE": "NJ",
#         "ZIP": "08721",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.917900854,
#         "LONGITUDE": -74.158728029
#       },
#       "geometry": {
#         "x": -74.15872802899997,
#         "y": 39.917900854000045
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 50376,
#         "NAME": "SWITLIK ELEMENTARY SCHOOL",
#         "ADDRESS": "75 WEST VETERANS HIGHWAY",
#         "CITY": "JACKSON",
#         "STATE": "NJ",
#         "ZIP": "08527",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.1106330470001,
#         "LONGITUDE": -74.3483451929999
#       },
#       "geometry": {
#         "x": -74.34834519299994,
#         "y": 40.11063304700007
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 50509,
#         "NAME": "SILVER BAY ELEMENTARY SCHOOL",
#         "ADDRESS": "100 SILVER BAY ROAD",
#         "CITY": "TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08753",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.0076711630001,
#         "LONGITUDE": -74.139734361
#       },
#       "geometry": {
#         "x": -74.13973436099997,
#         "y": 40.007671163000055
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 50889,
#         "NAME": "MANCHESTER TOWNSHIP HIGH SCHOOL",
#         "ADDRESS": "101 S COLONIAL DR",
#         "CITY": "MANCHESTER",
#         "STATE": "NJ",
#         "ZIP": "08759",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 40.0054046110001,
#         "LONGITUDE": -74.3099344189999
#       },
#       "geometry": {
#         "x": -74.30993441899994,
#         "y": 40.005404611000074
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51816,
#         "NAME": "OAK STREET ELEM SCHOOL",
#         "ADDRESS": "75 OAK STREET",
#         "CITY": "LAKEWOOD",
#         "STATE": "NJ",
#         "ZIP": "08701",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.0678272820001,
#         "LONGITUDE": -74.2128709309999
#       },
#       "geometry": {
#         "x": -74.21287093099994,
#         "y": 40.067827282000046
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51834,
#         "NAME": "MARINE ACADEMY OF TECHNOLOGY AND ENVIRONMENTAL SCIENCE",
#         "ADDRESS": "195 CEDAR BRIDGE ROAD",
#         "CITY": "MANAHAWKIN",
#         "STATE": "NJ",
#         "ZIP": "08050",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 39.7169350890001,
#         "LONGITUDE": -74.254180372
#       },
#       "geometry": {
#         "x": -74.25418037199995,
#         "y": 39.71693508900006
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51925,
#         "NAME": "LAKEWOOD HIGH SCHOOL",
#         "ADDRESS": "855 SOMERSET AVENUE",
#         "CITY": "LAKEWOOD",
#         "STATE": "NJ",
#         "ZIP": "08701",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 40.099896356,
#         "LONGITUDE": -74.19323001
#       },
#       "geometry": {
#         "x": -74.19323000999998,
#         "y": 40.09989635600004
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 52669,
#         "NAME": "BRICK TOWNSHIP HIGH SCHOOL",
#         "ADDRESS": "346 CHAMBERS BRIDGE RD",
#         "CITY": "BRICK TOWN",
#         "STATE": "NJ",
#         "ZIP": "08723",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 40.0732805590001,
#         "LONGITUDE": -74.1531633069999
#       },
#       "geometry": {
#         "x": -74.15316330699994,
#         "y": 40.07328055900007
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 52877,
#         "NAME": "CHRISTA MCAULIFFE MIDDLE SCHOOL",
#         "ADDRESS": "35 SOUTH HOPE CHAPEL ROAD",
#         "CITY": "JACKSON",
#         "STATE": "NJ",
#         "ZIP": "08527",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "MIDDLE",
#         "LATITUDE": 40.0796081010001,
#         "LONGITUDE": -74.264201145
#       },
#       "geometry": {
#         "x": -74.26420114499996,
#         "y": 40.07960810100007
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 53708,
#         "NAME": "ROBERT C. WOOD SR EARLY CHILDHOOD CENTER",
#         "ADDRESS": "950 ROUTE 539",
#         "CITY": "LITTLE EGG HARBOR",
#         "STATE": "NJ",
#         "ZIP": "08087",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "PREKINDERGARTEN",
#         "LATITUDE": 39.619853103,
#         "LONGITUDE": -74.343560283
#       },
#       "geometry": {
#         "x": -74.34356028299999,
#         "y": 39.61985310300001
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 54187,
#         "NAME": "PINER ELEMENTARY SCHOOL",
#         "ADDRESS": "1141 E COUNTY LINE ROAD",
#         "CITY": "LAKEWOOD",
#         "STATE": "NJ",
#         "ZIP": "08701",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.1032731220001,
#         "LONGITUDE": -74.17202631
#       },
#       "geometry": {
#         "x": -74.17202630999998,
#         "y": 40.103273122000076
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 61203,
#         "NAME": "LAKEWOOD EARLY CHILDHOOD CENTER",
#         "ADDRESS": "100 LINDEN AVENUE",
#         "CITY": "LAKEWOOD",
#         "STATE": "NJ",
#         "ZIP": "08701",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "PREKINDERGARTEN",
#         "LATITUDE": 40.094301312,
#         "LONGITUDE": -74.195717819
#       },
#       "geometry": {
#         "x": -74.19571781899998,
#         "y": 40.094301312000034
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 61321,
#         "NAME": "MILL POND ELEMENTARY SCHOOL",
#         "ADDRESS": "210 WESTERN BLVD",
#         "CITY": "LANOKA HARBOR",
#         "STATE": "NJ",
#         "ZIP": "08734",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "MIDDLE",
#         "LATITUDE": 39.868289314,
#         "LONGITUDE": -74.1985981989999
#       },
#       "geometry": {
#         "x": -74.19859819899995,
#         "y": 39.86828931400004
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 62163,
#         "NAME": "FROG POND ELEMENTARY SCHOOL",
#         "ADDRESS": "305 FROG POND ROAD",
#         "CITY": "LITTLE EGG HARBOR",
#         "STATE": "NJ",
#         "ZIP": "08087",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.629356124,
#         "LONGITUDE": -74.327724589
#       },
#       "geometry": {
#         "x": -74.32772458899996,
#         "y": 39.629356124000026
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 63893,
#         "NAME": "CEDAR GROVE ELEMENTARY SCHOOL",
#         "ADDRESS": "179 CEDAR GROVE ROAD",
#         "CITY": "TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08753",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.968659922,
#         "LONGITUDE": -74.169831057
#       },
#       "geometry": {
#         "x": -74.16983105699995,
#         "y": 39.96865992200002
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 63899,
#         "NAME": "LAVALLETTE ELEMENTARY SCHOOL",
#         "ADDRESS": "105 BROOKLYN AVE",
#         "CITY": "LAVALLETTE",
#         "STATE": "NJ",
#         "ZIP": "08735",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.968689086,
#         "LONGITUDE": -74.070415543
#       },
#       "geometry": {
#         "x": -74.07041554299997,
#         "y": 39.96868908600003
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 63932,
#         "NAME": "JACKSON MEMORIAL HIGH SCHOOL",
#         "ADDRESS": "101 DON CONNOR BLVD",
#         "CITY": "JACKSON",
#         "STATE": "NJ",
#         "ZIP": "08527",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 40.1068607180001,
#         "LONGITUDE": -74.3444850659999
#       },
#       "geometry": {
#         "x": -74.34448506599995,
#         "y": 40.10686071800006
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 64250,
#         "NAME": "RONALD L. MEINDERS PRIMARY LEARNING CENTER",
#         "ADDRESS": "1000 MCKINLEY AVENUE",
#         "CITY": "MANAHAWKIN",
#         "STATE": "NJ",
#         "ZIP": "08050",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.70273812,
#         "LONGITUDE": -74.283434768
#       },
#       "geometry": {
#         "x": -74.28343476799995,
#         "y": 39.70273812000004
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 64288,
#         "NAME": "HOWARD C. JOHNSON ELEMENTARY SCHOOL",
#         "ADDRESS": "1021 LARSEN ROAD",
#         "CITY": "JACKSON",
#         "STATE": "NJ",
#         "ZIP": "08527",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.1489375210001,
#         "LONGITUDE": -74.267063191
#       },
#       "geometry": {
#         "x": -74.26706319099998,
#         "y": 40.14893752100004
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 64915,
#         "NAME": "MCKINLEY AVENUE ELEMENTARY SCHOOL",
#         "ADDRESS": "1000 MCKINLEY AVENUE",
#         "CITY": "MANAHAWKIN",
#         "STATE": "NJ",
#         "ZIP": "08050",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.7026888550001,
#         "LONGITUDE": -74.283559462
#       },
#       "geometry": {
#         "x": -74.28355946199997,
#         "y": 39.70268885500007
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 64947,
#         "NAME": "RIDGEWAY ELEMENTARY SCHOOL",
#         "ADDRESS": "2861 RIDGEWAY RD",
#         "CITY": "MANCHESTER",
#         "STATE": "NJ",
#         "ZIP": "08759",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.01985491,
#         "LONGITUDE": -74.265527576
#       },
#       "geometry": {
#         "x": -74.26552757599995,
#         "y": 40.019854910000056
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 66076,
#         "NAME": "LANOKA HARBOR ELEMENTARY SCHOOL",
#         "ADDRESS": "281 MANCHESTER AVE",
#         "CITY": "LANOKA HARBOR",
#         "STATE": "NJ",
#         "ZIP": "08734",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.8670174120001,
#         "LONGITUDE": -74.185030863
#       },
#       "geometry": {
#         "x": -74.18503086299995,
#         "y": 39.867017412000045
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 67115,
#         "NAME": "MANCHESTER REGIONAL DAY SCHOOL",
#         "ADDRESS": "890 TOMS RIVER ROAD",
#         "CITY": "JACKSON",
#         "STATE": "NJ",
#         "ZIP": "08527",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "OTHER",
#         "LATITUDE": 40.0569626860001,
#         "LONGITUDE": -74.3549468109999
#       },
#       "geometry": {
#         "x": -74.35494681099993,
#         "y": 40.05696268600008
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 67244,
#         "NAME": "TOMS RIVER HIGH SCHOOL EAST",
#         "ADDRESS": "1225 RAIDER WAY",
#         "CITY": "TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08753",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 39.9645577840001,
#         "LONGITUDE": -74.1421180579999
#       },
#       "geometry": {
#         "x": -74.14211805799994,
#         "y": 39.96455778400007
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 68553,
#         "NAME": "VETERANS MEMORIAL ELEMENTARY SCHOOL",
#         "ADDRESS": "103 HENDRICKSON AVENUE",
#         "CITY": "BRICK",
#         "STATE": "NJ",
#         "ZIP": "08724",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.08418161,
#         "LONGITUDE": -74.11665472
#       },
#       "geometry": {
#         "x": -74.11665471999999,
#         "y": 40.084181610000016
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 68934,
#         "NAME": "BEACHWOOD ELEMENTARY SCHOOL",
#         "ADDRESS": "901 BERKELEY AVENUE",
#         "CITY": "BEACHWOOD",
#         "STATE": "NJ",
#         "ZIP": "08722",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.923182899,
#         "LONGITUDE": -74.1922133799999
#       },
#       "geometry": {
#         "x": -74.19221337999994,
#         "y": 39.92318289900003
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 71006,
#         "NAME": "CARL W. GOETZ MIDDLE SCHOOL",
#         "ADDRESS": "835 PATTERSON ROAD",
#         "CITY": "JACKSON",
#         "STATE": "NJ",
#         "ZIP": "08527",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "MIDDLE",
#         "LATITUDE": 40.15452515,
#         "LONGITUDE": -74.3913654579999
#       },
#       "geometry": {
#         "x": -74.39136545799994,
#         "y": 40.154525150000026
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 72033,
#         "NAME": "LONG BEACH ISLAND GRADE SCHOOL",
#         "ADDRESS": "201 20TH STREET",
#         "CITY": "SHIP BOTTOM",
#         "STATE": "NJ",
#         "ZIP": "08008",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.6438173340001,
#         "LONGITUDE": -74.183178047
#       },
#       "geometry": {
#         "x": -74.18317804699996,
#         "y": 39.643817334000055
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 73080,
#         "NAME": "OSBORNVILLE ELEMENTARY SCHOOL",
#         "ADDRESS": "218 DRUM POINT RD",
#         "CITY": "BRICK",
#         "STATE": "NJ",
#         "ZIP": "08723",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.044503085,
#         "LONGITUDE": -74.12308123
#       },
#       "geometry": {
#         "x": -74.12308122999997,
#         "y": 40.04450308500003
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 73183,
#         "NAME": "LUCY N. HOLMAN ELEMENTARY SCHOOL",
#         "ADDRESS": "125 MANHATTAN STREET",
#         "CITY": "JACKSON",
#         "STATE": "NJ",
#         "ZIP": "08527",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.1162142950001,
#         "LONGITUDE": -74.286139506
#       },
#       "geometry": {
#         "x": -74.28613950599998,
#         "y": 40.11621429500008
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 73751,
#         "NAME": "TOMS RIVER INTERMEDIATE SCHOOL NORTH",
#         "ADDRESS": "150 INTERMEDIATE NORTH WAY",
#         "CITY": "TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08753",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "MIDDLE",
#         "LATITUDE": 39.992582299,
#         "LONGITUDE": -74.201635978
#       },
#       "geometry": {
#         "x": -74.20163597799996,
#         "y": 39.99258229900005
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 74059,
#         "NAME": "WALNUT STREET ELEMENTARY SCHOOL",
#         "ADDRESS": "60 WALNUT STREET",
#         "CITY": "TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08753",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.969404889,
#         "LONGITUDE": -74.1962965389999
#       },
#       "geometry": {
#         "x": -74.19629653899995,
#         "y": 39.96940488900003
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 74256,
#         "NAME": "G. HAROLD ANTRIM ELEMENTARY SCHOOL",
#         "ADDRESS": "401 NIBLICK STREET",
#         "CITY": "POINT PLEASANT BEACH",
#         "STATE": "NJ",
#         "ZIP": "08742",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.095774238,
#         "LONGITUDE": -74.04648106
#       },
#       "geometry": {
#         "x": -74.04648105999996,
#         "y": 40.09577423800005
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 74789,
#         "NAME": "OCEAN COUNTY VOCATIONAL TECHNICAL SCHOOL WARETOWN CENTER",
#         "ADDRESS": "423 WELLS MILLS ROAD",
#         "CITY": "WARETOWN",
#         "STATE": "NJ",
#         "ZIP": "08758",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 39.7957111470001,
#         "LONGITUDE": -74.246654583
#       },
#       "geometry": {
#         "x": -74.24665458299995,
#         "y": 39.795711147000084
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 74879,
#         "NAME": "TUCKERTON ELEMENTARY SCHOOL",
#         "ADDRESS": "MARINE STREET",
#         "CITY": "TUCKERTON",
#         "STATE": "NJ",
#         "ZIP": "08087",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.601715847,
#         "LONGITUDE": -74.336153856
#       },
#       "geometry": {
#         "x": -74.33615385599995,
#         "y": 39.60171584700004
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 75679,
#         "NAME": "CRAWFORD-RODRIGUEZ ELEMENTARY SCHOOL",
#         "ADDRESS": "1025 LARSEN ROAD",
#         "CITY": "JACKSON",
#         "STATE": "NJ",
#         "ZIP": "08527",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.148768692,
#         "LONGITUDE": -74.2651236309999
#       },
#       "geometry": {
#         "x": -74.26512363099994,
#         "y": 40.148768692000026
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 76904,
#         "NAME": "SPRUCE STREET ELEMENTARY SCHOOL",
#         "ADDRESS": "90 SPRUCE STREET",
#         "CITY": "LAKEWOOD",
#         "STATE": "NJ",
#         "ZIP": "08701",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.069905539,
#         "LONGITUDE": -74.213764796
#       },
#       "geometry": {
#         "x": -74.21376479599996,
#         "y": 40.06990553900004
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 77167,
#         "NAME": "LACEY TOWNSHIP HIGH SCHOOL",
#         "ADDRESS": "73 HAINES STREET",
#         "CITY": "LANOKA HARBOR",
#         "STATE": "NJ",
#         "ZIP": "08734",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 39.860268853,
#         "LONGITUDE": -74.1941127329999
#       },
#       "geometry": {
#         "x": -74.19411273299994,
#         "y": 39.860268853000036
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 79426,
#         "NAME": "BAY HEAD ELEMENTARY",
#         "ADDRESS": "145 GROVE STREET",
#         "CITY": "BAY HEAD",
#         "STATE": "NJ",
#         "ZIP": "08742",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.069612389,
#         "LONGITUDE": -74.050182206
#       },
#       "geometry": {
#         "x": -74.05018220599999,
#         "y": 40.06961238900004
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 79513,
#         "NAME": "WEST DOVER ELEMENTARY SCHOOL",
#         "ADDRESS": "50 BLUE JAY DRIVE",
#         "CITY": "TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08753",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.9719651550001,
#         "LONGITUDE": -74.2324415259999
#       },
#       "geometry": {
#         "x": -74.23244152599995,
#         "y": 39.97196515500007
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 79556,
#         "NAME": "DRUM POINT ROAD ELEMENTARY SCHOOL",
#         "ADDRESS": "41 DRUM POINT RD",
#         "CITY": "BRICK TOWN",
#         "STATE": "NJ",
#         "ZIP": "08723",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.044680946,
#         "LONGITUDE": -74.1389814459999
#       },
#       "geometry": {
#         "x": -74.13898144599995,
#         "y": 40.04468094600004
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 80889,
#         "NAME": "POINT PLEASANT BOROUGH HIGH SCHOOL",
#         "ADDRESS": "LAURA HERBERT DR",
#         "CITY": "POINT PLEASANT",
#         "STATE": "NJ",
#         "ZIP": "08742",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 40.07773245,
#         "LONGITUDE": -74.071342925
#       },
#       "geometry": {
#         "x": -74.07134292499995,
#         "y": 40.077732450000035
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 80922,
#         "NAME": "MEMORIAL MIDDLE SCHOOL",
#         "ADDRESS": "LAURA HERBERT DR",
#         "CITY": "POINT PLEASANT",
#         "STATE": "NJ",
#         "ZIP": "08742",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "MIDDLE",
#         "LATITUDE": 40.0793131390001,
#         "LONGITUDE": -74.072759444
#       },
#       "geometry": {
#         "x": -74.07275944399998,
#         "y": 40.07931313900008
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 81580,
#         "NAME": "LAKEHURST ELEMENTARY SCHOOL",
#         "ADDRESS": "301 UNION AVE",
#         "CITY": "LAKEHURST",
#         "STATE": "NJ",
#         "ZIP": "08733",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.011990887,
#         "LONGITUDE": -74.316513341
#       },
#       "geometry": {
#         "x": -74.31651334099996,
#         "y": 40.011990887000024
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 82063,
#         "NAME": "OCEAN GATE ELEMENTARY SCHOOL",
#         "ADDRESS": "126 WEST ARVERNE AVENUE",
#         "CITY": "OCEAN GATE",
#         "STATE": "NJ",
#         "ZIP": "08740",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.9239082670001,
#         "LONGITUDE": -74.143032295
#       },
#       "geometry": {
#         "x": -74.14303229499995,
#         "y": 39.92390826700006
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 82085,
#         "NAME": "CLIFTON AVE GRADE SCHOOL",
#         "ADDRESS": "625 CLIFTON AVENUE",
#         "CITY": "LAKEWOOD",
#         "STATE": "NJ",
#         "ZIP": "08701",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.0964196190001,
#         "LONGITUDE": -74.214198091
#       },
#       "geometry": {
#         "x": -74.21419809099996,
#         "y": 40.09641961900007
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 83578,
#         "NAME": "CENTRAL REGIONAL HIGH SCHOOL",
#         "ADDRESS": "509 FOREST HILLS PARKWAY",
#         "CITY": "BAYVILLE",
#         "STATE": "NJ",
#         "ZIP": "08721",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 39.8903791870001,
#         "LONGITUDE": -74.204589969
#       },
#       "geometry": {
#         "x": -74.20458996899998,
#         "y": 39.89037918700007
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 83589,
#         "NAME": "TOMS RIVER INTERMEDIATE SCHOOL EAST",
#         "ADDRESS": "1519 HOOPER AVENUE",
#         "CITY": "TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08753",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "MIDDLE",
#         "LATITUDE": 39.9967952810001,
#         "LONGITUDE": -74.166174881
#       },
#       "geometry": {
#         "x": -74.16617488099996,
#         "y": 39.996795281000054
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 84882,
#         "NAME": "EMMA HAVENS YOUNG ELEMENTARY SCHOOL",
#         "ADDRESS": "43 DRUM POINT RD",
#         "CITY": "BRICK",
#         "STATE": "NJ",
#         "ZIP": "08723",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.043352998,
#         "LONGITUDE": -74.137405647
#       },
#       "geometry": {
#         "x": -74.13740564699998,
#         "y": 40.043352998000046
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 86792,
#         "NAME": "EAST DOVER ELEMENTARY SCHOOL",
#         "ADDRESS": "725 VAUGHN AVENUE",
#         "CITY": "TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08753",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.9650062910001,
#         "LONGITUDE": -74.149096458
#       },
#       "geometry": {
#         "x": -74.14909645799997,
#         "y": 39.965006291000066
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 86901,
#         "NAME": "NELLIE F. BENNETT ELEMENTARY SCHOOL",
#         "ADDRESS": "RIVIERA PARKWAY",
#         "CITY": "POINT PLEASANT",
#         "STATE": "NJ",
#         "ZIP": "08742",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.068020936,
#         "LONGITUDE": -74.062885632
#       },
#       "geometry": {
#         "x": -74.06288563199996,
#         "y": 40.06802093600004
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 88056,
#         "NAME": "NEW EGYPT HIGH SCHOOL",
#         "ADDRESS": "117 EVERGREEN ROAD",
#         "CITY": "NEW EGYPT",
#         "STATE": "NJ",
#         "ZIP": "08533",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 40.080503853,
#         "LONGITUDE": -74.5305135579999
#       },
#       "geometry": {
#         "x": -74.53051355799994,
#         "y": 40.08050385300004
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 88135,
#         "NAME": "GEORGE J. MITCHELL ELEMENTARY SCHOOL",
#         "ADDRESS": "950 ROUTE 539",
#         "CITY": "LITTLE EGG HARBOR",
#         "STATE": "NJ",
#         "ZIP": "08087",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.619908771,
#         "LONGITUDE": -74.343365464
#       },
#       "geometry": {
#         "x": -74.34336546399999,
#         "y": 39.61990877100005
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 90581,
#         "NAME": "ELLA G CLARKE ELEMENTARY SCHOOL",
#         "ADDRESS": "455 MANETTA AVENUE",
#         "CITY": "LAKEWOOD",
#         "STATE": "NJ",
#         "ZIP": "08701",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.0946414690001,
#         "LONGITUDE": -74.198899922
#       },
#       "geometry": {
#         "x": -74.19889992199995,
#         "y": 40.09464146900007
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 90587,
#         "NAME": "WARETOWN ELEMENTARY SCHOOL",
#         "ADDRESS": "64 RAILROAD AVENUE",
#         "CITY": "WARETOWN",
#         "STATE": "NJ",
#         "ZIP": "08758",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.788745238,
#         "LONGITUDE": -74.201119147
#       },
#       "geometry": {
#         "x": -74.20111914699999,
#         "y": 39.78874523800004
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 91132,
#         "NAME": "TOMS RIVER HIGH SCHOOL SOUTH",
#         "ADDRESS": "55 HYERS STREET",
#         "CITY": "TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08753",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 39.9570413700001,
#         "LONGITUDE": -74.195075023
#       },
#       "geometry": {
#         "x": -74.19507502299996,
#         "y": 39.95704137000006
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 91221,
#         "NAME": "LAKE RIVIERA MIDDLE SCHOOL",
#         "ADDRESS": "171 BEAVERSON BOULEVARD",
#         "CITY": "BRICK",
#         "STATE": "NJ",
#         "ZIP": "08723",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "MIDDLE",
#         "LATITUDE": 40.028738618,
#         "LONGITUDE": -74.1574262839999
#       },
#       "geometry": {
#         "x": -74.15742628399994,
#         "y": 40.02873861800003
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 92301,
#         "NAME": "ISLAND HEIGHTS ELEMENTARY SCHOOL",
#         "ADDRESS": "115 SUMMIT AVE",
#         "CITY": "ISLAND HEIGHTS",
#         "STATE": "NJ",
#         "ZIP": "08732",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.9459830640001,
#         "LONGITUDE": -74.1524481179999
#       },
#       "geometry": {
#         "x": -74.15244811799994,
#         "y": 39.945983064000075
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 92823,
#         "NAME": "TOMS RIVER INTERMEDIATE SCHOOL SOUTH",
#         "ADDRESS": "1675 PINEWALD ROAD",
#         "CITY": "BEACHWOOD",
#         "STATE": "NJ",
#         "ZIP": "08722",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "MIDDLE",
#         "LATITUDE": 39.9151760840001,
#         "LONGITUDE": -74.206097141
#       },
#       "geometry": {
#         "x": -74.20609714099999,
#         "y": 39.91517608400004
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 93444,
#         "NAME": "TOMS RIVER HIGH SCHOOL NORTH",
#         "ADDRESS": "1245 OLD FREEHOLD ROAD",
#         "CITY": "TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08753",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 39.9849941320001,
#         "LONGITUDE": -74.196013775
#       },
#       "geometry": {
#         "x": -74.19601377499998,
#         "y": 39.98499413200005
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 94018,
#         "NAME": "NORTH DOVER ELEMENTARY SCHOOL",
#         "ADDRESS": "1759 NEW HAMPSHIRE AVENUE",
#         "CITY": "TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08753",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.017664967,
#         "LONGITUDE": -74.1970764289999
#       },
#       "geometry": {
#         "x": -74.19707642899994,
#         "y": 40.01766496700002
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 94667,
#         "NAME": "BERKELEY TOWNSHIP ELEMENTARY SCHOOL",
#         "ADDRESS": "10 EMORY ROAD",
#         "CITY": "BAYVILLE",
#         "STATE": "NJ",
#         "ZIP": "08721",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "MIDDLE",
#         "LATITUDE": 39.901114729,
#         "LONGITUDE": -74.158636008
#       },
#       "geometry": {
#         "x": -74.15863600799997,
#         "y": 39.90111472900003
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 95414,
#         "NAME": "BRICK TOWNSHIP MEMORIAL HIGH SCHOOL",
#         "ADDRESS": "2001 LANES MILL RD",
#         "CITY": "BRICK",
#         "STATE": "NJ",
#         "ZIP": "08724",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 40.104301096,
#         "LONGITUDE": -74.1289851079999
#       },
#       "geometry": {
#         "x": -74.12898510799994,
#         "y": 40.10430109600002
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 96741,
#         "NAME": "WASHINGTON STREET ELEMENTARY SCHOOL",
#         "ADDRESS": "500 WEST EARL COURT",
#         "CITY": "TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08753",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.9551093220001,
#         "LONGITUDE": -74.171372987
#       },
#       "geometry": {
#         "x": -74.17137298699998,
#         "y": 39.955109322000055
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 97998,
#         "NAME": "OCEAN ACRES ELEMENTARY SCHOOL",
#         "ADDRESS": "489 NAUTILUS DRIVE",
#         "CITY": "MANAHAWKIN",
#         "STATE": "NJ",
#         "ZIP": "08050",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 39.741927263,
#         "LONGITUDE": -74.2807001159999
#       },
#       "geometry": {
#         "x": -74.28070011599993,
#         "y": 39.741927263000036
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 100056,
#         "NAME": "OCEAN CO JUV DET CTR",
#         "ADDRESS": "165 SUNSET AVENUE",
#         "CITY": "TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08754",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 40.0059218440001,
#         "LONGITUDE": -74.2262273489999
#       },
#       "geometry": {
#         "x": -74.22622734899994,
#         "y": 40.00592184400006
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 100319,
#         "NAME": "BARNEGAT HIGH SCHOOL",
#         "ADDRESS": "180 BENGAL BLVD",
#         "CITY": "BARNEGAT",
#         "STATE": "NJ",
#         "ZIP": "08005",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "HIGH",
#         "LATITUDE": 39.771831692,
#         "LONGITUDE": -74.234155874
#       },
#       "geometry": {
#         "x": -74.23415587399995,
#         "y": 39.77183169200003
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 100431,
#         "NAME": "NEW EGYPT MIDDLE SCHOOL",
#         "ADDRESS": "115 EVERGREEN ROAD",
#         "CITY": "NEW EGYPT",
#         "STATE": "NJ",
#         "ZIP": "08533",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "MIDDLE",
#         "LATITUDE": 40.0797409580001,
#         "LONGITUDE": -74.52892672
#       },
#       "geometry": {
#         "x": -74.52892671999996,
#         "y": 40.079740958000066
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 100909,
#         "NAME": "NEW EGYPT PRIMARY SCHOOL",
#         "ADDRESS": "131 EVERGREEN ROAD",
#         "CITY": "NEW EGYPT",
#         "STATE": "NJ",
#         "ZIP": "08533",
#         "COUNTY": "OCEAN",
#         "LEVEL_": "ELEMENTARY",
#         "LATITUDE": 40.085133855,
#         "LONGITUDE": -74.5308554539999
#       },
#       "geometry": {
#         "x": -74.53085545399995,
#         "y": 40.08513385500003
#       }
#     }
#   ]
# }

# %%
pre_school = pd.json_normalize(data_school['features'])
pre_school
# Out:
#      attributes.OBJECTID                        attributes.NAME  \
# 0                    264    FREDERIC A. PRIFF ELEMENTARY SCHOOL
# 1                   2741         CENTRAL REGIONAL MIDDLE SCHOOL
# 2                   2822  PINELANDS REGIONAL JUNIOR HIGH SCHOOL
# 3                   3630           MIDSTREAMS ELEMENTARY SCHOOL
# 4                   5809           OCEAN ACADEMY CHARTER SCHOOL
# ..                   ...                                    ...
# 115                97998          OCEAN ACRES ELEMENTARY SCHOOL
# 116               100056                   OCEAN CO JUV DET CTR
# 117               100319                   BARNEGAT HIGH SCHOOL
# 118               100431                NEW EGYPT MIDDLE SCHOOL
# 119               100909               NEW EGYPT PRIMARY SCHOOL
#
#            attributes.ADDRESS    attributes.CITY attributes.STATE  \
# 0         139 WELLS MILL ROAD           WARETOWN               NJ
# 1    509 FOREST HILLS PARKWAY           BAYVILLE               NJ
# 2          590 NUGENTOWN ROAD  LITTLE EGG HARBOR               NJ
# 3           500 MIDSTREAMS RD         BRICK TOWN               NJ
# 4                  678 5TH ST           LAKEWOOD               NJ
# ..                        ...                ...              ...
# 115        489 NAUTILUS DRIVE         MANAHAWKIN               NJ
# 116         165 SUNSET AVENUE         TOMS RIVER               NJ
# 117           180 BENGAL BLVD           BARNEGAT               NJ
# 118        115 EVERGREEN ROAD          NEW EGYPT               NJ
# 119        131 EVERGREEN ROAD          NEW EGYPT               NJ
#
#     attributes.ZIP attributes.COUNTY attributes.LEVEL_  attributes.LATITUDE  \
# 0            08758             OCEAN            MIDDLE            39.790614
# 1            08721             OCEAN            MIDDLE            39.889370
# 2            08087             OCEAN            MIDDLE            39.614155
# 3            08724             OCEAN        ELEMENTARY            40.068134
# 4            08701             OCEAN        ELEMENTARY            40.093754
# ..             ...               ...               ...                  ...
# 115          08050             OCEAN        ELEMENTARY            39.741927
# 116          08754             OCEAN              HIGH            40.005922
# 117          08005             OCEAN              HIGH            39.771832
# 118          08533             OCEAN            MIDDLE            40.079741
# 119          08533             OCEAN        ELEMENTARY            40.085134
#
#      attributes.LONGITUDE  geometry.x  geometry.y
# 0              -74.201966  -74.201966   39.790614
# 1              -74.210436  -74.210436   39.889370
# 2              -74.360452  -74.360452   39.614155
# 3              -74.100071  -74.100071   40.068134
# 4              -74.223589  -74.223589   40.093754
# ..                    ...         ...         ...
# 115            -74.280700  -74.280700   39.741927
# 116            -74.226227  -74.226227   40.005922
# 117            -74.234156  -74.234156   39.771832
# 118            -74.528927  -74.528927   40.079741
# 119            -74.530855  -74.530855   40.085134
#
# [120 rows x 12 columns]

# %%
pre_school[['S_ID', 'S_name', 'S_address', 'S_level', 'S_city', 'S_zip', 'S_latitude', 'S_longitude']] = pre_school[['attributes.OBJECTID', 'attributes.NAME', 'attributes.ADDRESS', 'attributes.LEVEL_', 'attributes.CITY', 'attributes.ZIP', 'attributes.LATITUDE', 'attributes.LONGITUDE']]
df_school = pre_school.iloc[:, -8:]
df_school
# Out:
#        S_ID                                 S_name                 S_address  \
# 0       264    FREDERIC A. PRIFF ELEMENTARY SCHOOL       139 WELLS MILL ROAD
# 1      2741         CENTRAL REGIONAL MIDDLE SCHOOL  509 FOREST HILLS PARKWAY
# 2      2822  PINELANDS REGIONAL JUNIOR HIGH SCHOOL        590 NUGENTOWN ROAD
# 3      3630           MIDSTREAMS ELEMENTARY SCHOOL         500 MIDSTREAMS RD
# 4      5809           OCEAN ACADEMY CHARTER SCHOOL                678 5TH ST
# ..      ...                                    ...                       ...
# 115   97998          OCEAN ACRES ELEMENTARY SCHOOL        489 NAUTILUS DRIVE
# 116  100056                   OCEAN CO JUV DET CTR         165 SUNSET AVENUE
# 117  100319                   BARNEGAT HIGH SCHOOL           180 BENGAL BLVD
# 118  100431                NEW EGYPT MIDDLE SCHOOL        115 EVERGREEN ROAD
# 119  100909               NEW EGYPT PRIMARY SCHOOL        131 EVERGREEN ROAD
#
#         S_level             S_city  S_zip  S_latitude  S_longitude
# 0        MIDDLE           WARETOWN  08758   39.790614   -74.201966
# 1        MIDDLE           BAYVILLE  08721   39.889370   -74.210436
# 2        MIDDLE  LITTLE EGG HARBOR  08087   39.614155   -74.360452
# 3    ELEMENTARY         BRICK TOWN  08724   40.068134   -74.100071
# 4    ELEMENTARY           LAKEWOOD  08701   40.093754   -74.223589
# ..          ...                ...    ...         ...          ...
# 115  ELEMENTARY         MANAHAWKIN  08050   39.741927   -74.280700
# 116        HIGH         TOMS RIVER  08754   40.005922   -74.226227
# 117        HIGH           BARNEGAT  08005   39.771832   -74.234156
# 118      MIDDLE          NEW EGYPT  08533   40.079741   -74.528927
# 119  ELEMENTARY          NEW EGYPT  08533   40.085134   -74.530855
#
# [120 rows x 8 columns]

# %%
# df_school.to_csv('./Data_Source/school.csv', index = False)

# %% [markdown]
# ## City

# %%
where = urllib.parse.quote_plus("""
{
    "State": "NJ",
    "County": "Ocean County"
}
""")
url = 'https://parseapi.back4app.com/classes/US_Zip_Code?count=1&limit=35&order=US_Zip_Code&excludeKeys=Unacceptable_cities,country,Remarks,Timezone&where=%s' % where
headers = {
    'X-Parse-Application-Id': back4app_ID,
    'X-Parse-Master-Key': back4app_key
}

data_city = json.loads(requests.get(url, headers = headers).content.decode('utf-8'))
print(json.dumps(data_city, indent = 2))
# Out:
# {
#   "results": [
#     {
#       "objectId": "meQ6vKJetk",
#       "US_Zip_Code": 8005,
#       "Type": "STANDARD",
#       "Primary_city": "Barnegat",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 609,
#       "Latitude": 39.75,
#       "Longitude": -74.22,
#       "estimated_population": 19593,
#       "createdAt": "2020-02-11T17:24:50.669Z",
#       "updatedAt": "2020-02-11T17:24:50.669Z"
#     },
#     {
#       "objectId": "dtP0eU85lh",
#       "US_Zip_Code": 8006,
#       "Type": "PO BOX",
#       "Primary_city": "Barnegat Light",
#       "Acceptable_cities": "Barnegat Lgt",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 609,
#       "Latitude": 39.75,
#       "Longitude": -74.11,
#       "estimated_population": 687,
#       "createdAt": "2020-02-11T17:24:50.669Z",
#       "updatedAt": "2020-02-11T17:24:50.669Z"
#     },
#     {
#       "objectId": "lc4pUW4mon",
#       "US_Zip_Code": 8008,
#       "Type": "STANDARD",
#       "Primary_city": "Beach Haven",
#       "Acceptable_cities": "Harvey Cedars, Long Bch Twp, Long Beach, Long Beach Township, Ship Bottom, Surf City",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 609,
#       "Latitude": 39.55,
#       "Longitude": -74.24,
#       "estimated_population": 6743,
#       "createdAt": "2020-02-11T17:24:50.669Z",
#       "updatedAt": "2020-02-11T17:24:50.669Z"
#     },
#     {
#       "objectId": "LJ6dAgrWmg",
#       "US_Zip_Code": 8050,
#       "Type": "STANDARD",
#       "Primary_city": "Manahawkin",
#       "Acceptable_cities": "Stafford Township, Stafford Twp",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 609,
#       "Latitude": 39.69,
#       "Longitude": -74.25,
#       "estimated_population": 20931,
#       "createdAt": "2020-02-11T17:24:50.706Z",
#       "updatedAt": "2020-02-11T17:24:50.706Z"
#     },
#     {
#       "objectId": "YMZimxAlJ9",
#       "US_Zip_Code": 8087,
#       "Type": "STANDARD",
#       "Primary_city": "Tuckerton",
#       "Acceptable_cities": "Little Egg Harbor, Little Egg Harbor Twp, Ltl Egg Hbr, Mystic Islands, Mystic Islnds",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 609,
#       "Latitude": 39.59,
#       "Longitude": -74.32,
#       "estimated_population": 20609,
#       "createdAt": "2020-02-11T17:24:50.708Z",
#       "updatedAt": "2020-02-11T17:24:50.708Z"
#     },
#     {
#       "objectId": "srBzYvMuo4",
#       "US_Zip_Code": 8092,
#       "Type": "STANDARD",
#       "Primary_city": "West Creek",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 609,
#       "Latitude": 39.65,
#       "Longitude": -74.28,
#       "estimated_population": 3158,
#       "createdAt": "2020-02-11T17:24:50.708Z",
#       "updatedAt": "2020-02-11T17:24:50.708Z"
#     },
#     {
#       "objectId": "MHHcTj6OPc",
#       "US_Zip_Code": 8527,
#       "Type": "STANDARD",
#       "Primary_city": "Jackson",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 40.1,
#       "Longitude": -74.35,
#       "estimated_population": 47406,
#       "createdAt": "2020-02-11T17:24:50.753Z",
#       "updatedAt": "2020-02-11T17:24:50.753Z"
#     },
#     {
#       "objectId": "Vv5aU0LOUX",
#       "US_Zip_Code": 8533,
#       "Type": "STANDARD",
#       "Primary_city": "New Egypt",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 609,
#       "Latitude": 40.06,
#       "Longitude": -74.53,
#       "estimated_population": 6225,
#       "createdAt": "2020-02-11T17:24:50.754Z",
#       "updatedAt": "2020-02-11T17:24:50.754Z"
#     },
#     {
#       "objectId": "lHgsyHmsNF",
#       "US_Zip_Code": 8701,
#       "Type": "STANDARD",
#       "Primary_city": "Lakewood",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732610000000,
#       "Latitude": 40.09,
#       "Longitude": -74.21,
#       "estimated_population": 52778,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "4T4vhwyS3A",
#       "US_Zip_Code": 8721,
#       "Type": "STANDARD",
#       "Primary_city": "Bayville",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 39.91,
#       "Longitude": -74.21,
#       "estimated_population": 17550,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "EARqt5TGi6",
#       "US_Zip_Code": 8722,
#       "Type": "STANDARD",
#       "Primary_city": "Beachwood",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 39.92,
#       "Longitude": -74.2,
#       "estimated_population": 9570,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "nor0AD2OKt",
#       "US_Zip_Code": 8723,
#       "Type": "STANDARD",
#       "Primary_city": "Brick",
#       "Acceptable_cities": "Osbornville",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 40.06,
#       "Longitude": -74.11,
#       "estimated_population": 27903,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "iS57kYIQUs",
#       "US_Zip_Code": 8724,
#       "Type": "STANDARD",
#       "Primary_city": "Brick",
#       "Acceptable_cities": "Wall Township",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 40.06,
#       "Longitude": -74.11,
#       "estimated_population": 37268,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "E8GsD2HHVN",
#       "US_Zip_Code": 8731,
#       "Type": "STANDARD",
#       "Primary_city": "Forked River",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 609732856,
#       "Latitude": 39.84,
#       "Longitude": -74.19,
#       "estimated_population": 17395,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "v3eNyb5DTp",
#       "US_Zip_Code": 8732,
#       "Type": "PO BOX",
#       "Primary_city": "Island Heights",
#       "Acceptable_cities": "Island Hgts",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 39.94,
#       "Longitude": -74.14,
#       "estimated_population": 1563,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "jCyxZOkjkw",
#       "US_Zip_Code": 8733,
#       "Type": "STANDARD",
#       "Primary_city": "Lakehurst",
#       "Acceptable_cities": "Lakehurst Nae, Lakehurst Naec",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 40.01,
#       "Longitude": -74.32,
#       "estimated_population": 2437,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "ttFMAIpYDr",
#       "US_Zip_Code": 8734,
#       "Type": "STANDARD",
#       "Primary_city": "Lanoka Harbor",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 609,
#       "Latitude": 39.86,
#       "Longitude": -74.16,
#       "estimated_population": 6888,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "ctHq2rrXTA",
#       "US_Zip_Code": 8735,
#       "Type": "STANDARD",
#       "Primary_city": "Lavallette",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 39.96,
#       "Longitude": -74.06,
#       "estimated_population": 2840,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "svWKYNzwFE",
#       "US_Zip_Code": 8738,
#       "Type": "STANDARD",
#       "Primary_city": "Mantoloking",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 40.04,
#       "Longitude": -74.04,
#       "estimated_population": 831,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "qYFoCFL6u6",
#       "US_Zip_Code": 8739,
#       "Type": "PO BOX",
#       "Primary_city": "Normandy Beach",
#       "Acceptable_cities": "Normandy Bch",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 40,
#       "Longitude": -74.06,
#       "estimated_population": 478,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "8pA5MtSBVJ",
#       "US_Zip_Code": 8740,
#       "Type": "PO BOX",
#       "Primary_city": "Ocean Gate",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 39.92,
#       "Longitude": -74.13,
#       "estimated_population": 1669,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "5g0VmmxWIa",
#       "US_Zip_Code": 8741,
#       "Type": "STANDARD",
#       "Primary_city": "Pine Beach",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 39.93,
#       "Longitude": -74.17,
#       "estimated_population": 2458,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "dp0RtgEz1C",
#       "US_Zip_Code": 8742,
#       "Type": "STANDARD",
#       "Primary_city": "Point Pleasant Beach",
#       "Acceptable_cities": "Bay Head, Point Pleasant Boro, Pt Pleas Bch, Pt Pleasant, Pt Pleasant B, Pt Pleasant Beach",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 40.09,
#       "Longitude": -74.04,
#       "estimated_population": 22127,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "euVxvd2u6T",
#       "US_Zip_Code": 8751,
#       "Type": "STANDARD",
#       "Primary_city": "Seaside Heights",
#       "Acceptable_cities": "Seaside Hgts",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 201732,
#       "Latitude": 39.94,
#       "Longitude": -74.07,
#       "estimated_population": 3094,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "W4acBzqd64",
#       "US_Zip_Code": 8752,
#       "Type": "STANDARD",
#       "Primary_city": "Seaside Park",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 201732,
#       "Latitude": 39.79,
#       "Longitude": -74.09,
#       "estimated_population": 1913,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "itFWH1ht9y",
#       "US_Zip_Code": 8753,
#       "Type": "STANDARD",
#       "Primary_city": "Toms River",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 39.95,
#       "Longitude": -74.18,
#       "estimated_population": 55159,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "mU0Ht5IQ77",
#       "US_Zip_Code": 8754,
#       "Type": "PO BOX",
#       "Primary_city": "Toms River",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 39.95,
#       "Longitude": -74.18,
#       "estimated_population": 640,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "Kr3wVgt15R",
#       "US_Zip_Code": 8755,
#       "Type": "STANDARD",
#       "Primary_city": "Toms River",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732848908,
#       "Latitude": 39.95,
#       "Longitude": -74.18,
#       "estimated_population": 21432,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "Uh0HfLQ5ur",
#       "US_Zip_Code": 8756,
#       "Type": "PO BOX",
#       "Primary_city": "Toms River",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 39.95,
#       "Longitude": -74.18,
#       "estimated_population": 0,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "4vnZoZsC3j",
#       "US_Zip_Code": 8757,
#       "Type": "STANDARD",
#       "Primary_city": "Toms River",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732848908,
#       "Latitude": 39.95,
#       "Longitude": -74.18,
#       "estimated_population": 26967,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "FXx7NVKo0d",
#       "US_Zip_Code": 8758,
#       "Type": "STANDARD",
#       "Primary_city": "Waretown",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 609,
#       "Latitude": 39.78,
#       "Longitude": -74.19,
#       "estimated_population": 6336,
#       "createdAt": "2020-02-11T17:24:50.792Z",
#       "updatedAt": "2020-02-11T17:24:50.792Z"
#     },
#     {
#       "objectId": "bbYwcCiHSb",
#       "US_Zip_Code": 8759,
#       "Type": "STANDARD",
#       "Primary_city": "Manchester Township",
#       "Acceptable_cities": "Lakehurst, Manchester, Manchester Tw, Whiting",
#       "State": "NJ",
#       "County": "Ocean County",
#       "Area_codes": 732,
#       "Latitude": 39.93,
#       "Longitude": -74.39,
#       "estimated_population": 27892,
#       "createdAt": "2020-02-11T17:24:50.793Z",
#       "updatedAt": "2020-02-11T17:24:50.793Z"
#     }
#   ],
#   "count": 32
# }

# %%
pre_city = pd.json_normalize(data_city['results'])

pre_city['US_Zip_Code'] = '0' + pre_city['US_Zip_Code'].astype(str)
pre_city[['C_ID', 'C_name', 'C_AKA', 'C_zip', 'C_latitude', 'C_longitude', 'C_population']] = pre_city[['objectId', 'Primary_city', 'Acceptable_cities', 'US_Zip_Code', 'Latitude', 'Longitude', 'estimated_population']]
df_city = pre_city.iloc[:,-7:]
df_city
# Out:
#           C_ID                C_name  \
# 0   meQ6vKJetk              Barnegat
# 1   dtP0eU85lh        Barnegat Light
# 2   lc4pUW4mon           Beach Haven
# 3   LJ6dAgrWmg            Manahawkin
# 4   YMZimxAlJ9             Tuckerton
# 5   srBzYvMuo4            West Creek
# 6   MHHcTj6OPc               Jackson
# 7   Vv5aU0LOUX             New Egypt
# 8   lHgsyHmsNF              Lakewood
# 9   4T4vhwyS3A              Bayville
# 10  EARqt5TGi6             Beachwood
# 11  nor0AD2OKt                 Brick
# 12  iS57kYIQUs                 Brick
# 13  E8GsD2HHVN          Forked River
# 14  v3eNyb5DTp        Island Heights
# 15  jCyxZOkjkw             Lakehurst
# 16  ttFMAIpYDr         Lanoka Harbor
# 17  ctHq2rrXTA            Lavallette
# 18  svWKYNzwFE           Mantoloking
# 19  qYFoCFL6u6        Normandy Beach
# 20  8pA5MtSBVJ            Ocean Gate
# 21  5g0VmmxWIa            Pine Beach
# 22  dp0RtgEz1C  Point Pleasant Beach
# 23  euVxvd2u6T       Seaside Heights
# 24  W4acBzqd64          Seaside Park
# 25  itFWH1ht9y            Toms River
# 26  mU0Ht5IQ77            Toms River
# 27  Kr3wVgt15R            Toms River
# 28  Uh0HfLQ5ur            Toms River
# 29  4vnZoZsC3j            Toms River
# 30  FXx7NVKo0d              Waretown
# 31  bbYwcCiHSb   Manchester Township
#
#                                                 C_AKA  C_zip  C_latitude  \
# 0                                                 NaN  08005       39.75
# 1                                        Barnegat Lgt  08006       39.75
# 2   Harvey Cedars, Long Bch Twp, Long Beach, Long ...  08008       39.55
# 3                     Stafford Township, Stafford Twp  08050       39.69
# 4   Little Egg Harbor, Little Egg Harbor Twp, Ltl ...  08087       39.59
# 5                                                 NaN  08092       39.65
# 6                                                 NaN  08527       40.10
# 7                                                 NaN  08533       40.06
# 8                                                 NaN  08701       40.09
# 9                                                 NaN  08721       39.91
# 10                                                NaN  08722       39.92
# 11                                        Osbornville  08723       40.06
# 12                                      Wall Township  08724       40.06
# 13                                                NaN  08731       39.84
# 14                                        Island Hgts  08732       39.94
# 15                      Lakehurst Nae, Lakehurst Naec  08733       40.01
# 16                                                NaN  08734       39.86
# 17                                                NaN  08735       39.96
# 18                                                NaN  08738       40.04
# 19                                       Normandy Bch  08739       40.00
# 20                                                NaN  08740       39.92
# 21                                                NaN  08741       39.93
# 22  Bay Head, Point Pleasant Boro, Pt Pleas Bch, P...  08742       40.09
# 23                                       Seaside Hgts  08751       39.94
# 24                                                NaN  08752       39.79
# 25                                                NaN  08753       39.95
# 26                                                NaN  08754       39.95
# 27                                                NaN  08755       39.95
# 28                                                NaN  08756       39.95
# 29                                                NaN  08757       39.95
# 30                                                NaN  08758       39.78
# 31      Lakehurst, Manchester, Manchester Tw, Whiting  08759       39.93
#
#     C_longitude  C_population
# 0        -74.22         19593
# 1        -74.11           687
# 2        -74.24          6743
# 3        -74.25         20931
# 4        -74.32         20609
# 5        -74.28          3158
# 6        -74.35         47406
# 7        -74.53          6225
# 8        -74.21         52778
# 9        -74.21         17550
# 10       -74.20          9570
# 11       -74.11         27903
# 12       -74.11         37268
# 13       -74.19         17395
# 14       -74.14          1563
# 15       -74.32          2437
# 16       -74.16          6888
# 17       -74.06          2840
# 18       -74.04           831
# 19       -74.06           478
# 20       -74.13          1669
# 21       -74.17          2458
# 22       -74.04         22127
# 23       -74.07          3094
# 24       -74.09          1913
# 25       -74.18         55159
# 26       -74.18           640
# 27       -74.18         21432
# 28       -74.18             0
# 29       -74.18         26967
# 30       -74.19          6336
# 31       -74.39         27892

# %%
# df_city.to_csv('./Data_Source/city.csv', index = False)

# %%
city_names = list(df_city['C_name'].unique())
city_names
# Out:
# ['Barnegat',
#  'Barnegat Light',
#  'Beach Haven',
#  'Manahawkin',
#  'Tuckerton',
#  'West Creek',
#  'Jackson',
#  'New Egypt',
#  'Lakewood',
#  'Bayville',
#  'Beachwood',
#  'Brick',
#  'Forked River',
#  'Island Heights',
#  'Lakehurst',
#  'Lanoka Harbor',
#  'Lavallette',
#  'Mantoloking',
#  'Normandy Beach',
#  'Ocean Gate',
#  'Pine Beach',
#  'Point Pleasant Beach',
#  'Seaside Heights',
#  'Seaside Park',
#  'Toms River',
#  'Waretown',
#  'Manchester Township']

# %% [markdown]
# ## Fire department

# %%
url_fire = 'https://services1.arcgis.com/' + HIFLD_key + '/arcgis/rest/services/Fire_Station/FeatureServer/0/query?where=STATE%20%3D%20%27NJ%27&outFields=OBJECTID,NAME,ADDRESS,CITY,STATE,ZIPCODE&outSR=4326&f=json'
data_fire = json.loads(requests.get(url_fire).content.decode('utf-8'))
print(json.dumps(data_fire, indent = 2))
# Out:
# {
#   "objectIdFieldName": "OBJECTID",
#   "uniqueIdField": {
#     "name": "OBJECTID",
#     "isSystemMaintained": true
#   },
#   "globalIdFieldName": "GLOBALID",
#   "geometryType": "esriGeometryPoint",
#   "spatialReference": {
#     "wkid": 4326,
#     "latestWkid": 4326
#   },
#   "fields": [
#     {
#       "name": "OBJECTID",
#       "type": "esriFieldTypeOID",
#       "alias": "OBJECTID",
#       "sqlType": "sqlTypeOther",
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "NAME",
#       "type": "esriFieldTypeString",
#       "alias": "NAME",
#       "sqlType": "sqlTypeOther",
#       "length": 100,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "ADDRESS",
#       "type": "esriFieldTypeString",
#       "alias": "ADDRESS",
#       "sqlType": "sqlTypeOther",
#       "length": 75,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "CITY",
#       "type": "esriFieldTypeString",
#       "alias": "CITY",
#       "sqlType": "sqlTypeOther",
#       "length": 40,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "STATE",
#       "type": "esriFieldTypeString",
#       "alias": "STATE",
#       "sqlType": "sqlTypeOther",
#       "length": 2,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "ZIPCODE",
#       "type": "esriFieldTypeString",
#       "alias": "ZIPCODE",
#       "sqlType": "sqlTypeOther",
#       "length": 10,
#       "domain": null,
#       "defaultValue": null
#     }
#   ],
#   "features": [
#     {
#       "attributes": {
#         "OBJECTID": 36,
#         "NAME": "Independent Fire Company No. 1 Station 301",
#         "ADDRESS": "1601 Burlington Bypass",
#         "CITY": "Burlington",
#         "STATE": "NJ",
#         "ZIPCODE": "08016"
#       },
#       "geometry": {
#         "x": -74.84007047429077,
#         "y": 40.05850559820127
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4703,
#         "NAME": "Dumont Fire Department Company 2",
#         "ADDRESS": "205 Prospect Avenue",
#         "CITY": "Dumont",
#         "STATE": "NJ",
#         "ZIPCODE": "07628"
#       },
#       "geometry": {
#         "x": -74.00283469251129,
#         "y": 40.942813361861255
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4704,
#         "NAME": "Montville Township Fire Company 3",
#         "ADDRESS": "86 River Road",
#         "CITY": "Montville",
#         "STATE": "NJ",
#         "ZIPCODE": "07045"
#       },
#       "geometry": {
#         "x": -74.37302137768802,
#         "y": 40.89974338100916
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4705,
#         "NAME": "Reliance Fire Company",
#         "ADDRESS": "25 Broad Street",
#         "CITY": "Woodstown",
#         "STATE": "NJ",
#         "ZIPCODE": "08098"
#       },
#       "geometry": {
#         "x": -75.32297426343422,
#         "y": 39.6528186049357
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4708,
#         "NAME": "Lawrenceville Fire Company",
#         "ADDRESS": "64 Phillips Avenue",
#         "CITY": "Lawrenceville",
#         "STATE": "NJ",
#         "ZIPCODE": "08648"
#       },
#       "geometry": {
#         "x": -74.731239319051,
#         "y": 40.299026488882596
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4709,
#         "NAME": "Hope Hose Humane Company 1",
#         "ADDRESS": "150 West Burlington Street",
#         "CITY": "Bordentown",
#         "STATE": "NJ",
#         "ZIPCODE": "08505"
#       },
#       "geometry": {
#         "x": -74.7120963452393,
#         "y": 40.14369169242882
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4711,
#         "NAME": "Delran Fire District 1 Station 231",
#         "ADDRESS": "9 South Bridgeboro Street",
#         "CITY": "Delran",
#         "STATE": "NJ",
#         "ZIPCODE": "08075"
#       },
#       "geometry": {
#         "x": -74.93218962120463,
#         "y": 40.02602138226811
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4713,
#         "NAME": "Logan Volunteer Fire Company of Pedricktown",
#         "ADDRESS": "39 South Railroad Avenue",
#         "CITY": "Pedricktown",
#         "STATE": "NJ",
#         "ZIPCODE": "08067"
#       },
#       "geometry": {
#         "x": -75.40280733855344,
#         "y": 39.756922518510464
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4714,
#         "NAME": "Rosenhayn Fire and Rescue",
#         "ADDRESS": "678 Morton Avenue",
#         "CITY": "Bridgeton",
#         "STATE": "NJ",
#         "ZIPCODE": "08302"
#       },
#       "geometry": {
#         "x": -75.13189419315971,
#         "y": 39.48077591087947
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4723,
#         "NAME": "Rockaway Township Fire Department Marcella Fire Company 3",
#         "ADDRESS": "20 Upper Hibernia Road",
#         "CITY": "Rockaway",
#         "STATE": "NJ",
#         "ZIPCODE": "07866"
#       },
#       "geometry": {
#         "x": -74.47137427061583,
#         "y": 40.98533369190576
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4737,
#         "NAME": "Berkeley Heights Fire Department",
#         "ADDRESS": "411 Hamilton Avenue",
#         "CITY": "Berkeley Heights",
#         "STATE": "NJ",
#         "ZIPCODE": "07922"
#       },
#       "geometry": {
#         "x": -74.43385157809863,
#         "y": 40.67757823789193
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4746,
#         "NAME": "Union Fire Company 1",
#         "ADDRESS": "21 Walnut Street",
#         "CITY": "Salem",
#         "STATE": "NJ",
#         "ZIPCODE": "08079"
#       },
#       "geometry": {
#         "x": -75.46695703699484,
#         "y": 39.56994131664535
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4750,
#         "NAME": "Washington Fire Company 3",
#         "ADDRESS": "374 East Broadway",
#         "CITY": "Salem",
#         "STATE": "NJ",
#         "ZIPCODE": "08079"
#       },
#       "geometry": {
#         "x": -75.46061548472132,
#         "y": 39.56522130656132
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4752,
#         "NAME": "Rockaway Township Fire Department Birchwood Fire Company 4",
#         "ADDRESS": "Art Street",
#         "CITY": "Dover",
#         "STATE": "NJ",
#         "ZIPCODE": "07801"
#       },
#       "geometry": {
#         "x": -74.5382032189085,
#         "y": 40.901004204488636
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4753,
#         "NAME": "Livingston Fire Department Northfield Station",
#         "ADDRESS": "2 East Hobart Gap Road",
#         "CITY": "Livingston",
#         "STATE": "NJ",
#         "ZIPCODE": "07039"
#       },
#       "geometry": {
#         "x": -74.32745945944015,
#         "y": 40.77196875791231
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4755,
#         "NAME": "Woolwich Fire Department Substation",
#         "ADDRESS": "124 Woodstown Road",
#         "CITY": "Swedesboro",
#         "STATE": "NJ",
#         "ZIPCODE": "08085"
#       },
#       "geometry": {
#         "x": -75.31788686966753,
#         "y": 39.73100016227582
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4756,
#         "NAME": "Basking Ridge Fire Company 1 and First Aid Squad",
#         "ADDRESS": "30 Washington Avenue",
#         "CITY": "Basking Ridge",
#         "STATE": "NJ",
#         "ZIPCODE": "07920"
#       },
#       "geometry": {
#         "x": -74.55709682125944,
#         "y": 40.70838719467075
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4771,
#         "NAME": "Randolph Township Fire Department Chemical Engine Company 5 Shongum Mountain",
#         "ADDRESS": "West Hanover Avenue and Arrow Place",
#         "CITY": "Randolph",
#         "STATE": "NJ",
#         "ZIPCODE": "07869"
#       },
#       "geometry": {
#         "x": -74.54870029176146,
#         "y": 40.82982573098654
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4776,
#         "NAME": "Oaklyn Fire Department Station 18-3",
#         "ADDRESS": "20 West Clinton Avenue",
#         "CITY": "Oaklyn",
#         "STATE": "NJ",
#         "ZIPCODE": "08107"
#       },
#       "geometry": {
#         "x": -75.07904734134759,
#         "y": 39.90320585801131
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4780,
#         "NAME": "Collings Lakes Volunteer Fire Department",
#         "ADDRESS": "600 Cains Mill Road",
#         "CITY": "Williamstown",
#         "STATE": "NJ",
#         "ZIPCODE": "08094"
#       },
#       "geometry": {
#         "x": -74.88124438749279,
#         "y": 39.590503941601014
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4781,
#         "NAME": "Cassville Volunteer Fire Company Station 56",
#         "ADDRESS": "12 Toms River Road",
#         "CITY": "Jackson",
#         "STATE": "NJ",
#         "ZIPCODE": "08527"
#       },
#       "geometry": {
#         "x": -74.38683319098301,
#         "y": 40.104000091936044
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4782,
#         "NAME": "Newfield Fire Department",
#         "ADDRESS": "18 Catawba Avenue",
#         "CITY": "Newfield",
#         "STATE": "NJ",
#         "ZIPCODE": "08344"
#       },
#       "geometry": {
#         "x": -75.02283854094321,
#         "y": 39.547302272790105
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4786,
#         "NAME": "Landisville Volunteer Fire Company 1",
#         "ADDRESS": "Harding Highway",
#         "CITY": "Landisville",
#         "STATE": "NJ",
#         "ZIPCODE": "08326"
#       },
#       "geometry": {
#         "x": -74.94093437543403,
#         "y": 39.52671008824784
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4792,
#         "NAME": "New Milford Fire Department Company 2",
#         "ADDRESS": "680 Trenton Street",
#         "CITY": "New Milford",
#         "STATE": "NJ",
#         "ZIPCODE": "07646"
#       },
#       "geometry": {
#         "x": -74.0247838676146,
#         "y": 40.93218769861589
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4793,
#         "NAME": "Washington Township Fire District Headquarters",
#         "ADDRESS": "213 East Holly Avenue",
#         "CITY": "Sewell",
#         "STATE": "NJ",
#         "ZIPCODE": "08080"
#       },
#       "geometry": {
#         "x": -75.10688434064181,
#         "y": 39.745731125879516
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4794,
#         "NAME": "Kendall Park Volunteer Fire Company Substation",
#         "ADDRESS": "123 Henderson Road",
#         "CITY": "Kendall Park",
#         "STATE": "NJ",
#         "ZIPCODE": "08824"
#       },
#       "geometry": {
#         "x": -74.53100229875146,
#         "y": 40.425937981254904
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4800,
#         "NAME": "Liberty Fire Company 2",
#         "ADDRESS": "52 5th Street",
#         "CITY": "Salem",
#         "STATE": "NJ",
#         "ZIPCODE": "08079"
#       },
#       "geometry": {
#         "x": -75.46918917129257,
#         "y": 39.574332317436856
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4801,
#         "NAME": "Livingston Fire Department Circle Station",
#         "ADDRESS": "375 West Northfield Road",
#         "CITY": "Livingston",
#         "STATE": "NJ",
#         "ZIPCODE": "07039"
#       },
#       "geometry": {
#         "x": -74.34043434623828,
#         "y": 40.79496648690624
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4804,
#         "NAME": "Erma Volunteer Fire Company",
#         "ADDRESS": "415 Breakwater Road",
#         "CITY": "Cape May",
#         "STATE": "NJ",
#         "ZIPCODE": "08204"
#       },
#       "geometry": {
#         "x": -74.90867813488751,
#         "y": 39.001264382930934
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4805,
#         "NAME": "Shiloh Fire and Rescue",
#         "ADDRESS": "900 Main Street",
#         "CITY": "Shiloh",
#         "STATE": "NJ",
#         "ZIPCODE": "08353"
#       },
#       "geometry": {
#         "x": -75.29639888296715,
#         "y": 39.45677976170362
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4809,
#         "NAME": "East Greenwich Fire Department East Greenwich Fire Company",
#         "ADDRESS": "5 West Cohawkin Road",
#         "CITY": "Clarksboro",
#         "STATE": "NJ",
#         "ZIPCODE": "08020"
#       },
#       "geometry": {
#         "x": -75.22485017478435,
#         "y": 39.8000961042891
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4810,
#         "NAME": "Denville Volunteer Fire and Rescue Company 3",
#         "ADDRESS": "2 River Road",
#         "CITY": "Denville",
#         "STATE": "NJ",
#         "ZIPCODE": "07834"
#       },
#       "geometry": {
#         "x": -74.46354651620571,
#         "y": 40.904731303726905
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4811,
#         "NAME": "East Windsor Volunteer Fire Company 2",
#         "ADDRESS": "69 Twin Rivers Drive",
#         "CITY": "East Windsor",
#         "STATE": "NJ",
#         "ZIPCODE": "08520"
#       },
#       "geometry": {
#         "x": -74.49369521337148,
#         "y": 40.26065033251366
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4832,
#         "NAME": "Hurffville Fire Company - Substation",
#         "ADDRESS": "Altair Drive And Theis Road",
#         "CITY": "Sewell",
#         "STATE": "NJ",
#         "ZIPCODE": "08080"
#       },
#       "geometry": {
#         "x": -75.07540082969881,
#         "y": 39.72844772357797
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4848,
#         "NAME": "Montclair Fire Department Station 1",
#         "ADDRESS": "1 Pine Street",
#         "CITY": "Montclair",
#         "STATE": "NJ",
#         "ZIPCODE": "07042"
#       },
#       "geometry": {
#         "x": -74.20955651990084,
#         "y": 40.807275967902356
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4852,
#         "NAME": "Mauricetown Volunteer Fire Department",
#         "ADDRESS": "9544 Noble Street",
#         "CITY": "Mauricetown",
#         "STATE": "NJ",
#         "ZIPCODE": "08329"
#       },
#       "geometry": {
#         "x": -74.99645667249855,
#         "y": 39.28501467652822
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4857,
#         "NAME": "Harrisonville Fire Company",
#         "ADDRESS": "30 Main Street",
#         "CITY": "Harrisonville",
#         "STATE": "NJ",
#         "ZIPCODE": "08039"
#       },
#       "geometry": {
#         "x": -75.26668848741024,
#         "y": 39.687464808616085
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4865,
#         "NAME": "Delaware Gardens Volunteer Fire Company, No. 1",
#         "ADDRESS": "540 49th Street",
#         "CITY": "Pennsauken",
#         "STATE": "NJ",
#         "ZIPCODE": "08110"
#       },
#       "geometry": {
#         "x": -75.06963374207865,
#         "y": 39.964348571448355
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4867,
#         "NAME": "Vineland Fire Department Station 5",
#         "ADDRESS": "4450 Italia Avenue",
#         "CITY": "Vineland",
#         "STATE": "NJ",
#         "ZIPCODE": "08361"
#       },
#       "geometry": {
#         "x": -74.9446389998169,
#         "y": 39.460856913523074
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4879,
#         "NAME": "Parsippany Troy Hills District 6 Volunteer Fire Department",
#         "ADDRESS": "60 Littleton Road",
#         "CITY": "Parsippany",
#         "STATE": "NJ",
#         "ZIPCODE": "07054"
#       },
#       "geometry": {
#         "x": -74.41634245822013,
#         "y": 40.86732322944425
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4911,
#         "NAME": "Daretown Fire Company",
#         "ADDRESS": "25 Woodstown Daretown Road",
#         "CITY": "Elmer",
#         "STATE": "NJ",
#         "ZIPCODE": "08318"
#       },
#       "geometry": {
#         "x": -75.25937001772984,
#         "y": 39.60602048959351
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4916,
#         "NAME": "Pennsville Fire and Rescue 1",
#         "ADDRESS": "91 1st Street",
#         "CITY": "Pennsville",
#         "STATE": "NJ",
#         "ZIPCODE": "08070"
#       },
#       "geometry": {
#         "x": -75.51966415093618,
#         "y": 39.64774769476084
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4929,
#         "NAME": "Rockaway Township Fire Department White Meadow Lake Fire Company 5",
#         "ADDRESS": "1 Pawnee Avenue",
#         "CITY": "Rockaway",
#         "STATE": "NJ",
#         "ZIPCODE": "07866"
#       },
#       "geometry": {
#         "x": -74.50932029211239,
#         "y": 40.91936997053102
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4931,
#         "NAME": "Rockaway Borough Fire Department",
#         "ADDRESS": "1 East Main Street",
#         "CITY": "Rockaway",
#         "STATE": "NJ",
#         "ZIPCODE": "07866"
#       },
#       "geometry": {
#         "x": -74.51201972615324,
#         "y": 40.90028292925052
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4932,
#         "NAME": "Pine Brook Volunteer Fire Station 2",
#         "ADDRESS": "77 Konner Avenue",
#         "CITY": "Pine Brook",
#         "STATE": "NJ",
#         "ZIPCODE": "07058"
#       },
#       "geometry": {
#         "x": -74.35108716065226,
#         "y": 40.87210988687048
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4958,
#         "NAME": "Rio Grand Volunteer Fire Station 72",
#         "ADDRESS": "1120 Route 47 South",
#         "CITY": "Rio Grande",
#         "STATE": "NJ",
#         "ZIPCODE": "08242"
#       },
#       "geometry": {
#         "x": -74.87763512597655,
#         "y": 39.01563178690805
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4963,
#         "NAME": "CALDWELL FIRE DEPARTMENT",
#         "ADDRESS": "30 Roseland Avenue",
#         "CITY": "Caldwell",
#         "STATE": "NJ",
#         "ZIPCODE": "07006"
#       },
#       "geometry": {
#         "x": -74.2755951428255,
#         "y": 40.83794027149452
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4969,
#         "NAME": "Elsinboro Fire Company",
#         "ADDRESS": "35 Delaware Avenue",
#         "CITY": "Salem",
#         "STATE": "NJ",
#         "ZIPCODE": "08079"
#       },
#       "geometry": {
#         "x": -75.51794118534879,
#         "y": 39.553743644924914
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4970,
#         "NAME": "Scotch Plains Fire Department Station 2",
#         "ADDRESS": "1910 Raritan Road",
#         "CITY": "Scotch Plains",
#         "STATE": "NJ",
#         "ZIPCODE": "07076"
#       },
#       "geometry": {
#         "x": -74.35240023110362,
#         "y": 40.62227009462361
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4972,
#         "NAME": "East Hanover Fire Department",
#         "ADDRESS": "323 Ridgedale Avenue",
#         "CITY": "East Hanover",
#         "STATE": "NJ",
#         "ZIPCODE": "07936"
#       },
#       "geometry": {
#         "x": -74.36596439451378,
#         "y": 40.820961821237205
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4974,
#         "NAME": "West Orange Fire Department Station 4",
#         "ADDRESS": "280 Pleasant Valley Way",
#         "CITY": "West Orange",
#         "STATE": "NJ",
#         "ZIPCODE": "07052"
#       },
#       "geometry": {
#         "x": -74.25636940720923,
#         "y": 40.8157566605916
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4975,
#         "NAME": "East Greenwich Fire Department Mount Royal Fire Company - Mantua Station",
#         "ADDRESS": "5 Mantua Road",
#         "CITY": "Mount Royal",
#         "STATE": "NJ",
#         "ZIPCODE": "08061"
#       },
#       "geometry": {
#         "x": -75.21136067734103,
#         "y": 39.80923373470503
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4985,
#         "NAME": "Roseland Volunteer Fire Department",
#         "ADDRESS": "300 Eagle Rock Avenue",
#         "CITY": "Roseland",
#         "STATE": "NJ",
#         "ZIPCODE": "07068"
#       },
#       "geometry": {
#         "x": -74.30876319396793,
#         "y": 40.820304397108096
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4986,
#         "NAME": "Lower Alloways Creek Fire and Rescue Company Station 2",
#         "ADDRESS": "773 Smick Road",
#         "CITY": "Salem",
#         "STATE": "NJ",
#         "ZIPCODE": "08079"
#       },
#       "geometry": {
#         "x": -75.41428923864356,
#         "y": 39.473310903490145
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4988,
#         "NAME": "Denville Volunteer Fire and Rescue Company 2",
#         "ADDRESS": "390 Franklin Road",
#         "CITY": "Denville",
#         "STATE": "NJ",
#         "ZIPCODE": "07834"
#       },
#       "geometry": {
#         "x": -74.51931411109531,
#         "y": 40.87218899648006
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4992,
#         "NAME": "Ogdensburg Fire Department",
#         "ADDRESS": "30 Main Street",
#         "CITY": "Ogdensburg",
#         "STATE": "NJ",
#         "ZIPCODE": "07439"
#       },
#       "geometry": {
#         "x": -74.5917028589031,
#         "y": 41.08359070749822
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 4999,
#         "NAME": "Bloomfield Park Volunteer Fire Company 1",
#         "ADDRESS": "5301 Lexington Avenue",
#         "CITY": "Pennsauken",
#         "STATE": "NJ",
#         "ZIPCODE": "08109"
#       },
#       "geometry": {
#         "x": -75.05657986357147,
#         "y": 39.93997460461139
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5000,
#         "NAME": "Possumtown Volunteer Fire Company",
#         "ADDRESS": "85 Stratton Street South",
#         "CITY": "Piscataway",
#         "STATE": "NJ",
#         "ZIPCODE": "08854"
#       },
#       "geometry": {
#         "x": -74.49428213465407,
#         "y": 40.55645752260102
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5018,
#         "NAME": "New Providence Fire Department",
#         "ADDRESS": "175 Floral Avenue",
#         "CITY": "New Providence",
#         "STATE": "NJ",
#         "ZIPCODE": "07974"
#       },
#       "geometry": {
#         "x": -74.40879157120432,
#         "y": 40.6950282421736
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5019,
#         "NAME": "North Plainfield Fire Department",
#         "ADDRESS": "8 Lincoln Place",
#         "CITY": "North Plainfield",
#         "STATE": "NJ",
#         "ZIPCODE": "07060"
#       },
#       "geometry": {
#         "x": -74.42831881659309,
#         "y": 40.620651505151365
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5028,
#         "NAME": "Parsippany Troy Hills Department Station 2",
#         "ADDRESS": "200 South Beverwyck Road",
#         "CITY": "Parsippany",
#         "STATE": "NJ",
#         "ZIPCODE": "07054"
#       },
#       "geometry": {
#         "x": -74.38860510393722,
#         "y": 40.85670863671837
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5030,
#         "NAME": "Cinnaminson Fire Department Station 201",
#         "ADDRESS": "1725 Cinnaminson Avenue",
#         "CITY": "Cinnaminson",
#         "STATE": "NJ",
#         "ZIPCODE": "08077"
#       },
#       "geometry": {
#         "x": -75.01255051937731,
#         "y": 39.98994154937036
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5031,
#         "NAME": "Denville Volunteer Fire and Rescue Company 1",
#         "ADDRESS": "2 Indian Road",
#         "CITY": "Denville",
#         "STATE": "NJ",
#         "ZIPCODE": "07834"
#       },
#       "geometry": {
#         "x": -74.4792144015009,
#         "y": 40.889608017952455
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5040,
#         "NAME": "Mantua Township Fire Department Main Station",
#         "ADDRESS": "155 Union Avenue",
#         "CITY": "Sewell",
#         "STATE": "NJ",
#         "ZIPCODE": "08080"
#       },
#       "geometry": {
#         "x": -75.1418295528653,
#         "y": 39.7661613286764
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5041,
#         "NAME": "Gouldtown Fire Department Fairfield Township Fire Company 2",
#         "ADDRESS": "1137 Bridgeton-Millville Pike",
#         "CITY": "Bridgeton",
#         "STATE": "NJ",
#         "ZIPCODE": "08302"
#       },
#       "geometry": {
#         "x": -75.18116544461614,
#         "y": 39.41982115843135
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5043,
#         "NAME": "Alloway Township Fire Company",
#         "ADDRESS": "17 East Main Street",
#         "CITY": "Alloway",
#         "STATE": "NJ",
#         "ZIPCODE": "08001"
#       },
#       "geometry": {
#         "x": -75.36091046984427,
#         "y": 39.56103058535226
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5044,
#         "NAME": "Paulsboro Volunteer Fire Company",
#         "ADDRESS": "1524 SWEDESBORO AVE",
#         "CITY": "Paulsboro",
#         "STATE": "NJ",
#         "ZIPCODE": "08066"
#       },
#       "geometry": {
#         "x": -75.24114688789626,
#         "y": 39.82878053749737
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5050,
#         "NAME": "Woodbury Heights Fire Department",
#         "ADDRESS": "534 Elm Avenue",
#         "CITY": "Woodbury Heights",
#         "STATE": "NJ",
#         "ZIPCODE": "08097"
#       },
#       "geometry": {
#         "x": -75.15097495259138,
#         "y": 39.81764831040952
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5051,
#         "NAME": "Warren Township Volunteer Fire Department - Community Fire Company #3",
#         "ADDRESS": "14 Community Place",
#         "CITY": "Warren",
#         "STATE": "NJ",
#         "ZIPCODE": "07059"
#       },
#       "geometry": {
#         "x": -74.47675979484393,
#         "y": 40.64342792660208
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5052,
#         "NAME": "Jefferson Township Fire Department Company 1",
#         "ADDRESS": "162 Milton Road",
#         "CITY": "Oak Ridge",
#         "STATE": "NJ",
#         "ZIPCODE": "07438"
#       },
#       "geometry": {
#         "x": -74.52713143437619,
#         "y": 41.021051497813374
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5070,
#         "NAME": "Randolph Township Fire Department Chemical Engine Company 4 Ironia",
#         "ADDRESS": "331 Dover Chester Road",
#         "CITY": "Randolph",
#         "STATE": "NJ",
#         "ZIPCODE": "07869"
#       },
#       "geometry": {
#         "x": -74.61554295048246,
#         "y": 40.82918545762184
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5078,
#         "NAME": "Washington Township Fire Department Station 10 - 1 Grenloch Fire Company Substation",
#         "ADDRESS": "233 Greentree Road",
#         "CITY": "Turnersville",
#         "STATE": "NJ",
#         "ZIPCODE": "08012"
#       },
#       "geometry": {
#         "x": -75.06587702826702,
#         "y": 39.75462802910504
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5091,
#         "NAME": "Lake Hiawatha Volunteer Fire Department",
#         "ADDRESS": "39 North Beverwyck Road",
#         "CITY": "Lake Hiawatha",
#         "STATE": "NJ",
#         "ZIPCODE": "07034"
#       },
#       "geometry": {
#         "x": -74.38276277951387,
#         "y": 40.87918947564792
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5097,
#         "NAME": "West Cape May Volunteer Fire Company",
#         "ADDRESS": "732 Broadway",
#         "CITY": "West Cape May",
#         "STATE": "NJ",
#         "ZIPCODE": "08204"
#       },
#       "geometry": {
#         "x": -74.93013063827715,
#         "y": 38.94273677036364
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5102,
#         "NAME": "Belleville Fire Department Station 2",
#         "ADDRESS": "434 Washington Avenue",
#         "CITY": "Belleville",
#         "STATE": "NJ",
#         "ZIPCODE": "07109"
#       },
#       "geometry": {
#         "x": -74.14888129880893,
#         "y": 40.79554506777757
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5133,
#         "NAME": "Brooklawn Fire Company",
#         "ADDRESS": "110 South Wilson Avenue",
#         "CITY": "Brooklawn",
#         "STATE": "NJ",
#         "ZIPCODE": "08030"
#       },
#       "geometry": {
#         "x": -75.12236390867024,
#         "y": 39.877822522281726
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5176,
#         "NAME": "Harding Township Fire Department",
#         "ADDRESS": "139 Baileys Mill Road",
#         "CITY": "New Vernon",
#         "STATE": "NJ",
#         "ZIPCODE": "07976"
#       },
#       "geometry": {
#         "x": -74.53055764617116,
#         "y": 40.74224056885191
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5177,
#         "NAME": "Jackson Mills Volunteer Fire Company Station 2",
#         "ADDRESS": "550 West Commodore Boulevard",
#         "CITY": "Jackson",
#         "STATE": "NJ",
#         "ZIPCODE": "08527"
#       },
#       "geometry": {
#         "x": -74.38986206070989,
#         "y": 40.15676498451146
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5182,
#         "NAME": "Moorestown Hose Company Number 1 Fire Station",
#         "ADDRESS": "261 West Main Street",
#         "CITY": "Moorestown",
#         "STATE": "NJ",
#         "ZIPCODE": "08057"
#       },
#       "geometry": {
#         "x": -74.95288749988327,
#         "y": 39.961538700072545
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5192,
#         "NAME": "Tri - County Volunteer Fire Company",
#         "ADDRESS": "1720 State Highway 57",
#         "CITY": "Hackettstown",
#         "STATE": "NJ",
#         "ZIPCODE": "07840"
#       },
#       "geometry": {
#         "x": -74.8491117339373,
#         "y": 40.81012767672853
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5197,
#         "NAME": "Riverside Township Fire District 1 Riverside Fire Company 1",
#         "ADDRESS": "4 Scott Street",
#         "CITY": "Riverside",
#         "STATE": "NJ",
#         "ZIPCODE": "08075"
#       },
#       "geometry": {
#         "x": -74.96041582976818,
#         "y": 40.03752923873233
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5204,
#         "NAME": "Berkeley Heights Rescue Squad",
#         "ADDRESS": "378 Snyder Avenue",
#         "CITY": "Berkeley Heights",
#         "STATE": "NJ",
#         "ZIPCODE": "07922"
#       },
#       "geometry": {
#         "x": -74.43028819996412,
#         "y": 40.678907199735455
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5205,
#         "NAME": "Piscataway Township Fire District 2 River Road Fire Company Station 650",
#         "ADDRESS": "102 Netherwood Avenue",
#         "CITY": "Piscataway",
#         "STATE": "NJ",
#         "ZIPCODE": "08854"
#       },
#       "geometry": {
#         "x": -74.49802954211505,
#         "y": 40.53979223588827
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5206,
#         "NAME": "Upper Deerfield Township Fire Company Station 2 Seabrook Fire and Rescue",
#         "ADDRESS": "90 Foster Road",
#         "CITY": "Seabrook",
#         "STATE": "NJ",
#         "ZIPCODE": "08302"
#       },
#       "geometry": {
#         "x": -75.22641529049541,
#         "y": 39.49742551083757
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5207,
#         "NAME": "West Orange Fire Department Fire House 3",
#         "ADDRESS": "93 Ridgeway Avenue",
#         "CITY": "West Orange",
#         "STATE": "NJ",
#         "ZIPCODE": "07052"
#       },
#       "geometry": {
#         "x": -74.26695376110897,
#         "y": 40.773554571829564
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5212,
#         "NAME": "Mount Tabor Fire Department Powder Mill Firehouse",
#         "ADDRESS": "72 South Powder Mill Road",
#         "CITY": "Morris Plains",
#         "STATE": "NJ",
#         "ZIPCODE": "07950"
#       },
#       "geometry": {
#         "x": -74.49103025120411,
#         "y": 40.857932293700564
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5218,
#         "NAME": "Repaupo Volunteer Fire Company",
#         "ADDRESS": "7 Repaupo Station Road",
#         "CITY": "Swedesboro",
#         "STATE": "NJ",
#         "ZIPCODE": "08085"
#       },
#       "geometry": {
#         "x": -75.29950293162456,
#         "y": 39.80043430167099
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5219,
#         "NAME": "Billingsport Volunteer Fire Company",
#         "ADDRESS": "437 Billingsport Road",
#         "CITY": "Paulsboro",
#         "STATE": "NJ",
#         "ZIPCODE": "08066"
#       },
#       "geometry": {
#         "x": -75.24661158943593,
#         "y": 39.84301272865349
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5220,
#         "NAME": "Hopewell - Stow Creek Fire Department",
#         "ADDRESS": "751 Roadstown Road",
#         "CITY": "Bridgeton",
#         "STATE": "NJ",
#         "ZIPCODE": "08302"
#       },
#       "geometry": {
#         "x": -75.31801243152083,
#         "y": 39.441006552580305
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5221,
#         "NAME": "Towaco Fire Department Station 2",
#         "ADDRESS": "10 Passaic Valley Road",
#         "CITY": "Towaco",
#         "STATE": "NJ",
#         "ZIPCODE": "07082"
#       },
#       "geometry": {
#         "x": -74.36110837416997,
#         "y": 40.904202382296695
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5232,
#         "NAME": "Delaware Park Chemical Engine Company 1",
#         "ADDRESS": "112 Park Avenue",
#         "CITY": "Phillipsburg",
#         "STATE": "NJ",
#         "ZIPCODE": "08865"
#       },
#       "geometry": {
#         "x": -75.19118504607071,
#         "y": 40.702600868437926
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5239,
#         "NAME": "Downe Township Fire and Rescue Fortescue Company 1 - Station 39",
#         "ADDRESS": "10 Vassar Avenue",
#         "CITY": "Fortescue",
#         "STATE": "NJ",
#         "ZIPCODE": "08321"
#       },
#       "geometry": {
#         "x": -75.16946383039627,
#         "y": 39.239972321828134
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5245,
#         "NAME": "Madison Fire Department",
#         "ADDRESS": "50 Kings Road",
#         "CITY": "Madison",
#         "STATE": "NJ",
#         "ZIPCODE": "07940"
#       },
#       "geometry": {
#         "x": -74.41492948211013,
#         "y": 40.75578295061459
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5251,
#         "NAME": "Maurice River Township Fire District #4 - Cumberland Station 23",
#         "ADDRESS": "5272 State Highway 49",
#         "CITY": "Millville",
#         "STATE": "NJ",
#         "ZIPCODE": "08332"
#       },
#       "geometry": {
#         "x": -74.93608576456599,
#         "y": 39.36706045653593
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5265,
#         "NAME": "New Milford Fire Department Company 1",
#         "ADDRESS": "249 Center Street",
#         "CITY": "New Milford",
#         "STATE": "NJ",
#         "ZIPCODE": "07646"
#       },
#       "geometry": {
#         "x": -74.01782906647371,
#         "y": 40.949754902256714
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5267,
#         "NAME": "Washington Township Fire Department - Grenloch Fire Company Main Station",
#         "ADDRESS": "441 Hurffville Grenloch Road",
#         "CITY": "Sewell",
#         "STATE": "NJ",
#         "ZIPCODE": "08080"
#       },
#       "geometry": {
#         "x": -75.06565942932005,
#         "y": 39.77335653282183
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5290,
#         "NAME": "Princeton Plasma Physics Lab Fire Department",
#         "ADDRESS": "US Highway 1 North",
#         "CITY": "Plainsboro",
#         "STATE": "NJ",
#         "ZIPCODE": "08543"
#       },
#       "geometry": {
#         "x": -74.60124631622973,
#         "y": 40.34721456336564
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5296,
#         "NAME": "Minotola Volunteer Fire Company",
#         "ADDRESS": "255 Wheat Road",
#         "CITY": "Minotola",
#         "STATE": "NJ",
#         "ZIPCODE": "08341"
#       },
#       "geometry": {
#         "x": -74.95250217816836,
#         "y": 39.51134688477731
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5297,
#         "NAME": "Princeton Hook and Ladder Company",
#         "ADDRESS": "27 North Harrison Street",
#         "CITY": "Princeton",
#         "STATE": "NJ",
#         "ZIPCODE": "08540"
#       },
#       "geometry": {
#         "x": -74.64586699125222,
#         "y": 40.35490100702955
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5306,
#         "NAME": "Greenwich Township Fire and Rescue",
#         "ADDRESS": "991 Ye Greate Street",
#         "CITY": "Greenwich",
#         "STATE": "NJ",
#         "ZIPCODE": "08323"
#       },
#       "geometry": {
#         "x": -75.33982472911094,
#         "y": 39.39037744482872
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5321,
#         "NAME": "National Park Fire Department",
#         "ADDRESS": "523 Hessian Avenue",
#         "CITY": "National Park",
#         "STATE": "NJ",
#         "ZIPCODE": "08063"
#       },
#       "geometry": {
#         "x": -75.18012873241811,
#         "y": 39.86633114085659
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5324,
#         "NAME": "Dumont Fire Department Independent Company",
#         "ADDRESS": "162 Veterans Plaza",
#         "CITY": "Dumont",
#         "STATE": "NJ",
#         "ZIPCODE": "07628"
#       },
#       "geometry": {
#         "x": -73.99690630617624,
#         "y": 40.94171052019058
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5325,
#         "NAME": "Vineland Fire Department Station 4",
#         "ADDRESS": "1500 East Oak Road",
#         "CITY": "Vineland",
#         "STATE": "NJ",
#         "ZIPCODE": "08360"
#       },
#       "geometry": {
#         "x": -74.99646775173679,
#         "y": 39.499947319494666
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5334,
#         "NAME": "Port Elizabeth Fire Department",
#         "ADDRESS": "7 Port Elizabeth Cumberland Road",
#         "CITY": "Port Elizabeth",
#         "STATE": "NJ",
#         "ZIPCODE": "08348"
#       },
#       "geometry": {
#         "x": -74.98173460256083,
#         "y": 39.308238881698564
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5337,
#         "NAME": "Quinton Fire Company",
#         "ADDRESS": "42 Main Street",
#         "CITY": "Quinton",
#         "STATE": "NJ",
#         "ZIPCODE": "08072"
#       },
#       "geometry": {
#         "x": -75.41169708484179,
#         "y": 39.54528818040129
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5338,
#         "NAME": "Upper Deerfield Township Fire Company Station 3 Carlls Corner",
#         "ADDRESS": "69 Cornwell Drive",
#         "CITY": "Bridgeton",
#         "STATE": "NJ",
#         "ZIPCODE": "08302"
#       },
#       "geometry": {
#         "x": -75.21705161869455,
#         "y": 39.460394437125096
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5355,
#         "NAME": "West Orange Fire Department Fire House 1",
#         "ADDRESS": "415 Valley Road",
#         "CITY": "West Orange",
#         "STATE": "NJ",
#         "ZIPCODE": "07052"
#       },
#       "geometry": {
#         "x": -74.24124487684685,
#         "y": 40.77299592055049
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5356,
#         "NAME": "Forest Grove Volunteer Fire Company",
#         "ADDRESS": "1635 Forest Grove Road",
#         "CITY": "Vineland",
#         "STATE": "NJ",
#         "ZIPCODE": "08360"
#       },
#       "geometry": {
#         "x": -74.9846892831109,
#         "y": 39.529566392481115
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5363,
#         "NAME": "Moorestown Hose Company Number 1 Fire Station",
#         "ADDRESS": "261 West Main Street",
#         "CITY": "Moorestown",
#         "STATE": "NJ",
#         "ZIPCODE": "08057"
#       },
#       "geometry": {
#         "x": -74.95288923217595,
#         "y": 39.96154681257409
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5366,
#         "NAME": "Dividing Creek Fire Company",
#         "ADDRESS": "529 CHURCH ST",
#         "CITY": "Port Norris",
#         "STATE": "NJ",
#         "ZIPCODE": "08349"
#       },
#       "geometry": {
#         "x": -75.10085571084149,
#         "y": 39.27358833202584
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5368,
#         "NAME": "Rockaway Township Fire Department Mount Hope Fire Company 2",
#         "ADDRESS": "600 Mount Hope Road",
#         "CITY": "Wharton",
#         "STATE": "NJ",
#         "ZIPCODE": "07885"
#       },
#       "geometry": {
#         "x": -74.54275008866661,
#         "y": 40.92725503334769
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5373,
#         "NAME": "Ewan Volunteer Fire Company",
#         "ADDRESS": "312 Ewan Road",
#         "CITY": "Ewan",
#         "STATE": "NJ",
#         "ZIPCODE": "08062"
#       },
#       "geometry": {
#         "x": -75.18915126372796,
#         "y": 39.699080113695295
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5374,
#         "NAME": "Montclair Fire Department Station 2",
#         "ADDRESS": "588 Valley Road",
#         "CITY": "Montclair",
#         "STATE": "NJ",
#         "ZIPCODE": "07043"
#       },
#       "geometry": {
#         "x": -74.20815942149372,
#         "y": 40.84042457437211
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5384,
#         "NAME": "Auburn Volunteer Fire Company",
#         "ADDRESS": "76 Main Street",
#         "CITY": "Auburn",
#         "STATE": "NJ",
#         "ZIPCODE": "08085"
#       },
#       "geometry": {
#         "x": -75.36724674751356,
#         "y": 39.710956548197714
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5385,
#         "NAME": "Woolwich Fire Department",
#         "ADDRESS": "1517 Kings Highway",
#         "CITY": "Swedesboro",
#         "STATE": "NJ",
#         "ZIPCODE": "08085"
#       },
#       "geometry": {
#         "x": -75.31191407809885,
#         "y": 39.74647617180364
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5386,
#         "NAME": "Palmyra Fire Department Independence Fire Company 1",
#         "ADDRESS": "115 West Broad Street",
#         "CITY": "Palmyra",
#         "STATE": "NJ",
#         "ZIPCODE": "08065"
#       },
#       "geometry": {
#         "x": -75.02373277162897,
#         "y": 40.003277074512866
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5392,
#         "NAME": "Heislerville Volunteer Fire Company",
#         "ADDRESS": "164 Main Street",
#         "CITY": "Heislerville",
#         "STATE": "NJ",
#         "ZIPCODE": "08324"
#       },
#       "geometry": {
#         "x": -74.99190526782685,
#         "y": 39.229111932142395
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5393,
#         "NAME": "Centerton Fire Company",
#         "ADDRESS": "64 Dealtown Road",
#         "CITY": "Pittsgrove",
#         "STATE": "NJ",
#         "ZIPCODE": "08318"
#       },
#       "geometry": {
#         "x": -75.16716894050212,
#         "y": 39.53025258614946
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5394,
#         "NAME": "Washington Township Fire Department Station 10 - 3 Hurffville Fire Company",
#         "ADDRESS": "213 East Holly Avenue",
#         "CITY": "Sewell",
#         "STATE": "NJ",
#         "ZIPCODE": "08080"
#       },
#       "geometry": {
#         "x": -75.10694773441573,
#         "y": 39.74579663109863
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5406,
#         "NAME": "Chatham Township Volunteer Fire Department Station 2",
#         "ADDRESS": "172 Southern Boulevard",
#         "CITY": "Chatham",
#         "STATE": "NJ",
#         "ZIPCODE": "07928"
#       },
#       "geometry": {
#         "x": -74.41207167227716,
#         "y": 40.72933262996313
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5413,
#         "NAME": "Victory Gardens Fire Department",
#         "ADDRESS": "425 Washington Avenue",
#         "CITY": "Dover",
#         "STATE": "NJ",
#         "ZIPCODE": "07801"
#       },
#       "geometry": {
#         "x": -74.54385501082434,
#         "y": 40.876223331792715
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5418,
#         "NAME": "Washington Township Fire Department - Whitman Square Substation",
#         "ADDRESS": "131 Johnson Road",
#         "CITY": "Turnersville",
#         "STATE": "NJ",
#         "ZIPCODE": "08012"
#       },
#       "geometry": {
#         "x": -75.04256042047399,
#         "y": 39.74705922843649
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5436,
#         "NAME": "Sicklerville Volunteer Fire Co Fire Station",
#         "ADDRESS": "520 Church Road",
#         "CITY": "Sicklerville",
#         "STATE": "NJ",
#         "ZIPCODE": "08081"
#       },
#       "geometry": {
#         "x": -74.97704315230669,
#         "y": 39.71844863863583
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5437,
#         "NAME": "Mount Tabor Fire Department Tarn Firehouse",
#         "ADDRESS": "909 Tabor Road",
#         "CITY": "Morris Plains",
#         "STATE": "NJ",
#         "ZIPCODE": "07950"
#       },
#       "geometry": {
#         "x": -74.46959561751515,
#         "y": 40.8614174118103
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5448,
#         "NAME": "Downe Township Fire and Rescue Newport Volunteer Fire Department",
#         "ADDRESS": "14 Hall Street",
#         "CITY": "Newport",
#         "STATE": "NJ",
#         "ZIPCODE": "08345"
#       },
#       "geometry": {
#         "x": -75.17651549003493,
#         "y": 39.29576856504864
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5450,
#         "NAME": "Mannington Volunteer Fire Company Station 1",
#         "ADDRESS": "175 Salem Woodstown Road",
#         "CITY": "Salem",
#         "STATE": "NJ",
#         "ZIPCODE": "08079"
#       },
#       "geometry": {
#         "x": -75.4539998340112,
#         "y": 39.587943187352664
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5454,
#         "NAME": "Surf City Volunteer Fire Company 1 and Emergency Medical Services",
#         "ADDRESS": "713 Long Beach Boulevard",
#         "CITY": "Surf City",
#         "STATE": "NJ",
#         "ZIPCODE": "08008"
#       },
#       "geometry": {
#         "x": -74.1680051374729,
#         "y": 39.659912541710796
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5478,
#         "NAME": "Randolph Township Fire Department Chemical Engine Company 3 Mount Freedom",
#         "ADDRESS": "670 Millbrook Avenue",
#         "CITY": "Randolph",
#         "STATE": "NJ",
#         "ZIPCODE": "07869"
#       },
#       "geometry": {
#         "x": -74.57375233734906,
#         "y": 40.83172305961839
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5490,
#         "NAME": "City of Orange Township Fire Department",
#         "ADDRESS": "419 Central Avenue",
#         "CITY": "Orange",
#         "STATE": "NJ",
#         "ZIPCODE": "07050"
#       },
#       "geometry": {
#         "x": -74.23870190069671,
#         "y": 40.767450098731935
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5491,
#         "NAME": "Ferrell Volunteer Fire Company and Rescue",
#         "ADDRESS": "186 Elk Road",
#         "CITY": "Monroeville",
#         "STATE": "NJ",
#         "ZIPCODE": "08343"
#       },
#       "geometry": {
#         "x": -75.19987345839253,
#         "y": 39.675453347168656
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5493,
#         "NAME": "Gloucester City Fire Department Station 51 Headquarters",
#         "ADDRESS": "1 North King Street",
#         "CITY": "Gloucester City",
#         "STATE": "NJ",
#         "ZIPCODE": "08030"
#       },
#       "geometry": {
#         "x": -75.12531961609646,
#         "y": 39.89911312741973
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5514,
#         "NAME": "Sparta Township Fire Department",
#         "ADDRESS": "141 Woodport Road",
#         "CITY": "Sparta",
#         "STATE": "NJ",
#         "ZIPCODE": "07871"
#       },
#       "geometry": {
#         "x": -74.6311649679445,
#         "y": 41.02781069534777
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5535,
#         "NAME": "Cedar Grove Fire Department South End Company 3",
#         "ADDRESS": "148 Pompton Avenue",
#         "CITY": "Cedar Grove",
#         "STATE": "NJ",
#         "ZIPCODE": "07009"
#       },
#       "geometry": {
#         "x": -74.22783712764772,
#         "y": 40.838540673308714
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5540,
#         "NAME": "Port Norris Fire Company 1",
#         "ADDRESS": "6858 Brown Street",
#         "CITY": "Port Norris",
#         "STATE": "NJ",
#         "ZIPCODE": "08349"
#       },
#       "geometry": {
#         "x": -75.03035127466578,
#         "y": 39.24681580622115
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5556,
#         "NAME": "Willow Grove Fire Company",
#         "ADDRESS": "879 Willow Grove Road",
#         "CITY": "Pittsgrove",
#         "STATE": "NJ",
#         "ZIPCODE": "08318"
#       },
#       "geometry": {
#         "x": -75.09126502469834,
#         "y": 39.56058708967594
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 5557,
#         "NAME": "Franklin Fire Department",
# ...
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51312,
#         "NAME": "Highlands Fire Department",
#         "ADDRESS": "17 - 1 Shore Drive",
#         "CITY": "Highlands",
#         "STATE": "NJ",
#         "ZIPCODE": "07732"
#       },
#       "geometry": {
#         "x": -73.98679345463115,
#         "y": 40.40057764543542
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51313,
#         "NAME": "North Centerville Volunteer Fire Company 1",
#         "ADDRESS": "372 Middle Road",
#         "CITY": "Hazlet",
#         "STATE": "NJ",
#         "ZIPCODE": "07730"
#       },
#       "geometry": {
#         "x": -74.15858583879906,
#         "y": 40.42481264210015
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51331,
#         "NAME": "Robertsville Fire Company 1",
#         "ADDRESS": "94 County Highway 520",
#         "CITY": "Morganville",
#         "STATE": "NJ",
#         "ZIPCODE": "07751"
#       },
#       "geometry": {
#         "x": -74.2961269999298,
#         "y": 40.351272999955704
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51332,
#         "NAME": "Morganville Volunteer Fire Company",
#         "ADDRESS": "78 Tennent Road",
#         "CITY": "Morganville",
#         "STATE": "NJ",
#         "ZIPCODE": "07751"
#       },
#       "geometry": {
#         "x": -74.25300600034537,
#         "y": 40.37793400044366
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51333,
#         "NAME": "Cheesequake Volunteer Fire Company Station 1",
#         "ADDRESS": "113 State Highway 34",
#         "CITY": "Matawan",
#         "STATE": "NJ",
#         "ZIPCODE": "07747"
#       },
#       "geometry": {
#         "x": -74.29212300006374,
#         "y": 40.426512000240294
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51345,
#         "NAME": "Wanamassa Fire Company Station 37 - 2",
#         "ADDRESS": "2001 Sunset Avenue",
#         "CITY": "Ocean",
#         "STATE": "NJ",
#         "ZIPCODE": "07712"
#       },
#       "geometry": {
#         "x": -74.02501667552525,
#         "y": 40.23190447348825
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51357,
#         "NAME": "Lakewood Township Fire Department Station 66",
#         "ADDRESS": "976 New Hampshire Avenue",
#         "CITY": "Lakewood",
#         "STATE": "NJ",
#         "ZIPCODE": "08701"
#       },
#       "geometry": {
#         "x": -74.19665047152112,
#         "y": 40.05357843758817
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51358,
#         "NAME": "Lakewood Township Fire Department Station 65",
#         "ADDRESS": "1350 Lanes Mill Road",
#         "CITY": "Lakewood",
#         "STATE": "NJ",
#         "ZIPCODE": "08701"
#       },
#       "geometry": {
#         "x": -74.17076900046817,
#         "y": 40.10064299985987
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51359,
#         "NAME": "Manitou Park Volunteer Fire Company Station 18",
#         "ADDRESS": "110 3rd Avenue",
#         "CITY": "Toms River",
#         "STATE": "NJ",
#         "ZIPCODE": "08757"
#       },
#       "geometry": {
#         "x": -74.21536608883697,
#         "y": 39.945942772948555
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51403,
#         "NAME": "Middletown Township Fire Department Station 8",
#         "ADDRESS": "336 State Highway 35",
#         "CITY": "Red Bank",
#         "STATE": "NJ",
#         "ZIPCODE": "07701"
#       },
#       "geometry": {
#         "x": -74.08553924869825,
#         "y": 40.36875694930065
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51405,
#         "NAME": "Fair Haven Volunteer Fire Company",
#         "ADDRESS": "645 River Road",
#         "CITY": "Fair Haven",
#         "STATE": "NJ",
#         "ZIPCODE": "07704"
#       },
#       "geometry": {
#         "x": -74.04046262880314,
#         "y": 40.362611275708566
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51415,
#         "NAME": "Jersey City Fire Department Engine 5 Ladder 6",
#         "ADDRESS": "355 Newark Avenue",
#         "CITY": "Jersey City",
#         "STATE": "NJ",
#         "ZIPCODE": "07302"
#       },
#       "geometry": {
#         "x": -74.05234500023379,
#         "y": 40.725433000282365
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51416,
#         "NAME": "Jersey City Fire Department Palisade Avenue",
#         "ADDRESS": "595 Palisade Avenue",
#         "CITY": "Jersey City",
#         "STATE": "NJ",
#         "ZIPCODE": "07307"
#       },
#       "geometry": {
#         "x": -74.04151900029372,
#         "y": 40.74889400001214
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51434,
#         "NAME": "Port - Au - Peck Volunteer Fire Company",
#         "ADDRESS": "433 Myrtle Avenue",
#         "CITY": "Oceanport",
#         "STATE": "NJ",
#         "ZIPCODE": "07757"
#       },
#       "geometry": {
#         "x": -74.01572724133933,
#         "y": 40.320154160946785
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51435,
#         "NAME": "Morganville Independent Fire Company",
#         "ADDRESS": "393 State Highway 79",
#         "CITY": "Morganville",
#         "STATE": "NJ",
#         "ZIPCODE": "07751"
#       },
#       "geometry": {
#         "x": -74.24624599997966,
#         "y": 40.37288699969272
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51440,
#         "NAME": "Jersey City Fire Department Engine 15 Ladder 9",
#         "ADDRESS": "200 Sip Avenue",
#         "CITY": "Jersey City",
#         "STATE": "NJ",
#         "ZIPCODE": "07306"
#       },
#       "geometry": {
#         "x": -74.06889299964975,
#         "y": 40.731914999917905
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51441,
#         "NAME": "Jersey City Fire Department Engine 9",
#         "ADDRESS": "697 Bergen Avenue",
#         "CITY": "Jersey City",
#         "STATE": "NJ",
#         "ZIPCODE": "07306"
#       },
#       "geometry": {
#         "x": -74.07033882463432,
#         "y": 40.724087086887934
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51442,
#         "NAME": "Jersey City Fire Department Rescue Squad 4",
#         "ADDRESS": "582 Communipaw Avenue",
#         "CITY": "Jersey City",
#         "STATE": "NJ",
#         "ZIPCODE": "07304"
#       },
#       "geometry": {
#         "x": -74.07193799972654,
#         "y": 40.71722400008139
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51443,
#         "NAME": "Jersey City Fire Company 8",
#         "ADDRESS": "1 Bergen Avenue",
#         "CITY": "Jersey City",
#         "STATE": "NJ",
#         "ZIPCODE": "07305"
#       },
#       "geometry": {
#         "x": -74.07748399997081,
#         "y": 40.709316000432736
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51451,
#         "NAME": "Lakewood Fire Department Engine Company 1 Station",
#         "ADDRESS": "119 1st Street",
#         "CITY": "Lakewood",
#         "STATE": "NJ",
#         "ZIPCODE": "08701"
#       },
#       "geometry": {
#         "x": -74.21111300023557,
#         "y": 40.09188499985376
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51628,
#         "NAME": "Ramtown Fire Company Station 19 - 4",
#         "ADDRESS": "88 Ramtown - Greenville Road",
#         "CITY": "Howell",
#         "STATE": "NJ",
#         "ZIPCODE": "07731"
#       },
#       "geometry": {
#         "x": -74.14604900008848,
#         "y": 40.12108999954328
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51634,
#         "NAME": "Manasquan Fire District 1 Manasquan Volunteer Eng Company 2",
#         "ADDRESS": "111 Parker Avenue",
#         "CITY": "Manasquan",
#         "STATE": "NJ",
#         "ZIPCODE": "08736"
#       },
#       "geometry": {
#         "x": -74.0466492448969,
#         "y": 40.125911437274915
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51635,
#         "NAME": "Carteret Fire Department",
#         "ADDRESS": "3 Pekola Terrace",
#         "CITY": "Carteret",
#         "STATE": "NJ",
#         "ZIPCODE": "07008"
#       },
#       "geometry": {
#         "x": -74.24322499979088,
#         "y": 40.59258700000281
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51636,
#         "NAME": "Linden Fire Department Station 3",
#         "ADDRESS": "1205 East Elizabeth Avenue",
#         "CITY": "Linden",
#         "STATE": "NJ",
#         "ZIPCODE": "07036"
#       },
#       "geometry": {
#         "x": -74.24040590922455,
#         "y": 40.64251860982219
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51637,
#         "NAME": "Roselle Park Fire Department Central Engine Company",
#         "ADDRESS": "607 Chestnut Street",
#         "CITY": "Roselle Park",
#         "STATE": "NJ",
#         "ZIPCODE": "07204"
#       },
#       "geometry": {
#         "x": -74.26508190509759,
#         "y": 40.668162560810856
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51638,
#         "NAME": "Newark Fire Department Engine 11",
#         "ADDRESS": "345 South 9th Street",
#         "CITY": "Newark",
#         "STATE": "NJ",
#         "ZIPCODE": "07103"
#       },
#       "geometry": {
#         "x": -74.20033300030418,
#         "y": 40.739425999862576
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51639,
#         "NAME": "Newark Fire Department Engine 13",
#         "ADDRESS": "714 Mount Prospect Avenue",
#         "CITY": "Newark",
#         "STATE": "NJ",
#         "ZIPCODE": "07104"
#       },
#       "geometry": {
#         "x": -74.16542799981406,
#         "y": 40.77690100003536
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51640,
#         "NAME": "Newark Fire Department Engine 15",
#         "ADDRESS": "269 Park Avenue",
#         "CITY": "Newark",
#         "STATE": "NJ",
#         "ZIPCODE": "07107"
#       },
#       "geometry": {
#         "x": -74.18701648478752,
#         "y": 40.75942823338214
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51641,
#         "NAME": "Newark Fire Department Engine 28",
#         "ADDRESS": "691 North 6th Street",
#         "CITY": "Newark",
#         "STATE": "NJ",
#         "ZIPCODE": "07107"
#       },
#       "geometry": {
#         "x": -74.17912578208067,
#         "y": 40.7732807071819
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51700,
#         "NAME": "Linden Fire Department Station 4",
#         "ADDRESS": "2400 South Wood Avenue",
#         "CITY": "Linden",
#         "STATE": "NJ",
#         "ZIPCODE": "07036"
#       },
#       "geometry": {
#         "x": -74.23314800024265,
#         "y": 40.618459000188274
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51701,
#         "NAME": "Linden Fire Department Station 2",
#         "ADDRESS": "302 West Saint Georges Avenue",
#         "CITY": "Linden",
#         "STATE": "NJ",
#         "ZIPCODE": "07036"
#       },
#       "geometry": {
#         "x": -74.26808936541796,
#         "y": 40.63384228840498
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51702,
#         "NAME": "Newark Fire Department Engine 19",
#         "ADDRESS": "526 Frelinghuysen Avenue",
#         "CITY": "Newark",
#         "STATE": "NJ",
#         "ZIPCODE": "07114"
#       },
#       "geometry": {
#         "x": -74.19483900048459,
#         "y": 40.70281200023835
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51703,
#         "NAME": "Newark Fire Department Engine 14",
#         "ADDRESS": "71 Vesey Street",
#         "CITY": "Newark",
#         "STATE": "NJ",
#         "ZIPCODE": "07105"
#       },
#       "geometry": {
#         "x": -74.17005900015275,
#         "y": 40.7242320000665
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51704,
#         "NAME": "Newark Fire Department Engine 18",
#         "ADDRESS": "395 Avon Avenue",
#         "CITY": "Newark",
#         "STATE": "NJ",
#         "ZIPCODE": "07103"
#       },
#       "geometry": {
#         "x": -74.20868678869375,
#         "y": 40.72751472121298
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51739,
#         "NAME": "Jersey City Fire Department",
#         "ADDRESS": "160 Grand Street",
#         "CITY": "Jersey City",
#         "STATE": "NJ",
#         "ZIPCODE": "07302"
#       },
#       "geometry": {
#         "x": -74.0411173669105,
#         "y": 40.71588721028033
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51768,
#         "NAME": "Jersey City Fire Department Engine 11",
#         "ADDRESS": "152 Lincoln Street",
#         "CITY": "Jersey City",
#         "STATE": "NJ",
#         "ZIPCODE": "07307"
#       },
#       "geometry": {
#         "x": -74.05583730176161,
#         "y": 40.7493930933553
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51769,
#         "NAME": "Jersey City Fire Department Engine 10 Ladder 12",
#         "ADDRESS": "283 Halladay Street",
#         "CITY": "Jersey City",
#         "STATE": "NJ",
#         "ZIPCODE": "07304"
#       },
#       "geometry": {
#         "x": -74.06308699973876,
#         "y": 40.71239500049594
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51770,
#         "NAME": "Jersey City Fire Department Engine 13",
#         "ADDRESS": "152 Linden Avenue",
#         "CITY": "Jersey City",
#         "STATE": "NJ",
#         "ZIPCODE": "07305"
#       },
#       "geometry": {
#         "x": -74.09233899976022,
#         "y": 40.69655999951373
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51771,
#         "NAME": "Jersey City Fire Department Engine 19 Ladder 8",
#         "ADDRESS": "2 Bergen Avenue",
#         "CITY": "Jersey City",
#         "STATE": "NJ",
#         "ZIPCODE": "07305"
#       },
#       "geometry": {
#         "x": -74.0896840003949,
#         "y": 40.70377699996842
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51806,
#         "NAME": "Port Reading Fire Department",
#         "ADDRESS": "916 West Avenue",
#         "CITY": "Port Reading",
#         "STATE": "NJ",
#         "ZIPCODE": "07064"
#       },
#       "geometry": {
#         "x": -74.25217399996909,
#         "y": 40.56582599968089
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51824,
#         "NAME": "Roselle Fire Department Headquarters",
#         "ADDRESS": "725 Chestnut Street",
#         "CITY": "Roselle",
#         "STATE": "NJ",
#         "ZIPCODE": "07203"
#       },
#       "geometry": {
#         "x": -74.26125463829686,
#         "y": 40.65178607130393
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51825,
#         "NAME": "Hillside Fire Department",
#         "ADDRESS": "395 Hollywood Avenue",
#         "CITY": "Hillside",
#         "STATE": "NJ",
#         "ZIPCODE": "07205"
#       },
#       "geometry": {
#         "x": -74.22713571624134,
#         "y": 40.690152284136346
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51826,
#         "NAME": "Newark Fire Department Engine 6",
#         "ADDRESS": "344 Springfield Avenue",
#         "CITY": "Newark",
#         "STATE": "NJ",
#         "ZIPCODE": "07103"
#       },
#       "geometry": {
#         "x": -74.19445008036942,
#         "y": 40.73364993019952
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51827,
#         "NAME": "Newark Fire Department Engine 26",
#         "ADDRESS": "420 Sanford Avenue",
#         "CITY": "Newark",
#         "STATE": "NJ",
#         "ZIPCODE": "07106"
#       },
#       "geometry": {
#         "x": -74.23170500035712,
#         "y": 40.74728000027576
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51828,
#         "NAME": "Newark Fire Department Engine 5",
#         "ADDRESS": "65 Congress Street",
#         "CITY": "Newark",
#         "STATE": "NJ",
#         "ZIPCODE": "07105"
#       },
#       "geometry": {
#         "x": -74.16196083027867,
#         "y": 40.73099700895798
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51829,
#         "NAME": "Newark Fire Department Engine 7",
#         "ADDRESS": "241 West Market Street",
#         "CITY": "Newark",
#         "STATE": "NJ",
#         "ZIPCODE": "07103"
#       },
#       "geometry": {
#         "x": -74.18660180556199,
#         "y": 40.74359855428333
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 51989,
#         "NAME": "Carteret Fire Department Headquarters",
#         "ADDRESS": "240 Roosevelt Avenue",
#         "CITY": "Carteret",
#         "STATE": "NJ",
#         "ZIPCODE": "07008"
#       },
#       "geometry": {
#         "x": -74.21733799991289,
#         "y": 40.57576499972212
#       }
#     }
#   ]
# }

# %%
nj_fire = pd.json_normalize(data_fire['features'])
pre_fire = nj_fire[nj_fire['attributes.CITY'].isin(city_names)].copy()

# %%
pre_fire['attributes.ZIPCODE'] = pre_fire[['attributes.ZIPCODE']].apply(lambda x: x.str.slice(0, 5))

pre_fire[['F_ID', 'F_name', 'F_address', 'F_city', 'F_zip', 'F_latitude', 'F_longitude']] = pre_fire[['attributes.OBJECTID', 'attributes.NAME', 'attributes.ADDRESS', 'attributes.CITY', 'attributes.ZIPCODE', 'geometry.y', 'geometry.x']]
df_fire = pre_fire.iloc[:, -7:]
df_fire
# Out:
#        F_ID                                             F_name  \
# 20     4781        Cassville Volunteer Fire Company Station 56
# 77     5177     Jackson Mills Volunteer Fire Company Station 2
# 139    5593        Six Flags Great Adventure Safety Department
# 214   22074                          Tuckerton Fire Department
# 237   23145   Barnegat Light Volunteer Fire Company Station 13
# ...     ...                                                ...
# 1220  51148            Herbertsville Fire Company 1 Station 24
# 1236  51357       Lakewood Township Fire Department Station 66
# 1237  51358       Lakewood Township Fire Department Station 65
# 1238  51359     Manitou Park Volunteer Fire Company Station 18
# 1249  51451  Lakewood Fire Department Engine Company 1 Station
#
#                          F_address          F_city  F_zip  F_latitude  \
# 20              12 Toms River Road         Jackson  08527   40.104000
# 77    550 West Commodore Boulevard         Jackson  08527   40.156765
# 139          1 Six Flags Boulevard         Jackson  08527   40.141055
# 214         111 North Green Street       Tuckerton  08087   39.603992
# 237             907 Central Avenue  Barnegat Light  08006   39.756428
# ...                            ...             ...    ...         ...
# 1220        601 Herbertsville Road           Brick  08724   40.111195
# 1236      976 New Hampshire Avenue        Lakewood  08701   40.053578
# 1237          1350 Lanes Mill Road        Lakewood  08701   40.100643
# 1238                110 3rd Avenue      Toms River  08757   39.945943
# 1249                119 1st Street        Lakewood  08701   40.091885
#
#       F_longitude
# 20     -74.386833
# 77     -74.389862
# 139    -74.445171
# 214    -74.339928
# 237    -74.107544
# ...           ...
# 1220   -74.107506
# 1236   -74.196650
# 1237   -74.170769
# 1238   -74.215366
# 1249   -74.211113
#
# [72 rows x 7 columns]

# %%
# df_fire.to_csv('./Data_Source/fire.csv', index = False)

# %% [markdown]
# ## Police department

# %%
url_police = 'https://services1.arcgis.com/' + HIFLD_key + '/arcgis/rest/services/Local_Law_Enforcement_Locations/FeatureServer/0/query?where=STATE%20%3D%20%27NJ%27%20AND%20COUNTY%20%3D%20%27OCEAN%27&outFields=OBJECTID,NAME,ADDRESS,CITY,STATE,ZIP,COUNTY,LATITUDE,LONGITUDE&outSR=4326&f=json'
data_police = json.loads(requests.get(url_police).content.decode('utf-8'))
print(json.dumps(data_police, indent = 2))
# Out:
# {
#   "objectIdFieldName": "OBJECTID",
#   "uniqueIdField": {
#     "name": "OBJECTID",
#     "isSystemMaintained": true
#   },
#   "globalIdFieldName": "",
#   "geometryType": "esriGeometryPoint",
#   "spatialReference": {
#     "wkid": 4326,
#     "latestWkid": 4326
#   },
#   "fields": [
#     {
#       "name": "OBJECTID",
#       "type": "esriFieldTypeOID",
#       "alias": "OBJECTID",
#       "sqlType": "sqlTypeOther",
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "NAME",
#       "type": "esriFieldTypeString",
#       "alias": "NAME",
#       "sqlType": "sqlTypeOther",
#       "length": 150,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "ADDRESS",
#       "type": "esriFieldTypeString",
#       "alias": "ADDRESS",
#       "sqlType": "sqlTypeOther",
#       "length": 150,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "CITY",
#       "type": "esriFieldTypeString",
#       "alias": "CITY",
#       "sqlType": "sqlTypeOther",
#       "length": 50,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "STATE",
#       "type": "esriFieldTypeString",
#       "alias": "STATE",
#       "sqlType": "sqlTypeOther",
#       "length": 20,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "ZIP",
#       "type": "esriFieldTypeString",
#       "alias": "ZIP",
#       "sqlType": "sqlTypeOther",
#       "length": 15,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "COUNTY",
#       "type": "esriFieldTypeString",
#       "alias": "COUNTY",
#       "sqlType": "sqlTypeOther",
#       "length": 50,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "LATITUDE",
#       "type": "esriFieldTypeDouble",
#       "alias": "LATITUDE",
#       "sqlType": "sqlTypeOther",
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "LONGITUDE",
#       "type": "esriFieldTypeDouble",
#       "alias": "LONGITUDE",
#       "sqlType": "sqlTypeOther",
#       "domain": null,
#       "defaultValue": null
#     }
#   ],
#   "features": [
#     {
#       "attributes": {
#         "OBJECTID": 5443,
#         "NAME": "BERKELEY TOWNSHIP POLICE DEPARTMENT",
#         "ADDRESS": "631 PINEWALD KESWICK ROAD",
#         "CITY": "BAYVILLE",
#         "STATE": "NJ",
#         "ZIP": "08721",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.9056057000001,
#         "LONGITUDE": -74.2344368
#       },
#       "geometry": {
#         "x": -74.23443679999997,
#         "y": 39.90560570000009
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 6221,
#         "NAME": "BEACH HAVEN POLICE DEPARTMENT",
#         "ADDRESS": "300 ENGLESIDE AVENUE",
#         "CITY": "BEACH HAVEN",
#         "STATE": "NJ",
#         "ZIP": "08008",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.5630485030001,
#         "LONGITUDE": -74.241287023
#       },
#       "geometry": {
#         "x": -74.24128702299998,
#         "y": 39.56304850300006
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 6514,
#         "NAME": "PLUMSTED TOWNSHIP POLICE DEPARTMENT",
#         "ADDRESS": "2 CEDAR STREET",
#         "CITY": "NEW EGYPT",
#         "STATE": "NJ",
#         "ZIP": "08533",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 40.0666059000001,
#         "LONGITUDE": -74.5232113
#       },
#       "geometry": {
#         "x": -74.52321129999996,
#         "y": 40.06660590000006
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 7382,
#         "NAME": "MANTOLOKING POLICE DEPARTMENT",
#         "ADDRESS": "202 DOWNER AVENUE",
#         "CITY": "MANTOLOKING",
#         "STATE": "NJ",
#         "ZIP": "08738",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 40.03698689,
#         "LONGITUDE": -74.052315885
#       },
#       "geometry": {
#         "x": -74.05231588499998,
#         "y": 40.03698689000003
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 7389,
#         "NAME": "BAY HEAD POLICE DEPARTMENT",
#         "ADDRESS": "81 BRIDGE AVENUE",
#         "CITY": "BAY HEAD",
#         "STATE": "NJ",
#         "ZIP": "08742",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 40.0695504620001,
#         "LONGITUDE": -74.0465646659999
#       },
#       "geometry": {
#         "x": -74.04656466599994,
#         "y": 40.069550462000045
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 8276,
#         "NAME": "OCEAN GATE BOROUGH POLICE DEPARTMENT",
#         "ADDRESS": "801 OCEAN GATE AVENUE",
#         "CITY": "OCEAN GATE",
#         "STATE": "NJ",
#         "ZIP": "08740",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.9244337000001,
#         "LONGITUDE": -74.1404029999999
#       },
#       "geometry": {
#         "x": -74.14040299999994,
#         "y": 39.92443370000006
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 9165,
#         "NAME": "STAFFORD TOWNSHIP POLICE DEPARTMENT",
#         "ADDRESS": "260 EAST BAY AVENUE",
#         "CITY": "MANAHAWKIN",
#         "STATE": "NJ",
#         "ZIP": "08050",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.6918431,
#         "LONGITUDE": -74.2503976
#       },
#       "geometry": {
#         "x": -74.25039759999999,
#         "y": 39.69184310000002
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 9168,
#         "NAME": "BARNEGAT TOWNSHIP POLICE DEPARTMENT",
#         "ADDRESS": "900 WEST BAY AVENUE",
#         "CITY": "BARNEGAT",
#         "STATE": "NJ",
#         "ZIP": "08005",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.758761237,
#         "LONGITUDE": -74.244876389
#       },
#       "geometry": {
#         "x": -74.24487638899996,
#         "y": 39.75876123700002
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 10168,
#         "NAME": "TUCKERTON BOROUGH POLICE DEPARTMENT",
#         "ADDRESS": "445 SOUTH GREEN STREET",
#         "CITY": "TUCKERTON",
#         "STATE": "NJ",
#         "ZIP": "08087",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.5928671,
#         "LONGITUDE": -74.3386298
#       },
#       "geometry": {
#         "x": -74.33862979999998,
#         "y": 39.59286710000002
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 10336,
#         "NAME": "LAKEWOOD POLICE DEPARTMENT",
#         "ADDRESS": "231 3RD STREET",
#         "CITY": "LAKEWOOD",
#         "STATE": "NJ",
#         "ZIP": "08701",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 40.0935915000001,
#         "LONGITUDE": -74.2131649999999
#       },
#       "geometry": {
#         "x": -74.21316499999995,
#         "y": 40.09359150000005
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 10388,
#         "NAME": "JACKSON TOWNSHIP POLICE DEPARTMENT",
#         "ADDRESS": "102 JACKSON DRIVE",
#         "CITY": "JACKSON",
#         "STATE": "NJ",
#         "ZIP": "08527",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 40.110020461,
#         "LONGITUDE": -74.3540878279999
#       },
#       "geometry": {
#         "x": -74.35408782799993,
#         "y": 40.11002046100003
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 10799,
#         "NAME": "LAVALLETTE POLICE DEPARTMENT",
#         "ADDRESS": "1300 GRAND CENTRAL AVENUE",
#         "CITY": "LAVALLETTE",
#         "STATE": "NJ",
#         "ZIP": "08735",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.9685623,
#         "LONGITUDE": -74.0695133
#       },
#       "geometry": {
#         "x": -74.06951329999998,
#         "y": 39.96856230000002
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 11004,
#         "NAME": "SURF CITY POLICE DEPARTMENT",
#         "ADDRESS": "813 LONG BEACH BOULEVARD",
#         "CITY": "SURF CITY",
#         "STATE": "NJ",
#         "ZIP": "08008",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.6604518,
#         "LONGITUDE": -74.1674492
#       },
#       "geometry": {
#         "x": -74.16744919999996,
#         "y": 39.66045180000003
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 12479,
#         "NAME": "BEACHWOOD POLICE DEPARTMENT",
#         "ADDRESS": "1600 PINEWALD ROAD",
#         "CITY": "BEACHWOOD",
#         "STATE": "NJ",
#         "ZIP": "08722",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.9177658,
#         "LONGITUDE": -74.2072329
#       },
#       "geometry": {
#         "x": -74.20723289999995,
#         "y": 39.91776580000004
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 12488,
#         "NAME": "HARVEY CEDARS POLICE DEPARTMENT",
#         "ADDRESS": "7606 LONG BEACH BOULEVARD",
#         "CITY": "HARVEY CEDARS",
#         "STATE": "NJ",
#         "ZIP": "08008",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.7050931910001,
#         "LONGITUDE": -74.135201851
#       },
#       "geometry": {
#         "x": -74.13520185099998,
#         "y": 39.70509319100005
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 12489,
#         "NAME": "BRICK TOWNSHIP POLICE DEPARTMENT",
#         "ADDRESS": "401 CHAMBERS BRIDGE ROAD",
#         "CITY": "BRICK",
#         "STATE": "NJ",
#         "ZIP": "08723",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 40.0752609,
#         "LONGITUDE": -74.152465299
#       },
#       "geometry": {
#         "x": -74.15246529899997,
#         "y": 40.07526090000004
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 12585,
#         "NAME": "SOUTH TOMS RIVER POLICE DEPARTMENT",
#         "ADDRESS": "144 MILL STREET",
#         "CITY": "SOUTH TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08757",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.94175503,
#         "LONGITUDE": -74.2026431309999
#       },
#       "geometry": {
#         "x": -74.20264313099995,
#         "y": 39.941755030000024
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 13275,
#         "NAME": "LACEY TOWNSHIP POLICE DEPARTMENT",
#         "ADDRESS": "808 WEST LACEY ROAD",
#         "CITY": "FORKED RIVER",
#         "STATE": "NJ",
#         "ZIP": "08731",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.8606832,
#         "LONGITUDE": -74.2073008
#       },
#       "geometry": {
#         "x": -74.20730079999998,
#         "y": 39.860683200000025
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 13519,
#         "NAME": "ISLAND HEIGHTS POLICE DEPARTMENT",
#         "ADDRESS": "1 EAST END AVENUE",
#         "CITY": "ISLAND HEIGHTS",
#         "STATE": "NJ",
#         "ZIP": "08732",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.9409456000001,
#         "LONGITUDE": -74.1369119
#       },
#       "geometry": {
#         "x": -74.13691189999997,
#         "y": 39.94094560000007
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 13860,
#         "NAME": "POINT PLEASANT POLICE DEPARTMENT",
#         "ADDRESS": "2233 BRIDGE AVENUE",
#         "CITY": "POINT PLEASANT",
#         "STATE": "NJ",
#         "ZIP": "08742",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 40.0726473010001,
#         "LONGITUDE": -74.069449672
#       },
#       "geometry": {
#         "x": -74.06944967199996,
#         "y": 40.072647301000075
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 14024,
#         "NAME": "MANCHESTER TOWNSHIP POLICE DEPARTMENT",
#         "ADDRESS": "1 COLONIAL DRIVE",
#         "CITY": "MANCHESTER",
#         "STATE": "NJ",
#         "ZIP": "08759",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 40.0065705000001,
#         "LONGITUDE": -74.297077299
#       },
#       "geometry": {
#         "x": -74.29707729899997,
#         "y": 40.00657050000006
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 14069,
#         "NAME": "BOROUGH OF PINE BEACH POLICE DEPARTMENT",
#         "ADDRESS": "599 PENNSYLVANIA AVENUE",
#         "CITY": "PINE BEACH",
#         "STATE": "NJ",
#         "ZIP": "08741",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.933579385,
#         "LONGITUDE": -74.1698491929999
#       },
#       "geometry": {
#         "x": -74.16984919299995,
#         "y": 39.93357938500002
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 14070,
#         "NAME": "LITTLE EGG HARBOR TOWNSHIP POLICE DEPARTMENT",
#         "ADDRESS": "665 RADIO ROAD",
#         "CITY": "LITTLE EGG HARBOR",
#         "STATE": "NJ",
#         "ZIP": "08087",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.5761797920001,
#         "LONGITUDE": -74.3636304679999
#       },
#       "geometry": {
#         "x": -74.36363046799994,
#         "y": 39.576179792000055
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 14103,
#         "NAME": "SEASIDE HEIGHTS POLICE DEPARTMENT",
#         "ADDRESS": "116 SHERMAN AVENUE",
#         "CITY": "SEASIDE HEIGHTS",
#         "STATE": "NJ",
#         "ZIP": "08751",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.9437372,
#         "LONGITUDE": -74.0737397999999
#       },
#       "geometry": {
#         "x": -74.07373979999994,
#         "y": 39.94373720000004
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 18416,
#         "NAME": "NEW JERSEY STATE POLICE TROOP C - TUCKERTON STATION",
#         "ADDRESS": "399 MAIN STREET",
#         "CITY": "WEST CREEK",
#         "STATE": "NJ",
#         "ZIP": "08092",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.6490523000001,
#         "LONGITUDE": -74.2966627
#       },
#       "geometry": {
#         "x": -74.29666269999996,
#         "y": 39.64905230000006
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 18735,
#         "NAME": "NEW JERSEY STATE POLICE - PLEASANT PLAINS SUBSTATION",
#         "ADDRESS": "GARDEN STATE PARKWAY, MILE MARKER 83.8",
#         "CITY": "TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08755",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.9843890000001,
#         "LONGITUDE": -74.2125124999999
#       },
#       "geometry": {
#         "x": -74.21251249999995,
#         "y": 39.98438900000008
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 19276,
#         "NAME": "LONG BEACH TOWNSHIP POLICE DEPARTMENT",
#         "ADDRESS": "6805 LONG BEACH BOULEVARD",
#         "CITY": "BRANT BEACH",
#         "STATE": "NJ",
#         "ZIP": "08008",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.6158931000001,
#         "LONGITUDE": -74.1994831
#       },
#       "geometry": {
#         "x": -74.19948309999995,
#         "y": 39.615893100000044
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 19277,
#         "NAME": "LAKEHURST POLICE DEPARTMENT",
#         "ADDRESS": "5 UNION AVENUE",
#         "CITY": "LAKEHURST",
#         "STATE": "NJ",
#         "ZIP": "08733",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 40.0125713,
#         "LONGITUDE": -74.3099233
#       },
#       "geometry": {
#         "x": -74.30992329999998,
#         "y": 40.01257130000003
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 19288,
#         "NAME": "TOMS RIVER POLICE DEPARTMENT",
#         "ADDRESS": "255 OAK AVENUE",
#         "CITY": "TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08753",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.9873247,
#         "LONGITUDE": -74.1845878
#       },
#       "geometry": {
#         "x": -74.18458779999997,
#         "y": 39.98732470000004
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 19311,
#         "NAME": "OCEAN TOWNSHIP POLICE DEPARTMENT",
#         "ADDRESS": "50 RAILROAD AVENUE",
#         "CITY": "WARETOWN",
#         "STATE": "NJ",
#         "ZIP": "08758",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.7904972000001,
#         "LONGITUDE": -74.197807
#       },
#       "geometry": {
#         "x": -74.19780699999995,
#         "y": 39.79049720000006
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 19431,
#         "NAME": "OCEAN COUNTY SHERIFFS DEPARTMENT",
#         "ADDRESS": "144 CHESTNUT STREET",
#         "CITY": "TOMS RIVER",
#         "STATE": "NJ",
#         "ZIP": "08753",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.9735115,
#         "LONGITUDE": -74.195503
#       },
#       "geometry": {
#         "x": -74.19550299999997,
#         "y": 39.97351150000002
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 19567,
#         "NAME": "SHIP BOTTOM POLICE DEPARTMENT",
#         "ADDRESS": "1621 LONG BEACH BOULEVARD",
#         "CITY": "SHIP BOTTOM",
#         "STATE": "NJ",
#         "ZIP": "08008",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.644869,
#         "LONGITUDE": -74.1800407
#       },
#       "geometry": {
#         "x": -74.18004069999995,
#         "y": 39.64486900000002
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 19585,
#         "NAME": "SEASIDE PARK BOROUGH POLICE DEPARTMENT",
#         "ADDRESS": "6TH AVENUE AND CENTRAL AVENUE",
#         "CITY": "SEASIDE PARK",
#         "STATE": "NJ",
#         "ZIP": "08752",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 39.9187315,
#         "LONGITUDE": -74.0790876999999
#       },
#       "geometry": {
#         "x": -74.07908769999995,
#         "y": 39.918731500000035
#       }
#     },
#     {
#       "attributes": {
#         "OBJECTID": 21138,
#         "NAME": "POINT PLEASANT BEACH POLICE DEPARTMENT",
#         "ADDRESS": "416 NEW JERSEY AVENUE",
#         "CITY": "POINT PLEASANT BEACH",
#         "STATE": "NJ",
#         "ZIP": "08742",
#         "COUNTY": "OCEAN",
#         "LATITUDE": 40.0869543000001,
#         "LONGITUDE": -74.0469075
#       },
#       "geometry": {
#         "x": -74.04690749999997,
#         "y": 40.08695430000006
#       }
#     }
#   ]
# }

# %%
pre_police = pd.json_normalize(data_police['features'])
pre_police
# Out:
#     attributes.OBJECTID                                    attributes.NAME  \
# 0                  5443                BERKELEY TOWNSHIP POLICE DEPARTMENT
# 1                  6221                      BEACH HAVEN POLICE DEPARTMENT
# 2                  6514                PLUMSTED TOWNSHIP POLICE DEPARTMENT
# 3                  7382                      MANTOLOKING POLICE DEPARTMENT
# 4                  7389                         BAY HEAD POLICE DEPARTMENT
# 5                  8276               OCEAN GATE BOROUGH POLICE DEPARTMENT
# 6                  9165                STAFFORD TOWNSHIP POLICE DEPARTMENT
# 7                  9168                BARNEGAT TOWNSHIP POLICE DEPARTMENT
# 8                 10168                TUCKERTON BOROUGH POLICE DEPARTMENT
# 9                 10336                         LAKEWOOD POLICE DEPARTMENT
# 10                10388                 JACKSON TOWNSHIP POLICE DEPARTMENT
# 11                10799                       LAVALLETTE POLICE DEPARTMENT
# 12                11004                        SURF CITY POLICE DEPARTMENT
# 13                12479                        BEACHWOOD POLICE DEPARTMENT
# 14                12488                    HARVEY CEDARS POLICE DEPARTMENT
# 15                12489                   BRICK TOWNSHIP POLICE DEPARTMENT
# 16                12585                 SOUTH TOMS RIVER POLICE DEPARTMENT
# 17                13275                   LACEY TOWNSHIP POLICE DEPARTMENT
# 18                13519                   ISLAND HEIGHTS POLICE DEPARTMENT
# 19                13860                   POINT PLEASANT POLICE DEPARTMENT
# 20                14024              MANCHESTER TOWNSHIP POLICE DEPARTMENT
# 21                14069            BOROUGH OF PINE BEACH POLICE DEPARTMENT
# 22                14070       LITTLE EGG HARBOR TOWNSHIP POLICE DEPARTMENT
# 23                14103                  SEASIDE HEIGHTS POLICE DEPARTMENT
# 24                18416  NEW JERSEY STATE POLICE TROOP C - TUCKERTON ST...
# 25                18735  NEW JERSEY STATE POLICE - PLEASANT PLAINS SUBS...
# 26                19276              LONG BEACH TOWNSHIP POLICE DEPARTMENT
# 27                19277                        LAKEHURST POLICE DEPARTMENT
# 28                19288                       TOMS RIVER POLICE DEPARTMENT
# 29                19311                   OCEAN TOWNSHIP POLICE DEPARTMENT
# 30                19431                   OCEAN COUNTY SHERIFFS DEPARTMENT
# 31                19567                      SHIP BOTTOM POLICE DEPARTMENT
# 32                19585             SEASIDE PARK BOROUGH POLICE DEPARTMENT
# 33                21138             POINT PLEASANT BEACH POLICE DEPARTMENT
#
#                         attributes.ADDRESS       attributes.CITY  \
# 0                631 PINEWALD KESWICK ROAD              BAYVILLE
# 1                     300 ENGLESIDE AVENUE           BEACH HAVEN
# 2                           2 CEDAR STREET             NEW EGYPT
# 3                        202 DOWNER AVENUE           MANTOLOKING
# 4                         81 BRIDGE AVENUE              BAY HEAD
# 5                    801 OCEAN GATE AVENUE            OCEAN GATE
# 6                      260 EAST BAY AVENUE            MANAHAWKIN
# 7                      900 WEST BAY AVENUE              BARNEGAT
# 8                   445 SOUTH GREEN STREET             TUCKERTON
# 9                           231 3RD STREET              LAKEWOOD
# 10                       102 JACKSON DRIVE               JACKSON
# 11               1300 GRAND CENTRAL AVENUE            LAVALLETTE
# 12                813 LONG BEACH BOULEVARD             SURF CITY
# 13                      1600 PINEWALD ROAD             BEACHWOOD
# 14               7606 LONG BEACH BOULEVARD         HARVEY CEDARS
# 15                401 CHAMBERS BRIDGE ROAD                 BRICK
# 16                         144 MILL STREET      SOUTH TOMS RIVER
# 17                     808 WEST LACEY ROAD          FORKED RIVER
# 18                       1 EAST END AVENUE        ISLAND HEIGHTS
# 19                      2233 BRIDGE AVENUE        POINT PLEASANT
# 20                        1 COLONIAL DRIVE            MANCHESTER
# 21                 599 PENNSYLVANIA AVENUE            PINE BEACH
# 22                          665 RADIO ROAD     LITTLE EGG HARBOR
# 23                      116 SHERMAN AVENUE       SEASIDE HEIGHTS
# 24                         399 MAIN STREET            WEST CREEK
# 25  GARDEN STATE PARKWAY, MILE MARKER 83.8            TOMS RIVER
# 26               6805 LONG BEACH BOULEVARD           BRANT BEACH
# 27                          5 UNION AVENUE             LAKEHURST
# 28                          255 OAK AVENUE            TOMS RIVER
# 29                      50 RAILROAD AVENUE              WARETOWN
# 30                     144 CHESTNUT STREET            TOMS RIVER
# 31               1621 LONG BEACH BOULEVARD           SHIP BOTTOM
# 32           6TH AVENUE AND CENTRAL AVENUE          SEASIDE PARK
# 33                   416 NEW JERSEY AVENUE  POINT PLEASANT BEACH
#
#    attributes.STATE attributes.ZIP attributes.COUNTY  attributes.LATITUDE  \
# 0                NJ          08721             OCEAN            39.905606
# 1                NJ          08008             OCEAN            39.563049
# 2                NJ          08533             OCEAN            40.066606
# 3                NJ          08738             OCEAN            40.036987
# 4                NJ          08742             OCEAN            40.069550
# 5                NJ          08740             OCEAN            39.924434
# 6                NJ          08050             OCEAN            39.691843
# 7                NJ          08005             OCEAN            39.758761
# 8                NJ          08087             OCEAN            39.592867
# 9                NJ          08701             OCEAN            40.093592
# 10               NJ          08527             OCEAN            40.110020
# 11               NJ          08735             OCEAN            39.968562
# 12               NJ          08008             OCEAN            39.660452
# 13               NJ          08722             OCEAN            39.917766
# 14               NJ          08008             OCEAN            39.705093
# 15               NJ          08723             OCEAN            40.075261
# 16               NJ          08757             OCEAN            39.941755
# 17               NJ          08731             OCEAN            39.860683
# 18               NJ          08732             OCEAN            39.940946
# 19               NJ          08742             OCEAN            40.072647
# 20               NJ          08759             OCEAN            40.006571
# 21               NJ          08741             OCEAN            39.933579
# 22               NJ          08087             OCEAN            39.576180
# 23               NJ          08751             OCEAN            39.943737
# 24               NJ          08092             OCEAN            39.649052
# 25               NJ          08755             OCEAN            39.984389
# 26               NJ          08008             OCEAN            39.615893
# 27               NJ          08733             OCEAN            40.012571
# 28               NJ          08753             OCEAN            39.987325
# 29               NJ          08758             OCEAN            39.790497
# 30               NJ          08753             OCEAN            39.973512
# 31               NJ          08008             OCEAN            39.644869
# 32               NJ          08752             OCEAN            39.918731
# 33               NJ          08742             OCEAN            40.086954
#
#     attributes.LONGITUDE  geometry.x  geometry.y
# 0             -74.234437  -74.234437   39.905606
# 1             -74.241287  -74.241287   39.563049
# 2             -74.523211  -74.523211   40.066606
# 3             -74.052316  -74.052316   40.036987
# 4             -74.046565  -74.046565   40.069550
# 5             -74.140403  -74.140403   39.924434
# 6             -74.250398  -74.250398   39.691843
# 7             -74.244876  -74.244876   39.758761
# 8             -74.338630  -74.338630   39.592867
# 9             -74.213165  -74.213165   40.093592
# 10            -74.354088  -74.354088   40.110020
# 11            -74.069513  -74.069513   39.968562
# 12            -74.167449  -74.167449   39.660452
# 13            -74.207233  -74.207233   39.917766
# 14            -74.135202  -74.135202   39.705093
# 15            -74.152465  -74.152465   40.075261
# 16            -74.202643  -74.202643   39.941755
# 17            -74.207301  -74.207301   39.860683
# 18            -74.136912  -74.136912   39.940946
# 19            -74.069450  -74.069450   40.072647
# 20            -74.297077  -74.297077   40.006571
# 21            -74.169849  -74.169849   39.933579
# 22            -74.363630  -74.363630   39.576180
# 23            -74.073740  -74.073740   39.943737
# 24            -74.296663  -74.296663   39.649052
# 25            -74.212512  -74.212512   39.984389
# 26            -74.199483  -74.199483   39.615893
# 27            -74.309923  -74.309923   40.012571
# 28            -74.184588  -74.184588   39.987325
# 29            -74.197807  -74.197807   39.790497
# 30            -74.195503  -74.195503   39.973512
# 31            -74.180041  -74.180041   39.644869
# 32            -74.079088  -74.079088   39.918732
# 33            -74.046908  -74.046907   40.086954

# %%
pre_police[['P_ID', 'P_name', 'P_address', 'P_city', 'P_zip', 'P_latitude', 'P_longitude']] = pre_police[['attributes.OBJECTID', 'attributes.NAME', 'attributes.ADDRESS', 'attributes.CITY', 'attributes.ZIP', 'attributes.LATITUDE', 'attributes.LONGITUDE']]
df_police = pre_police.iloc[:, -7:]
df_police = df_police.append([df_police[df_police['P_name'] == 'LONG BEACH TOWNSHIP POLICE DEPARTMENT'].copy()], ignore_index = True)
df_police.at[34, 'P_name'] = 'BARNEGAT LIGHT POLICE DEPARTMENT'
df_police
# Out:
#      P_ID                                             P_name  \
# 0    5443                BERKELEY TOWNSHIP POLICE DEPARTMENT
# 1    6221                      BEACH HAVEN POLICE DEPARTMENT
# 2    6514                PLUMSTED TOWNSHIP POLICE DEPARTMENT
# 3    7382                      MANTOLOKING POLICE DEPARTMENT
# 4    7389                         BAY HEAD POLICE DEPARTMENT
# 5    8276               OCEAN GATE BOROUGH POLICE DEPARTMENT
# 6    9165                STAFFORD TOWNSHIP POLICE DEPARTMENT
# 7    9168                BARNEGAT TOWNSHIP POLICE DEPARTMENT
# 8   10168                TUCKERTON BOROUGH POLICE DEPARTMENT
# 9   10336                         LAKEWOOD POLICE DEPARTMENT
# 10  10388                 JACKSON TOWNSHIP POLICE DEPARTMENT
# 11  10799                       LAVALLETTE POLICE DEPARTMENT
# 12  11004                        SURF CITY POLICE DEPARTMENT
# 13  12479                        BEACHWOOD POLICE DEPARTMENT
# 14  12488                    HARVEY CEDARS POLICE DEPARTMENT
# 15  12489                   BRICK TOWNSHIP POLICE DEPARTMENT
# 16  12585                 SOUTH TOMS RIVER POLICE DEPARTMENT
# 17  13275                   LACEY TOWNSHIP POLICE DEPARTMENT
# 18  13519                   ISLAND HEIGHTS POLICE DEPARTMENT
# 19  13860                   POINT PLEASANT POLICE DEPARTMENT
# 20  14024              MANCHESTER TOWNSHIP POLICE DEPARTMENT
# 21  14069            BOROUGH OF PINE BEACH POLICE DEPARTMENT
# 22  14070       LITTLE EGG HARBOR TOWNSHIP POLICE DEPARTMENT
# 23  14103                  SEASIDE HEIGHTS POLICE DEPARTMENT
# 24  18416  NEW JERSEY STATE POLICE TROOP C - TUCKERTON ST...
# 25  18735  NEW JERSEY STATE POLICE - PLEASANT PLAINS SUBS...
# 26  19276              LONG BEACH TOWNSHIP POLICE DEPARTMENT
# 27  19277                        LAKEHURST POLICE DEPARTMENT
# 28  19288                       TOMS RIVER POLICE DEPARTMENT
# 29  19311                   OCEAN TOWNSHIP POLICE DEPARTMENT
# 30  19431                   OCEAN COUNTY SHERIFFS DEPARTMENT
# 31  19567                      SHIP BOTTOM POLICE DEPARTMENT
# 32  19585             SEASIDE PARK BOROUGH POLICE DEPARTMENT
# 33  21138             POINT PLEASANT BEACH POLICE DEPARTMENT
# 34  19276                   BARNEGAT LIGHT POLICE DEPARTMENT
#
#                                  P_address                P_city  P_zip  \
# 0                631 PINEWALD KESWICK ROAD              BAYVILLE  08721
# 1                     300 ENGLESIDE AVENUE           BEACH HAVEN  08008
# 2                           2 CEDAR STREET             NEW EGYPT  08533
# 3                        202 DOWNER AVENUE           MANTOLOKING  08738
# 4                         81 BRIDGE AVENUE              BAY HEAD  08742
# 5                    801 OCEAN GATE AVENUE            OCEAN GATE  08740
# 6                      260 EAST BAY AVENUE            MANAHAWKIN  08050
# 7                      900 WEST BAY AVENUE              BARNEGAT  08005
# 8                   445 SOUTH GREEN STREET             TUCKERTON  08087
# 9                           231 3RD STREET              LAKEWOOD  08701
# 10                       102 JACKSON DRIVE               JACKSON  08527
# 11               1300 GRAND CENTRAL AVENUE            LAVALLETTE  08735
# 12                813 LONG BEACH BOULEVARD             SURF CITY  08008
# 13                      1600 PINEWALD ROAD             BEACHWOOD  08722
# 14               7606 LONG BEACH BOULEVARD         HARVEY CEDARS  08008
# 15                401 CHAMBERS BRIDGE ROAD                 BRICK  08723
# 16                         144 MILL STREET      SOUTH TOMS RIVER  08757
# 17                     808 WEST LACEY ROAD          FORKED RIVER  08731
# 18                       1 EAST END AVENUE        ISLAND HEIGHTS  08732
# 19                      2233 BRIDGE AVENUE        POINT PLEASANT  08742
# 20                        1 COLONIAL DRIVE            MANCHESTER  08759
# 21                 599 PENNSYLVANIA AVENUE            PINE BEACH  08741
# 22                          665 RADIO ROAD     LITTLE EGG HARBOR  08087
# 23                      116 SHERMAN AVENUE       SEASIDE HEIGHTS  08751
# 24                         399 MAIN STREET            WEST CREEK  08092
# 25  GARDEN STATE PARKWAY, MILE MARKER 83.8            TOMS RIVER  08755
# 26               6805 LONG BEACH BOULEVARD           BRANT BEACH  08008
# 27                          5 UNION AVENUE             LAKEHURST  08733
# 28                          255 OAK AVENUE            TOMS RIVER  08753
# 29                      50 RAILROAD AVENUE              WARETOWN  08758
# 30                     144 CHESTNUT STREET            TOMS RIVER  08753
# 31               1621 LONG BEACH BOULEVARD           SHIP BOTTOM  08008
# 32           6TH AVENUE AND CENTRAL AVENUE          SEASIDE PARK  08752
# 33                   416 NEW JERSEY AVENUE  POINT PLEASANT BEACH  08742
# 34               6805 LONG BEACH BOULEVARD           BRANT BEACH  08008
#
#     P_latitude  P_longitude
# 0    39.905606   -74.234437
# 1    39.563049   -74.241287
# 2    40.066606   -74.523211
# 3    40.036987   -74.052316
# 4    40.069550   -74.046565
# 5    39.924434   -74.140403
# 6    39.691843   -74.250398
# 7    39.758761   -74.244876
# 8    39.592867   -74.338630
# 9    40.093592   -74.213165
# 10   40.110020   -74.354088
# 11   39.968562   -74.069513
# 12   39.660452   -74.167449
# 13   39.917766   -74.207233
# 14   39.705093   -74.135202
# 15   40.075261   -74.152465
# 16   39.941755   -74.202643
# 17   39.860683   -74.207301
# 18   39.940946   -74.136912
# 19   40.072647   -74.069450
# 20   40.006571   -74.297077
# 21   39.933579   -74.169849
# 22   39.576180   -74.363630
# 23   39.943737   -74.073740
# 24   39.649052   -74.296663
# 25   39.984389   -74.212512
# 26   39.615893   -74.199483
# 27   40.012571   -74.309923
# 28   39.987325   -74.184588
# 29   39.790497   -74.197807
# 30   39.973512   -74.195503
# 31   39.644869   -74.180041
# 32   39.918731   -74.079088
# 33   40.086954   -74.046908
# 34   39.615893   -74.199483

# %%
# df_police.to_csv('./Data_Source/police.csv', index = False)

# %%
url_crime_station = 'https://api.usa.gov/crime/fbi/sapi/api/agencies/byStateAbbr/NJ?API_KEY=' + FBI_NJ_key
data_crime_station = json.loads(requests.get(url_crime_station).content.decode('utf-8'))
print(json.dumps(data_crime_station, indent = 2))
# Out:
# {
#   "results": [
#     {
#       "ori": "NJ0010000",
#       "agency_name": "Atlantic County Sheriff's Office",
#       "agency_type_name": "County",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ATLANTIC",
#       "nibrs": false,
#       "latitude": 39.469354,
#       "longitude": -74.633758,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0010100",
#       "agency_name": "Absecon Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ATLANTIC",
#       "nibrs": false,
#       "latitude": 39.432816,
#       "longitude": -74.50694,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0010200",
#       "agency_name": "Atlantic City Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ATLANTIC",
#       "nibrs": false,
#       "latitude": 39.35547,
#       "longitude": -74.44455,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0010300",
#       "agency_name": "Brigantine Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ATLANTIC",
#       "nibrs": false,
#       "latitude": 39.40182,
#       "longitude": -74.373,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0010400",
#       "agency_name": "Buena Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ATLANTIC",
#       "nibrs": false,
#       "latitude": 39.469354,
#       "longitude": -74.633758,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0010700",
#       "agency_name": "Egg Harbor City Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ATLANTIC",
#       "nibrs": false,
#       "latitude": 39.53562,
#       "longitude": -74.6435,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0010800",
#       "agency_name": "Egg Harbor Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ATLANTIC",
#       "nibrs": false,
#       "latitude": 39.361202,
#       "longitude": -74.58162,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0011100",
#       "agency_name": "Galloway Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ATLANTIC",
#       "nibrs": false,
#       "latitude": 39.469354,
#       "longitude": -74.633758,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0011200",
#       "agency_name": "Hamilton Township, Atlantic County Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ATLANTIC",
#       "nibrs": false,
#       "latitude": 39.46348,
#       "longitude": -74.72269,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0011300",
#       "agency_name": "Hammonton Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ATLANTIC",
#       "nibrs": false,
#       "latitude": 39.63631,
#       "longitude": -74.80069,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0011400",
#       "agency_name": "Linwood Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ATLANTIC",
#       "nibrs": false,
#       "latitude": 39.35344,
#       "longitude": -74.57406,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0011500",
#       "agency_name": "Longport Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ATLANTIC",
#       "nibrs": false,
#       "latitude": 39.469354,
#       "longitude": -74.633758,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0011600",
#       "agency_name": "Margate City Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ATLANTIC",
#       "nibrs": false,
#       "latitude": 39.469354,
#       "longitude": -74.633758,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0011700",
#       "agency_name": "Mullica Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ATLANTIC",
#       "nibrs": false,
#       "latitude": 39.469354,
#       "longitude": -74.633758,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0011800",
#       "agency_name": "Northfield Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ATLANTIC",
#       "nibrs": false,
#       "latitude": 39.366985,
#       "longitude": -74.54935,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0011900",
#       "agency_name": "Pleasantville Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ATLANTIC",
#       "nibrs": false,
#       "latitude": 39.469354,
#       "longitude": -74.633758,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0012100",
#       "agency_name": "Somers Point Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ATLANTIC",
#       "nibrs": false,
#       "latitude": 39.469354,
#       "longitude": -74.633758,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0012200",
#       "agency_name": "Ventnor City Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ATLANTIC",
#       "nibrs": false,
#       "latitude": 39.33784,
#       "longitude": -74.47907,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0012400",
#       "agency_name": "Stockton University",
#       "agency_type_name": "University or College",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ATLANTIC",
#       "nibrs": false,
#       "latitude": 39.469354,
#       "longitude": -74.633758,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0018900",
#       "agency_name": "Prosecutor: Atlantic County",
#       "agency_type_name": "Other",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ATLANTIC",
#       "nibrs": false,
#       "latitude": 39.469354,
#       "longitude": -74.633758,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ001SP00",
#       "agency_name": "State Police: Atlantic County",
#       "agency_type_name": "State Police",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ATLANTIC",
#       "nibrs": false,
#       "latitude": 39.57778,
#       "longitude": -74.871025,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0020000",
#       "agency_name": "Bergen County Sheriff's Office",
#       "agency_type_name": "County",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.87844,
#       "longitude": -74.04463,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0020100",
#       "agency_name": "Allendale Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 41.027573,
#       "longitude": -74.125175,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0020200",
#       "agency_name": "Alpine Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.959648,
#       "longitude": -74.07486,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0020300",
#       "agency_name": "Bergenfield Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.934464,
#       "longitude": -73.99526,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0020400",
#       "agency_name": "Bogota Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.878845,
#       "longitude": -74.030464,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0020500",
#       "agency_name": "Carlstadt Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.84115,
#       "longitude": -74.09472,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0020600",
#       "agency_name": "Cliffside Park Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.821335,
#       "longitude": -73.98795,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0020700",
#       "agency_name": "Closter Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.971157,
#       "longitude": -73.95951,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0020800",
#       "agency_name": "Cresskill Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.941456,
#       "longitude": -73.959854,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0020900",
#       "agency_name": "Demarest Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.955627,
#       "longitude": -73.96486,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0021000",
#       "agency_name": "Dumont Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.959648,
#       "longitude": -74.07486,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0021100",
#       "agency_name": "Elmwood Park Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.900894,
#       "longitude": -74.12382,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0021200",
#       "agency_name": "East Rutherford Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.835724,
#       "longitude": -74.101036,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0021300",
#       "agency_name": "Edgewater Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.826324,
#       "longitude": -73.97387,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0021400",
#       "agency_name": "Emerson Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.959648,
#       "longitude": -74.07486,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0021500",
#       "agency_name": "Englewood Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.959648,
#       "longitude": -74.07486,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0021600",
#       "agency_name": "Englewood Cliffs Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.87886,
#       "longitude": -73.95019,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0021700",
#       "agency_name": "Fair Lawn Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.935867,
#       "longitude": -74.13274,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0021800",
#       "agency_name": "Fairview Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.81177,
#       "longitude": -73.99978,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0021900",
#       "agency_name": "Fort Lee Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.84407,
#       "longitude": -73.98105,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0022000",
#       "agency_name": "Franklin Lakes Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 41.01939,
#       "longitude": -74.19872,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0022100",
#       "agency_name": "Garfield Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.878628,
#       "longitude": -74.102425,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0022200",
#       "agency_name": "Glen Rock Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.960922,
#       "longitude": -74.12806,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0022300",
#       "agency_name": "Hackensack Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.885597,
#       "longitude": -74.043846,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0022400",
#       "agency_name": "Harrington Park Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.959648,
#       "longitude": -74.07486,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0022500",
#       "agency_name": "Hasbrouck Heights Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.860577,
#       "longitude": -74.07742,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0022600",
#       "agency_name": "Haworth Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.960667,
#       "longitude": -73.98877,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0022700",
#       "agency_name": "Hillsdale Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 41.00267,
#       "longitude": -74.03907,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0022800",
#       "agency_name": "Ho-Ho-Kus Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.99976,
#       "longitude": -74.1082,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0022900",
#       "agency_name": "Leonia Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.959648,
#       "longitude": -74.07486,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0023000",
#       "agency_name": "Little Ferry Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.959648,
#       "longitude": -74.07486,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0023100",
#       "agency_name": "Lodi Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.959648,
#       "longitude": -74.07486,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0023200",
#       "agency_name": "Lyndhurst Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.959648,
#       "longitude": -74.07486,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0023300",
#       "agency_name": "Mahwah Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 41.0927,
#       "longitude": -74.14457,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0023400",
#       "agency_name": "Maywood Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.904198,
#       "longitude": -74.06047,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0023500",
#       "agency_name": "Midland Park Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.9911,
#       "longitude": -74.14154,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0023600",
#       "agency_name": "Montvale Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 41.052425,
#       "longitude": -74.062195,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0023700",
#       "agency_name": "Moonachie Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.841698,
#       "longitude": -74.04578,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0023800",
#       "agency_name": "New Milford Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.923904,
#       "longitude": -74.02718,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0023900",
#       "agency_name": "North Arlington Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.959648,
#       "longitude": -74.07486,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0024000",
#       "agency_name": "Northvale Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 41.00771,
#       "longitude": -73.95181,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0024100",
#       "agency_name": "Norwood Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.959648,
#       "longitude": -74.07486,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0024200",
#       "agency_name": "Oakland Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.959648,
#       "longitude": -74.07486,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0024300",
#       "agency_name": "Old Tappan Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 41.01251,
#       "longitude": -73.98387,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0024400",
#       "agency_name": "Oradell Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.953396,
#       "longitude": -74.03177,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0024500",
#       "agency_name": "Palisades Park Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.959648,
#       "longitude": -74.07486,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0024600",
#       "agency_name": "Paramus Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.926895,
#       "longitude": -74.07081,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0024700",
#       "agency_name": "Park Ridge Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 41.033936,
#       "longitude": -74.03984,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0024800",
#       "agency_name": "Ramsey Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.959648,
#       "longitude": -74.07486,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0024900",
#       "agency_name": "Ridgefield Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.835297,
#       "longitude": -74.00822,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0025000",
#       "agency_name": "Ridgefield Park Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.858017,
#       "longitude": -74.024796,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0025100",
#       "agency_name": "Ridgewood Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.98219,
#       "longitude": -74.112564,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0025200",
#       "agency_name": "River Edge Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.959648,
#       "longitude": -74.07486,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0025300",
#       "agency_name": "River Vale Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 41.00217,
#       "longitude": -74.0076,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0025400",
#       "agency_name": "Rochelle Park Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.91295,
#       "longitude": -74.07893,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0025500",
#       "agency_name": "Rockleigh Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 41.00771,
#       "longitude": -73.95181,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0025600",
#       "agency_name": "Rutherford Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.83072,
#       "longitude": -74.09892,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0025700",
#       "agency_name": "Saddle Brook Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.89535,
#       "longitude": -74.08156,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0025800",
#       "agency_name": "Saddle River Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 41.031727,
#       "longitude": -74.098526,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0025900",
#       "agency_name": "South Hackensack Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.860104,
#       "longitude": -74.04551,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0026000",
#       "agency_name": "Teaneck Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.88642,
#       "longitude": -74.00625,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0026100",
#       "agency_name": "Tenafly Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.927692,
#       "longitude": -73.97017,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0026200",
#       "agency_name": "Teterboro Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.850433,
#       "longitude": -74.043655,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0026300",
#       "agency_name": "Upper Saddle River Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 41.05641,
#       "longitude": -74.099045,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0026400",
#       "agency_name": "Waldwick Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 41.01075,
#       "longitude": -74.11732,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0026500",
#       "agency_name": "Wallington Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.853134,
#       "longitude": -74.11477,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0026600",
#       "agency_name": "Washington Township, Bergen County Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.987038,
#       "longitude": -74.06454,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0026700",
#       "agency_name": "Westwood Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.992096,
#       "longitude": -74.03615,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0026800",
#       "agency_name": "Woodcliff Lake Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.959648,
#       "longitude": -74.07486,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0026900",
#       "agency_name": "Wood-Ridge Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.84448,
#       "longitude": -74.08721,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0027000",
#       "agency_name": "Wyckoff Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 41.010517,
#       "longitude": -74.16765,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0028900",
#       "agency_name": "Prosecutor: Bergen County",
#       "agency_type_name": "Other",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.87844,
#       "longitude": -74.04463,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ002SP00",
#       "agency_name": "State Police: Bergen County",
#       "agency_type_name": "State Police",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.900017,
#       "longitude": -74.22954,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0030000",
#       "agency_name": "Burlington County Sheriff's Office",
#       "agency_type_name": "County",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BURLINGTON",
#       "nibrs": false,
#       "latitude": 39.875786,
#       "longitude": -74.663006,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0030200",
#       "agency_name": "Beverly Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BURLINGTON",
#       "nibrs": false,
#       "latitude": 40.06326,
#       "longitude": -74.92111,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0030300",
#       "agency_name": "Bordentown Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BURLINGTON",
#       "nibrs": false,
#       "latitude": 40.145588,
#       "longitude": -74.71135,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0030400",
#       "agency_name": "Bordentown Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BURLINGTON",
#       "nibrs": false,
#       "latitude": 40.140152,
#       "longitude": -74.703476,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0030500",
#       "agency_name": "Burlington Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BURLINGTON",
#       "nibrs": false,
#       "latitude": 40.07433,
#       "longitude": -74.85663,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0030600",
#       "agency_name": "Burlington Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BURLINGTON",
#       "nibrs": false,
#       "latitude": 39.875786,
#       "longitude": -74.663006,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0030700",
#       "agency_name": "Chesterfield Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BURLINGTON",
#       "nibrs": false,
#       "latitude": 39.875786,
#       "longitude": -74.663006,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0030800",
#       "agency_name": "Cinnaminson Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BURLINGTON",
#       "nibrs": false,
#       "latitude": 39.875786,
#       "longitude": -74.663006,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0030900",
#       "agency_name": "Delanco Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BURLINGTON",
#       "nibrs": false,
#       "latitude": 40.049206,
#       "longitude": -74.9475,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0031000",
#       "agency_name": "Delran Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BURLINGTON",
#       "nibrs": false,
#       "latitude": 39.875786,
#       "longitude": -74.663006,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0031100",
#       "agency_name": "Eastampton Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BURLINGTON",
#       "nibrs": false,
#       "latitude": 39.875786,
#       "longitude": -74.663006,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0031200",
#       "agency_name": "Edgewater Park Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BURLINGTON",
#       "nibrs": false,
#       "latitude": 39.875786,
#       "longitude": -74.663006,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0031300",
#       "agency_name": "Evesham Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BURLINGTON",
#       "nibrs": false,
#       "latitude": 39.883373,
#       "longitude": -74.87755,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0031400",
#       "agency_name": "Fieldsboro Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BURLINGTON",
#       "nibrs": false,
#       "latitude": 40.13747,
#       "longitude": -74.730156,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0031500",
#       "agency_name": "Florence Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BURLINGTON",
# ...
#     },
#     {
#       "ori": "NJ0201200",
#       "agency_name": "Plainfield Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "UNION",
#       "nibrs": false,
#       "latitude": 40.61861,
#       "longitude": -74.41885,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0201300",
#       "agency_name": "Rahway Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "UNION",
#       "nibrs": false,
#       "latitude": 40.659871,
#       "longitude": -74.308696,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0201400",
#       "agency_name": "Roselle Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "UNION",
#       "nibrs": false,
#       "latitude": 40.658653,
#       "longitude": -74.263275,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0201500",
#       "agency_name": "Roselle Park Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "UNION",
#       "nibrs": false,
#       "latitude": 40.66218,
#       "longitude": -74.260124,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0201600",
#       "agency_name": "Scotch Plains Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "UNION",
#       "nibrs": false,
#       "latitude": 40.65006,
#       "longitude": -74.39732,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0201700",
#       "agency_name": "Springfield Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "UNION",
#       "nibrs": false,
#       "latitude": 40.708416,
#       "longitude": -74.31366,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0201800",
#       "agency_name": "Summit Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "UNION",
#       "nibrs": false,
#       "latitude": 40.71703,
#       "longitude": -74.363396,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0201900",
#       "agency_name": "Union Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "UNION",
#       "nibrs": false,
#       "latitude": 40.659871,
#       "longitude": -74.308696,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0202000",
#       "agency_name": "Westfield Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "UNION",
#       "nibrs": false,
#       "latitude": 40.654408,
#       "longitude": -74.34541,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0202100",
#       "agency_name": "Winfield Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "UNION",
#       "nibrs": false,
#       "latitude": 40.659871,
#       "longitude": -74.308696,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0202400",
#       "agency_name": "Kean University",
#       "agency_type_name": "University or College",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "UNION",
#       "nibrs": false,
#       "latitude": 40.68504,
#       "longitude": -74.23841,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0208900",
#       "agency_name": "Prosecutor: Union County",
#       "agency_type_name": "Other",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "UNION",
#       "nibrs": false,
#       "latitude": 40.66166,
#       "longitude": -74.216965,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0209100",
#       "agency_name": "Park Police: Union County",
#       "agency_type_name": "Other",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "UNION",
#       "nibrs": false,
#       "latitude": 40.650787,
#       "longitude": -74.34329,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ020SP00",
#       "agency_name": "State Police: Union County",
#       "agency_type_name": "State Police",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "UNION",
#       "nibrs": false,
#       "latitude": 40.900017,
#       "longitude": -74.22954,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0210000",
#       "agency_name": "Warren County Sheriff's Office",
#       "agency_type_name": "County",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "WARREN",
#       "nibrs": false,
#       "latitude": 40.82724,
#       "longitude": -75.07699,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0210200",
#       "agency_name": "Alpha Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "WARREN",
#       "nibrs": false,
#       "latitude": 40.64938,
#       "longitude": -75.14311,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0210300",
#       "agency_name": "Belvidere Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "WARREN",
#       "nibrs": false,
#       "latitude": 40.832584,
#       "longitude": -75.066826,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0210400",
#       "agency_name": "Blairstown Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "WARREN",
#       "nibrs": false,
#       "latitude": 40.98754,
#       "longitude": -74.97823,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0210700",
#       "agency_name": "Greenwich Township, Warren County Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "WARREN",
#       "nibrs": false,
#       "latitude": 40.693443,
#       "longitude": -75.11222,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0210800",
#       "agency_name": "Hackettstown Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "WARREN",
#       "nibrs": false,
#       "latitude": 40.853524,
#       "longitude": -75.009542,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0211200",
#       "agency_name": "Independence Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "WARREN",
#       "nibrs": false,
#       "latitude": 40.853524,
#       "longitude": -75.009542,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0211500",
#       "agency_name": "Lopatcong Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "WARREN",
#       "nibrs": false,
#       "latitude": 40.700356,
#       "longitude": -75.17103,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0211600",
#       "agency_name": "Mansfield Township, Warren County Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "WARREN",
#       "nibrs": false,
#       "latitude": null,
#       "longitude": null,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0211700",
#       "agency_name": "Oxford Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "WARREN",
#       "nibrs": false,
#       "latitude": 40.803326,
#       "longitude": -74.991516,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0211900",
#       "agency_name": "Phillipsburg Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "WARREN",
#       "nibrs": false,
#       "latitude": 40.698498,
#       "longitude": -75.18114,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0212000",
#       "agency_name": "Pohatcong Township Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "WARREN",
#       "nibrs": false,
#       "latitude": 40.64938,
#       "longitude": -75.14311,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0212100",
#       "agency_name": "Washington Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "WARREN",
#       "nibrs": false,
#       "latitude": 40.75955,
#       "longitude": -74.98039,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0212200",
#       "agency_name": "Washington Township, Warren County Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "WARREN",
#       "nibrs": false,
#       "latitude": 40.75158,
#       "longitude": -74.97682,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0218900",
#       "agency_name": "Prosecutor: Warren County",
#       "agency_type_name": "Other",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "WARREN",
#       "nibrs": false,
#       "latitude": 40.853524,
#       "longitude": -75.009542,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ021SP00",
#       "agency_name": "State Police: Warren County",
#       "agency_type_name": "State Police",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "WARREN",
#       "nibrs": false,
#       "latitude": 40.900017,
#       "longitude": -74.22954,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0225400",
#       "agency_name": "State Park Police",
#       "agency_type_name": "Other State Agency",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "",
#       "nibrs": false,
#       "latitude": 40.282503,
#       "longitude": -74.703724,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJ0225500",
#       "agency_name": "Department of Corrections ",
#       "agency_type_name": "Other State Agency",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "",
#       "nibrs": false,
#       "latitude": null,
#       "longitude": null,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJNPD0000",
#       "agency_name": "Newark Police Department",
#       "agency_type_name": "City",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "ESSEX",
#       "nibrs": false,
#       "latitude": 40.731922,
#       "longitude": -74.17256,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJNPIPP00",
#       "agency_name": "Palisades Interstate Parkway",
#       "agency_type_name": "Other State Agency",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "BERGEN",
#       "nibrs": false,
#       "latitude": 40.959648,
#       "longitude": -74.07486,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJNSP2200",
#       "agency_name": "State Police",
#       "agency_type_name": "State Police",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "",
#       "nibrs": false,
#       "latitude": 39.328387,
#       "longitude": -75.121644,
#       "nibrs_start_date": null
#     },
#     {
#       "ori": "NJNYPOA00",
#       "agency_name": "Port Authority of New York and New Jersey",
#       "agency_type_name": "Other State Agency",
#       "state_name": "New Jersey",
#       "state_abbr": "NJ",
#       "division_name": "Middle Atlantic",
#       "region_name": "Northeast",
#       "region_desc": "Region I",
#       "county_name": "",
#       "nibrs": false,
#       "latitude": 40.731384,
#       "longitude": -74.078627,
#       "nibrs_start_date": null
#     }
#   ],
#   "pagination": {
#     "count": 577,
#     "page": 0,
#     "pages": 1,
#     "per_page": 0
#   }
# }

# %%
df_crime_station = pd.json_normalize(data_crime_station['results'])
df_crime_station = df_crime_station[df_crime_station['county_name'] == 'OCEAN']
df_crime_station['agency_name'] = df_crime_station['agency_name'].str.upper()
df_crime_station
# Out:
#            ori                                     agency_name  \
# 427  NJ0150000                   OCEAN COUNTY SHERIFF'S OFFICE
# 428  NJ0150100                BARNEGAT LIGHT POLICE DEPARTMENT
# 429  NJ0150200                      BAY HEAD POLICE DEPARTMENT
# 430  NJ0150300                   BEACH HAVEN POLICE DEPARTMENT
# 431  NJ0150400                     BEACHWOOD POLICE DEPARTMENT
# 432  NJ0150500             BERKELEY TOWNSHIP POLICE DEPARTMENT
# 433  NJ0150600                BRICK TOWNSHIP POLICE DEPARTMENT
# 434  NJ0150700           TOMS RIVER TOWNSHIP POLICE DEPARTMENT
# 435  NJ0150900                 HARVEY CEDARS POLICE DEPARTMENT
# 436  NJ0151000                ISLAND HEIGHTS POLICE DEPARTMENT
# 437  NJ0151100              JACKSON TOWNSHIP POLICE DEPARTMENT
# 438  NJ0151200                LACEY TOWNSHIP POLICE DEPARTMENT
# 439  NJ0151300                     LAKEHURST POLICE DEPARTMENT
# 440  NJ0151400             LAKEWOOD TOWNSHIP POLICE DEPARTMENT
# 441  NJ0151500                    LAVALLETTE POLICE DEPARTMENT
# 442  NJ0151600    LITTLE EGG HARBOR TOWNSHIP POLICE DEPARTMENT
# 443  NJ0151700           LONG BEACH TOWNSHIP POLICE DEPARTMENT
# 444  NJ0151800           MANCHESTER TOWNSHIP POLICE DEPARTMENT
# 445  NJ0151900                   MANTOLOKING POLICE DEPARTMENT
# 446  NJ0152000  OCEAN TOWNSHIP, OCEAN COUNTY POLICE DEPARTMENT
# 447  NJ0152100                    OCEAN GATE POLICE DEPARTMENT
# 448  NJ0152200                    PINE BEACH POLICE DEPARTMENT
# 449  NJ0152300             PLUMSTED TOWNSHIP POLICE DEPARTMENT
# 450  NJ0152400                POINT PLEASANT POLICE DEPARTMENT
# 451  NJ0152500          POINT PLEASANT BEACH POLICE DEPARTMENT
# 452  NJ0152600               SEASIDE HEIGHTS POLICE DEPARTMENT
# 453  NJ0152700                  SEASIDE PARK POLICE DEPARTMENT
# 454  NJ0152800                   SHIP BOTTOM POLICE DEPARTMENT
# 455  NJ0152900              SOUTH TOMS RIVER POLICE DEPARTMENT
# 456  NJ0153000             STAFFORD TOWNSHIP POLICE DEPARTMENT
# 457  NJ0153100                     SURF CITY POLICE DEPARTMENT
# 458  NJ0153200                     TUCKERTON POLICE DEPARTMENT
# 459  NJ0153300             BARNEGAT TOWNSHIP POLICE DEPARTMENT
# 460  NJ0158900                        PROSECUTOR: OCEAN COUNTY
# 461  NJ015SP00                      STATE POLICE: OCEAN COUNTY
#
#     agency_type_name  state_name state_abbr    division_name region_name  \
# 427           County  New Jersey         NJ  Middle Atlantic   Northeast
# 428             City  New Jersey         NJ  Middle Atlantic   Northeast
# 429             City  New Jersey         NJ  Middle Atlantic   Northeast
# 430             City  New Jersey         NJ  Middle Atlantic   Northeast
# 431             City  New Jersey         NJ  Middle Atlantic   Northeast
# 432             City  New Jersey         NJ  Middle Atlantic   Northeast
# 433             City  New Jersey         NJ  Middle Atlantic   Northeast
# 434             City  New Jersey         NJ  Middle Atlantic   Northeast
# 435             City  New Jersey         NJ  Middle Atlantic   Northeast
# 436             City  New Jersey         NJ  Middle Atlantic   Northeast
# 437             City  New Jersey         NJ  Middle Atlantic   Northeast
# 438             City  New Jersey         NJ  Middle Atlantic   Northeast
# 439             City  New Jersey         NJ  Middle Atlantic   Northeast
# 440             City  New Jersey         NJ  Middle Atlantic   Northeast
# 441             City  New Jersey         NJ  Middle Atlantic   Northeast
# 442             City  New Jersey         NJ  Middle Atlantic   Northeast
# 443             City  New Jersey         NJ  Middle Atlantic   Northeast
# 444             City  New Jersey         NJ  Middle Atlantic   Northeast
# 445             City  New Jersey         NJ  Middle Atlantic   Northeast
# 446             City  New Jersey         NJ  Middle Atlantic   Northeast
# 447             City  New Jersey         NJ  Middle Atlantic   Northeast
# 448             City  New Jersey         NJ  Middle Atlantic   Northeast
# 449             City  New Jersey         NJ  Middle Atlantic   Northeast
# 450             City  New Jersey         NJ  Middle Atlantic   Northeast
# 451             City  New Jersey         NJ  Middle Atlantic   Northeast
# 452             City  New Jersey         NJ  Middle Atlantic   Northeast
# 453             City  New Jersey         NJ  Middle Atlantic   Northeast
# 454             City  New Jersey         NJ  Middle Atlantic   Northeast
# 455             City  New Jersey         NJ  Middle Atlantic   Northeast
# 456             City  New Jersey         NJ  Middle Atlantic   Northeast
# 457             City  New Jersey         NJ  Middle Atlantic   Northeast
# 458             City  New Jersey         NJ  Middle Atlantic   Northeast
# 459             City  New Jersey         NJ  Middle Atlantic   Northeast
# 460            Other  New Jersey         NJ  Middle Atlantic   Northeast
# 461     State Police  New Jersey         NJ  Middle Atlantic   Northeast
#
#     region_desc county_name  nibrs   latitude  longitude nibrs_start_date
# 427    Region I       OCEAN  False  39.953976 -74.193436             None
# 428    Region I       OCEAN  False  39.616623 -74.200310             None
# 429    Region I       OCEAN  False  39.865669 -74.258864             None
# 430    Region I       OCEAN  False  39.562916 -74.240690             None
# 431    Region I       OCEAN  False  39.865669 -74.258864             None
# 432    Region I       OCEAN  False  39.865669 -74.258864             None
# 433    Region I       OCEAN  False  39.865669 -74.258864             None
# 434    Region I       OCEAN  False  39.986946 -74.181694             None
# 435    Region I       OCEAN  False  39.865669 -74.258864             None
# 436    Region I       OCEAN  False  39.865669 -74.258864             None
# 437    Region I       OCEAN  False  39.865669 -74.258864             None
# 438    Region I       OCEAN  False  39.859646 -74.206870             None
# 439    Region I       OCEAN  False  40.012380 -74.309944             None
# 440    Region I       OCEAN  False  40.093304 -74.213180             None
# 441    Region I       OCEAN  False  39.968130 -74.069305             None
# 442    Region I       OCEAN  False  39.576393 -74.364490             None
# 443    Region I       OCEAN  False  39.616623 -74.200310             None
# 444    Region I       OCEAN  False  40.005750 -74.297325             None
# 445    Region I       OCEAN  False  39.865669 -74.258864             None
# 446    Region I       OCEAN  False        NaN        NaN             None
# 447    Region I       OCEAN  False  39.924740 -74.140680             None
# 448    Region I       OCEAN  False  39.933838 -74.169586             None
# 449    Region I       OCEAN  False  40.066760 -74.523420             None
# 450    Region I       OCEAN  False  40.071968 -74.068245             None
# 451    Region I       OCEAN  False  40.087223 -74.047560             None
# 452    Region I       OCEAN  False  39.943450 -74.073660             None
# 453    Region I       OCEAN  False  39.865669 -74.258864             None
# 454    Region I       OCEAN  False  39.644833 -74.179726             None
# 455    Region I       OCEAN  False  39.943220 -74.200310             None
# 456    Region I       OCEAN  False  39.865669 -74.258864             None
# 457    Region I       OCEAN  False  39.568660 -74.236404             None
# 458    Region I       OCEAN  False  39.590490 -74.338930             None
# 459    Region I       OCEAN  False  39.865669 -74.258864             None
# 460    Region I       OCEAN  False  39.953693 -74.193490             None
# 461    Region I       OCEAN  False  39.865669 -74.258864             None

# %%
# df_crime_station.to_csv('./Data_Source/crime_data_pt1_station.csv', index = False)

# %%
station_codes = list(df_crime_station.ori)
station_codes
# Out:
# ['NJ0150000',
#  'NJ0150100',
#  'NJ0150200',
#  'NJ0150300',
#  'NJ0150400',
#  'NJ0150500',
#  'NJ0150600',
#  'NJ0150700',
#  'NJ0150900',
#  'NJ0151000',
#  'NJ0151100',
#  'NJ0151200',
#  'NJ0151300',
#  'NJ0151400',
#  'NJ0151500',
#  'NJ0151600',
#  'NJ0151700',
#  'NJ0151800',
#  'NJ0151900',
#  'NJ0152000',
#  'NJ0152100',
#  'NJ0152200',
#  'NJ0152300',
#  'NJ0152400',
#  'NJ0152500',
#  'NJ0152600',
#  'NJ0152700',
#  'NJ0152800',
#  'NJ0152900',
#  'NJ0153000',
#  'NJ0153100',
#  'NJ0153200',
#  'NJ0153300',
#  'NJ0158900',
#  'NJ015SP00']

# %%
def getRecord(station_codes):
    allRecord = []
    for station_code in station_codes:
        url_crime_record = 'https://api.usa.gov/crime/fbi/sapi/api/summarized/agencies/' + station_code + '/offenses/2015/2019?API_KEY=' + FBI_NJ_key
        data_crime_record = json.loads(requests.get(url_crime_record).content.decode('utf-8'))
        df_crime_record = pd.json_normalize(data_crime_record['results'])
        
        agg_crime_record = df_crime_record.groupby('offense').agg({'actual':'sum'}).T
        agg_crime_record['case_number'] = agg_crime_record.iloc[:, -12:-1].sum(axis=1)
        agg_crime_record['ori'] = station_code

        allRecord.append(agg_crime_record)
    
    allRecord = pd.concat(allRecord, axis = 0, ignore_index = True, sort = False)
    cols = allRecord.columns.tolist()
    cols = cols[-1:] + cols[:-1]
    allRecord = allRecord[cols]
    
    return allRecord

# %%
df_crime_record = getRecord(station_codes)
df_crime_record
# Out:
# offense        ori  aggravated-assault  arson  burglary  homicide  \
# 0        NJ0150000                   1      0         3         0
# 1        NJ0150100                   1      0         9         1
# 2        NJ0150200                   2      0        18         0
# 3        NJ0150300                   5      0        24         0
# 4        NJ0150400                   9      1       102         0
# 5        NJ0150500                 123      9       423         0
# 6        NJ0150600                 253     21       707         3
# 7        NJ0150700                 152     23      1019         3
# 8        NJ0150900                   1      0         6         0
# 9        NJ0151000                   2      0        16         0
# 10       NJ0151100                  78     27       464         3
# 11       NJ0151200                  62      1       184         2
# 12       NJ0151300                  11      0        13         0
# 13       NJ0151400                 422     27      1049         8
# 14       NJ0151500                   3      1        19         0
# 15       NJ0151600                  53     11       249         1
# 16       NJ0151700                  20      1        63         0
# 17       NJ0151800                  57     14       302         4
# 18       NJ0151900                   0      0         6         0
# 19       NJ0152000                   7      0        31         0
# 20       NJ0152100                   2      0        46         0
# 21       NJ0152200                   2      0         9         0
# 22       NJ0152300                  11      0        62         1
# 23       NJ0152400                  50      0       141         0
# 24       NJ0152500                   9      1        60         1
# 25       NJ0152600                 108      1       149         1
# 26       NJ0152700                   4      1        30         0
# 27       NJ0152800                   2      0        13         0
# 28       NJ0152900                  28      3        70         1
# 29       NJ0153000                  86      4        85         0
# 30       NJ0153100                   2      0         8         0
# 31       NJ0153200                   9      0        43         0
# 32       NJ0153300                  49      6       115         0
# 33       NJ0158900                   0      0         0         0
# 34       NJ015SP00                  13      0        32         0
#
# offense  human-trafficing  larceny  motor-vehicle-theft  property-crime  rape  \
# 0                       0       21                    0              24     0
# 1                       0       27                    0              36     1
# 2                       0       59                    7              84     0
# 3                       0      500                    3             527     1
# 4                       0      496                    4             602     8
# 5                       0     1638                   40            2101    32
# 6                       0     3962                   80            4749    77
# 7                       0     6888                  189            8096    44
# 8                       0       68                    0              74     0
# 9                       0       39                    0              55     1
# 10                      0     1606                   96            2166    16
# 11                      0     1389                   23            1596    20
# 12                      0      114                    6             133     0
# 13                      0     3458                  193            4700    42
# 14                      0      120                    5             144     0
# 15                      0      997                   29            1275    26
# 16                      0      340                    5             408     6
# 17                      0      957                   37            1296     5
# 18                      0       32                    5              43     0
# 19                      0      244                    5             280     1
# 20                      0      122                    2             170     0
# 21                      0       78                    0              87     1
# 22                      0      104                   11             177     6
# 23                      0      559                   15             715     4
# 24                      0      368                   17             445     1
# 25                      0      693                   15             857     2
# 26                      0      112                    4             146     1
# 27                      0      101                    0             114     0
# 28                      0      208                   17             295     1
# 29                      0      903                   37            1025     8
# 30                      0       82                    0              90     2
# 31                      0      139                    8             190     0
# 32                      0      542                   21             678     9
# 33                      0        0                    0               0     0
# 34                      0      119                    5             156     5
#
# offense  rape-legacy  robbery  violent-crime  case_number
# 0                  0        0              1           49
# 1                  0        0              3           75
# 2                  0        0              2          170
# 3                  0        0              6         1060
# 4                  0       12             29         1234
# 5                  0       43            198         4409
# 6                  0       69            402         9921
# 7                  0      113            312        16527
# 8                  0        0              1          149
# 9                  0        1              4          114
# 10                 0       25            122         4481
# 11                 0       18            102         3295
# 12                 0        6             17          283
# 13                 0      239            711        10138
# 14                 0        1              4          293
# 15                 0        9             89         2650
# 16                 0        0             26          843
# 17                 0       17             83         2689
# 18                 0        0              0           86
# 19                 0        1              9          569
# 20                 0        1              3          343
# 21                 0        1              4          178
# 22                 0        2             20          374
# 23                 0        5             59         1489
# 24                 0        4             15          906
# 25                 0       27            138         1853
# 26                 0        4              9          302
# 27                 0        0              2          230
# 28                 0       11             41          634
# 29                 0        8            102         2156
# 30                 0        0              4          184
# 31                 0        1             10          390
# 32                 0       14             72         1434
# 33                 0        0              0            0
# 34                 0        2             20          332

# %%
# df_crime_record.to_csv('./Data_Source/crime_data_pt2_record.csv', index = False)

# %%
df_crime_data = pd.merge(df_crime_station[['ori', 'agency_name']], df_crime_record, on = "ori")
df_crime_data
# Out:
#           ori                                     agency_name  \
# 0   NJ0150000                   OCEAN COUNTY SHERIFF'S OFFICE
# 1   NJ0150100                BARNEGAT LIGHT POLICE DEPARTMENT
# 2   NJ0150200                      BAY HEAD POLICE DEPARTMENT
# 3   NJ0150300                   BEACH HAVEN POLICE DEPARTMENT
# 4   NJ0150400                     BEACHWOOD POLICE DEPARTMENT
# 5   NJ0150500             BERKELEY TOWNSHIP POLICE DEPARTMENT
# 6   NJ0150600                BRICK TOWNSHIP POLICE DEPARTMENT
# 7   NJ0150700           TOMS RIVER TOWNSHIP POLICE DEPARTMENT
# 8   NJ0150900                 HARVEY CEDARS POLICE DEPARTMENT
# 9   NJ0151000                ISLAND HEIGHTS POLICE DEPARTMENT
# 10  NJ0151100              JACKSON TOWNSHIP POLICE DEPARTMENT
# 11  NJ0151200                LACEY TOWNSHIP POLICE DEPARTMENT
# 12  NJ0151300                     LAKEHURST POLICE DEPARTMENT
# 13  NJ0151400             LAKEWOOD TOWNSHIP POLICE DEPARTMENT
# 14  NJ0151500                    LAVALLETTE POLICE DEPARTMENT
# 15  NJ0151600    LITTLE EGG HARBOR TOWNSHIP POLICE DEPARTMENT
# 16  NJ0151700           LONG BEACH TOWNSHIP POLICE DEPARTMENT
# 17  NJ0151800           MANCHESTER TOWNSHIP POLICE DEPARTMENT
# 18  NJ0151900                   MANTOLOKING POLICE DEPARTMENT
# 19  NJ0152000  OCEAN TOWNSHIP, OCEAN COUNTY POLICE DEPARTMENT
# 20  NJ0152100                    OCEAN GATE POLICE DEPARTMENT
# 21  NJ0152200                    PINE BEACH POLICE DEPARTMENT
# 22  NJ0152300             PLUMSTED TOWNSHIP POLICE DEPARTMENT
# 23  NJ0152400                POINT PLEASANT POLICE DEPARTMENT
# 24  NJ0152500          POINT PLEASANT BEACH POLICE DEPARTMENT
# 25  NJ0152600               SEASIDE HEIGHTS POLICE DEPARTMENT
# 26  NJ0152700                  SEASIDE PARK POLICE DEPARTMENT
# 27  NJ0152800                   SHIP BOTTOM POLICE DEPARTMENT
# 28  NJ0152900              SOUTH TOMS RIVER POLICE DEPARTMENT
# 29  NJ0153000             STAFFORD TOWNSHIP POLICE DEPARTMENT
# 30  NJ0153100                     SURF CITY POLICE DEPARTMENT
# 31  NJ0153200                     TUCKERTON POLICE DEPARTMENT
# 32  NJ0153300             BARNEGAT TOWNSHIP POLICE DEPARTMENT
# 33  NJ0158900                        PROSECUTOR: OCEAN COUNTY
# 34  NJ015SP00                      STATE POLICE: OCEAN COUNTY
#
#     aggravated-assault  arson  burglary  homicide  human-trafficing  larceny  \
# 0                    1      0         3         0                 0       21
# 1                    1      0         9         1                 0       27
# 2                    2      0        18         0                 0       59
# 3                    5      0        24         0                 0      500
# 4                    9      1       102         0                 0      496
# 5                  123      9       423         0                 0     1638
# 6                  253     21       707         3                 0     3962
# 7                  152     23      1019         3                 0     6888
# 8                    1      0         6         0                 0       68
# 9                    2      0        16         0                 0       39
# 10                  78     27       464         3                 0     1606
# 11                  62      1       184         2                 0     1389
# 12                  11      0        13         0                 0      114
# 13                 422     27      1049         8                 0     3458
# 14                   3      1        19         0                 0      120
# 15                  53     11       249         1                 0      997
# 16                  20      1        63         0                 0      340
# 17                  57     14       302         4                 0      957
# 18                   0      0         6         0                 0       32
# 19                   7      0        31         0                 0      244
# 20                   2      0        46         0                 0      122
# 21                   2      0         9         0                 0       78
# 22                  11      0        62         1                 0      104
# 23                  50      0       141         0                 0      559
# 24                   9      1        60         1                 0      368
# 25                 108      1       149         1                 0      693
# 26                   4      1        30         0                 0      112
# 27                   2      0        13         0                 0      101
# 28                  28      3        70         1                 0      208
# 29                  86      4        85         0                 0      903
# 30                   2      0         8         0                 0       82
# 31                   9      0        43         0                 0      139
# 32                  49      6       115         0                 0      542
# 33                   0      0         0         0                 0        0
# 34                  13      0        32         0                 0      119
#
#     motor-vehicle-theft  property-crime  rape  rape-legacy  robbery  \
# 0                     0              24     0            0        0
# 1                     0              36     1            0        0
# 2                     7              84     0            0        0
# 3                     3             527     1            0        0
# 4                     4             602     8            0       12
# 5                    40            2101    32            0       43
# 6                    80            4749    77            0       69
# 7                   189            8096    44            0      113
# 8                     0              74     0            0        0
# 9                     0              55     1            0        1
# 10                   96            2166    16            0       25
# 11                   23            1596    20            0       18
# 12                    6             133     0            0        6
# 13                  193            4700    42            0      239
# 14                    5             144     0            0        1
# 15                   29            1275    26            0        9
# 16                    5             408     6            0        0
# 17                   37            1296     5            0       17
# 18                    5              43     0            0        0
# 19                    5             280     1            0        1
# 20                    2             170     0            0        1
# 21                    0              87     1            0        1
# 22                   11             177     6            0        2
# 23                   15             715     4            0        5
# 24                   17             445     1            0        4
# 25                   15             857     2            0       27
# 26                    4             146     1            0        4
# 27                    0             114     0            0        0
# 28                   17             295     1            0       11
# 29                   37            1025     8            0        8
# 30                    0              90     2            0        0
# 31                    8             190     0            0        1
# 32                   21             678     9            0       14
# 33                    0               0     0            0        0
# 34                    5             156     5            0        2
#
#     violent-crime  case_number
# 0               1           49
# 1               3           75
# 2               2          170
# 3               6         1060
# 4              29         1234
# 5             198         4409
# 6             402         9921
# 7             312        16527
# 8               1          149
# 9               4          114
# 10            122         4481
# 11            102         3295
# 12             17          283
# 13            711        10138
# 14              4          293
# 15             89         2650
# 16             26          843
# 17             83         2689
# 18              0           86
# 19              9          569
# 20              3          343
# 21              4          178
# 22             20          374
# 23             59         1489
# 24             15          906
# 25            138         1853
# 26              9          302
# 27              2          230
# 28             41          634
# 29            102         2156
# 30              4          184
# 31             10          390
# 32             72         1434
# 33              0            0
# 34             20          332

# %%
# df_crime_data.to_csv('./Data_Source/crime_data.csv', index = False)

# %% [markdown]
# ## Merge Police department with Crime record

# %%
def getFuzzyMatch(df_police, df_crime_data):
    df_crime_data['dummy'] = True
    df_police['dummy'] = True
    
    pre_crime_police = pd.merge(df_police, df_crime_data, on = 'dummy')
    pre_crime_police.drop('dummy', axis = 1, inplace = True)
    
    cols = pre_crime_police.columns.tolist()
    col = cols[:4] + cols[7:] + cols[4:7]
    pre_crime_police = pre_crime_police[col]
   
    pre_crime_police['Token_Set_Ratio'] = pre_crime_police[['agency_name', 'P_name']].apply(lambda x:fuzz.token_set_ratio(x.agency_name, x.P_name), axis = 1)
    pre_crime_police['Rank_Token_Set_Ratio'] = pre_crime_police.groupby('agency_name')['Token_Set_Ratio'].rank(ascending = False, method = 'dense')

    pre_crime_police['Token_Sort_Ratio'] = pre_crime_police[['agency_name','P_name']].apply(lambda x:fuzz.token_sort_ratio(x.agency_name, x.P_name), axis = 1)
    pre_crime_police['Rank_Token_Sort_Ratio'] = pre_crime_police.groupby('agency_name')['Token_Sort_Ratio'].rank(ascending = False, method = 'dense')

    pre_crime_police = pre_crime_police.loc[(pre_crime_police.Rank_Token_Set_Ratio == 1) & (pre_crime_police.Token_Set_Ratio > 70) & ((pre_crime_police.Token_Sort_Ratio == 100) | ((pre_crime_police.Token_Sort_Ratio < 90) & (pre_crime_police.Token_Sort_Ratio > 80)) | (pre_crime_police.Token_Sort_Ratio < 70))]
    crime_police = pre_crime_police.iloc[:,:-4]
    
    return crime_police

# %%
df_crime_police = getFuzzyMatch(df_police, df_crime_data)
df_crime_police
# Out:
#        P_ID                                        P_name  \
# 5      5443           BERKELEY TOWNSHIP POLICE DEPARTMENT
# 38     6221                 BEACH HAVEN POLICE DEPARTMENT
# 92     6514           PLUMSTED TOWNSHIP POLICE DEPARTMENT
# 123    7382                 MANTOLOKING POLICE DEPARTMENT
# 142    7389                    BAY HEAD POLICE DEPARTMENT
# 195    8276          OCEAN GATE BOROUGH POLICE DEPARTMENT
# 239    9165           STAFFORD TOWNSHIP POLICE DEPARTMENT
# 277    9168           BARNEGAT TOWNSHIP POLICE DEPARTMENT
# 311   10168           TUCKERTON BOROUGH POLICE DEPARTMENT
# 328   10336                    LAKEWOOD POLICE DEPARTMENT
# 360   10388            JACKSON TOWNSHIP POLICE DEPARTMENT
# 399   10799                  LAVALLETTE POLICE DEPARTMENT
# 450   11004                   SURF CITY POLICE DEPARTMENT
# 459   12479                   BEACHWOOD POLICE DEPARTMENT
# 498   12488               HARVEY CEDARS POLICE DEPARTMENT
# 531   12489              BRICK TOWNSHIP POLICE DEPARTMENT
# 588   12585            SOUTH TOMS RIVER POLICE DEPARTMENT
# 606   13275              LACEY TOWNSHIP POLICE DEPARTMENT
# 639   13519              ISLAND HEIGHTS POLICE DEPARTMENT
# 688   13860              POINT PLEASANT POLICE DEPARTMENT
# 717   14024         MANCHESTER TOWNSHIP POLICE DEPARTMENT
# 756   14069       BOROUGH OF PINE BEACH POLICE DEPARTMENT
# 785   14070  LITTLE EGG HARBOR TOWNSHIP POLICE DEPARTMENT
# 830   14103             SEASIDE HEIGHTS POLICE DEPARTMENT
# 926   19276         LONG BEACH TOWNSHIP POLICE DEPARTMENT
# 957   19277                   LAKEHURST POLICE DEPARTMENT
# 987   19288                  TOMS RIVER POLICE DEPARTMENT
# 1034  19311              OCEAN TOWNSHIP POLICE DEPARTMENT
# 1112  19567                 SHIP BOTTOM POLICE DEPARTMENT
# 1146  19585        SEASIDE PARK BOROUGH POLICE DEPARTMENT
# 1179  21138        POINT PLEASANT BEACH POLICE DEPARTMENT
# 1191  19276              BARNEGAT LIGHT POLICE DEPARTMENT
#
#                           P_address                P_city        ori  \
# 5         631 PINEWALD KESWICK ROAD              BAYVILLE  NJ0150500
# 38             300 ENGLESIDE AVENUE           BEACH HAVEN  NJ0150300
# 92                   2 CEDAR STREET             NEW EGYPT  NJ0152300
# 123               202 DOWNER AVENUE           MANTOLOKING  NJ0151900
# 142                81 BRIDGE AVENUE              BAY HEAD  NJ0150200
# 195           801 OCEAN GATE AVENUE            OCEAN GATE  NJ0152100
# 239             260 EAST BAY AVENUE            MANAHAWKIN  NJ0153000
# 277             900 WEST BAY AVENUE              BARNEGAT  NJ0153300
# 311          445 SOUTH GREEN STREET             TUCKERTON  NJ0153200
# 328                  231 3RD STREET              LAKEWOOD  NJ0151400
# 360               102 JACKSON DRIVE               JACKSON  NJ0151100
# 399       1300 GRAND CENTRAL AVENUE            LAVALLETTE  NJ0151500
# 450        813 LONG BEACH BOULEVARD             SURF CITY  NJ0153100
# 459              1600 PINEWALD ROAD             BEACHWOOD  NJ0150400
# 498       7606 LONG BEACH BOULEVARD         HARVEY CEDARS  NJ0150900
# 531        401 CHAMBERS BRIDGE ROAD                 BRICK  NJ0150600
# 588                 144 MILL STREET      SOUTH TOMS RIVER  NJ0152900
# 606             808 WEST LACEY ROAD          FORKED RIVER  NJ0151200
# 639               1 EAST END AVENUE        ISLAND HEIGHTS  NJ0151000
# 688              2233 BRIDGE AVENUE        POINT PLEASANT  NJ0152400
# 717                1 COLONIAL DRIVE            MANCHESTER  NJ0151800
# 756         599 PENNSYLVANIA AVENUE            PINE BEACH  NJ0152200
# 785                  665 RADIO ROAD     LITTLE EGG HARBOR  NJ0151600
# 830              116 SHERMAN AVENUE       SEASIDE HEIGHTS  NJ0152600
# 926       6805 LONG BEACH BOULEVARD           BRANT BEACH  NJ0151700
# 957                  5 UNION AVENUE             LAKEHURST  NJ0151300
# 987                  255 OAK AVENUE            TOMS RIVER  NJ0150700
# 1034             50 RAILROAD AVENUE              WARETOWN  NJ0152000
# 1112      1621 LONG BEACH BOULEVARD           SHIP BOTTOM  NJ0152800
# 1146  6TH AVENUE AND CENTRAL AVENUE          SEASIDE PARK  NJ0152700
# 1179          416 NEW JERSEY AVENUE  POINT PLEASANT BEACH  NJ0152500
# 1191      6805 LONG BEACH BOULEVARD           BRANT BEACH  NJ0150100
#
#                                          agency_name  aggravated-assault  \
# 5                BERKELEY TOWNSHIP POLICE DEPARTMENT                 123
# 38                     BEACH HAVEN POLICE DEPARTMENT                   5
# 92               PLUMSTED TOWNSHIP POLICE DEPARTMENT                  11
# 123                    MANTOLOKING POLICE DEPARTMENT                   0
# 142                       BAY HEAD POLICE DEPARTMENT                   2
# 195                     OCEAN GATE POLICE DEPARTMENT                   2
# 239              STAFFORD TOWNSHIP POLICE DEPARTMENT                  86
# 277              BARNEGAT TOWNSHIP POLICE DEPARTMENT                  49
# 311                      TUCKERTON POLICE DEPARTMENT                   9
# 328              LAKEWOOD TOWNSHIP POLICE DEPARTMENT                 422
# 360               JACKSON TOWNSHIP POLICE DEPARTMENT                  78
# 399                     LAVALLETTE POLICE DEPARTMENT                   3
# 450                      SURF CITY POLICE DEPARTMENT                   2
# 459                      BEACHWOOD POLICE DEPARTMENT                   9
# 498                  HARVEY CEDARS POLICE DEPARTMENT                   1
# 531                 BRICK TOWNSHIP POLICE DEPARTMENT                 253
# 588               SOUTH TOMS RIVER POLICE DEPARTMENT                  28
# 606                 LACEY TOWNSHIP POLICE DEPARTMENT                  62
# 639                 ISLAND HEIGHTS POLICE DEPARTMENT                   2
# 688                 POINT PLEASANT POLICE DEPARTMENT                  50
# 717            MANCHESTER TOWNSHIP POLICE DEPARTMENT                  57
# 756                     PINE BEACH POLICE DEPARTMENT                   2
# 785     LITTLE EGG HARBOR TOWNSHIP POLICE DEPARTMENT                  53
# 830                SEASIDE HEIGHTS POLICE DEPARTMENT                 108
# 926            LONG BEACH TOWNSHIP POLICE DEPARTMENT                  20
# 957                      LAKEHURST POLICE DEPARTMENT                  11
# 987            TOMS RIVER TOWNSHIP POLICE DEPARTMENT                 152
# 1034  OCEAN TOWNSHIP, OCEAN COUNTY POLICE DEPARTMENT                   7
# 1112                   SHIP BOTTOM POLICE DEPARTMENT                   2
# 1146                  SEASIDE PARK POLICE DEPARTMENT                   4
# 1179          POINT PLEASANT BEACH POLICE DEPARTMENT                   9
# 1191                BARNEGAT LIGHT POLICE DEPARTMENT                   1
#
#       arson  burglary  homicide  ...  motor-vehicle-theft  property-crime  \
# 5         9       423         0  ...                   40            2101
# 38        0        24         0  ...                    3             527
# 92        0        62         1  ...                   11             177
# 123       0         6         0  ...                    5              43
# 142       0        18         0  ...                    7              84
# 195       0        46         0  ...                    2             170
# 239       4        85         0  ...                   37            1025
# 277       6       115         0  ...                   21             678
# 311       0        43         0  ...                    8             190
# 328      27      1049         8  ...                  193            4700
# 360      27       464         3  ...                   96            2166
# 399       1        19         0  ...                    5             144
# 450       0         8         0  ...                    0              90
# 459       1       102         0  ...                    4             602
# 498       0         6         0  ...                    0              74
# 531      21       707         3  ...                   80            4749
# 588       3        70         1  ...                   17             295
# 606       1       184         2  ...                   23            1596
# 639       0        16         0  ...                    0              55
# 688       0       141         0  ...                   15             715
# 717      14       302         4  ...                   37            1296
# 756       0         9         0  ...                    0              87
# 785      11       249         1  ...                   29            1275
# 830       1       149         1  ...                   15             857
# 926       1        63         0  ...                    5             408
# 957       0        13         0  ...                    6             133
# 987      23      1019         3  ...                  189            8096
# 1034      0        31         0  ...                    5             280
# 1112      0        13         0  ...                    0             114
# 1146      1        30         0  ...                    4             146
# 1179      1        60         1  ...                   17             445
# 1191      0         9         1  ...                    0              36
#
#       rape  rape-legacy  robbery  violent-crime  case_number  P_zip  \
# 5       32            0       43            198         4409  08721
# 38       1            0        0              6         1060  08008
# 92       6            0        2             20          374  08533
# 123      0            0        0              0           86  08738
# 142      0            0        0              2          170  08742
# 195      0            0        1              3          343  08740
# 239      8            0        8            102         2156  08050
# 277      9            0       14             72         1434  08005
# 311      0            0        1             10          390  08087
# 328     42            0      239            711        10138  08701
# 360     16            0       25            122         4481  08527
# 399      0            0        1              4          293  08735
# 450      2            0        0              4          184  08008
# 459      8            0       12             29         1234  08722
# 498      0            0        0              1          149  08008
# 531     77            0       69            402         9921  08723
# 588      1            0       11             41          634  08757
# 606     20            0       18            102         3295  08731
# 639      1            0        1              4          114  08732
# 688      4            0        5             59         1489  08742
# 717      5            0       17             83         2689  08759
# 756      1            0        1              4          178  08741
# 785     26            0        9             89         2650  08087
# 830      2            0       27            138         1853  08751
# 926      6            0        0             26          843  08008
# 957      0            0        6             17          283  08733
# 987     44            0      113            312        16527  08753
# 1034     1            0        1              9          569  08758
# 1112     0            0        0              2          230  08008
# 1146     1            0        4              9          302  08752
# 1179     1            0        4             15          906  08742
# 1191     1            0        0              3           75  08008
#
#       P_latitude P_longitude
# 5      39.905606  -74.234437
# 38     39.563049  -74.241287
# 92     40.066606  -74.523211
# 123    40.036987  -74.052316
# 142    40.069550  -74.046565
# 195    39.924434  -74.140403
# 239    39.691843  -74.250398
# 277    39.758761  -74.244876
# 311    39.592867  -74.338630
# 328    40.093592  -74.213165
# 360    40.110020  -74.354088
# 399    39.968562  -74.069513
# 450    39.660452  -74.167449
# 459    39.917766  -74.207233
# 498    39.705093  -74.135202
# 531    40.075261  -74.152465
# 588    39.941755  -74.202643
# 606    39.860683  -74.207301
# 639    39.940946  -74.136912
# 688    40.072647  -74.069450
# 717    40.006571  -74.297077
# 756    39.933579  -74.169849
# 785    39.576180  -74.363630
# 830    39.943737  -74.073740
# 926    39.615893  -74.199483
# 957    40.012571  -74.309923
# 987    39.987325  -74.184588
# 1034   39.790497  -74.197807
# 1112   39.644869  -74.180041
# 1146   39.918731  -74.079088
# 1179   40.086954  -74.046908
# 1191   39.615893  -74.199483
#
# [32 rows x 22 columns]

# %%
df_crime_police = getFuzzyMatch(df_police, df_crime_data)
df_crime_police[df_crime_police['P_name'] == 'TOMS RIVER POLICE DEPARTMENT']
# Out:
#                            P_name                            agency_name  \
# 987  TOMS RIVER POLICE DEPARTMENT  TOMS RIVER TOWNSHIP POLICE DEPARTMENT
#
#      Token_Set_Ratio  Rank_Token_Set_Ratio  Token_Sort_Ratio  \
# 987              100                   1.0                86
#
#      Rank_Token_Sort_Ratio
# 987                    1.0

# %%
# df_crime_police.to_csv('./Data_Source/crime_police.csv', index = False)
